# %% [markdown]
# # ARAUS-extended dataset generation - preparing original ARAUS
# This script adequates the augmented audios and the data csv from ARAUS dataset so that it is prepared to generate the new ARAUS-extended dataset.
# responses.csv provided by ARAUS authors contains the data associated with the augmented soundscapes (participant answers, features of the audio, fold to which the audio belongs, base soundscape and masker used for the augmentation...).
# However, we are included some new columns into the dataframe, so that it is complete and handy for our operations.
# 1) We are adding the sound source of the maskers (bird, traffic, construction...), as new features --> 6 more columns
# 2) We are addind Pleasantness and Eventfulness values calculated from the participant answers punctuations --> 2 more columns
# 3) We are adding the wav gain that has to be applied to each digital signal to convert it to pressure signal in Pascals --> 1 more column

# %%
import numpy as np
import pandas as pd
import os
from maad.util import mean_dB
from maad.spl import pressure2leq
from Mosqito.loadFiles import load

# %% [markdown]
# ## Load ARAUS original csv file
# Obtained directly from ARAUS repository

# %%
responses = pd.read_csv(os.path.join('..','data/main_files','responses.csv'), dtype = {'participant':str})

# %% [markdown]
# ## Maskers as features

# %% [markdown]
# One-hot encoding is a technique used to convert categorical variables into a numerical format that can be used for machine learning algorithms. It is particularly useful when dealing with categorical data that has no inherent order or hierarchy among its categories.
#
# Here's how one-hot encoding works:
#
# 1) Identify Unique Categories:
# First, you identify all the unique categories present in the categorical variable.
#
# 1) Create Binary Columns:
# For each unique category, you create a new binary column. Each binary column corresponds to one unique category.
#
# 1) Assign Values:
# In each binary column, you assign a value of 1 if the observation belongs to the category represented by that column, and 0 otherwise.

# %%
# Extract only the maskers column to generate the one-hot encoding
maskers=responses["masker"]
# From the maskers, extract the type of masker from name (type_number.wav) and then calculate the number of different maskers there is, and assign an order
maskers_type=maskers.str.split("_").str[0]
# Count different maskers
maskers_variety=maskers_type.unique().tolist()
print(maskers_variety)
# Generate the one-hot encoded dataframe
one_hot_encoded=pd.get_dummies(maskers_type, columns=maskers_variety, prefix="masker", dtype=int)
# Finally, concatenate the one-hot-encoded dataframe with the original, and store it as a new csv
responses_with_maskers=pd.concat([responses, one_hot_encoded], axis=1)
print(responses_with_maskers.shape, responses_with_maskers)
# Out:
# ['silence', 'water', 'traffic', 'construction', 'wind', 'bird']
# (27255, 166)        participant  fold_r                          soundscape  \
# 0      ARAUS_00001      -1  R0091_segment_binaural_44100_1.wav
# 1      ARAUS_00001       1  R0079_segment_binaural_44100_1.wav
# 2      ARAUS_00001       1  R0056_segment_binaural_44100_2.wav
# 3      ARAUS_00001       1  R0046_segment_binaural_44100_2.wav
# 4      ARAUS_00001       1  R0092_segment_binaural_44100_1.wav
# ...            ...     ...                                 ...
# 27250  ARAUS_10005       0    R1007_segment_binaural_44100.wav
# 27251  ARAUS_10005       0    R1006_segment_binaural_44100.wav
# 27252  ARAUS_10005       0    R1008_segment_binaural_44100.wav
# 27253  ARAUS_10005       0    R1007_segment_binaural_44100.wav
# 27254  ARAUS_10005      -1  R0091_segment_binaural_44100_1.wav
#
#                        masker  smr  stimulus_index  time_taken  is_attention  \
# 0           silence_00001.wav    0               1      98.328             0
# 1           silence_00001.wav    6               2      77.446             0
# 2             water_00047.wav   -3               3      67.102             0
# 3           traffic_00006.wav    6               4      56.640             0
# 4           traffic_00016.wav   -6               5      51.311             0
# ...                       ...  ...             ...         ...           ...
# 27250       traffic_10001.wav    0              47      43.005             0
# 27251       silence_10001.wav    0              48      34.629             0
# 27252  construction_10001.wav    0              49      31.484             0
# 27253       silence_10001.wav    0              50      35.533             0
# 27254       silence_10001.wav    0              51      37.181             0
#
#        pleasant  eventful  ...  M16000_0_r  M20000_0_r    Leq_L_r    Leq_R_r  \
# 0             5         4  ...   30.380000   14.760000  85.172757  89.614971
# 1             5         2  ...   19.280000   22.170000  68.205627  68.885104
# 2             4         2  ...   50.650000   42.600000  74.789701  75.876626
# 3             5         4  ...   22.140000   15.740000  68.045045  70.963026
# 4             5         4  ...   23.930000   18.430000  77.314983  81.262421
# ...         ...       ...  ...         ...         ...        ...        ...
# 27250         3         4  ...   18.760216   14.550753  65.248280  67.034565
# 27251         2         5  ...   27.016665   31.888105  69.411266  71.075758
# 27252         1         4  ...   24.891455   21.321941  78.966513  78.857925
# 27253         5         2  ...   18.613720   14.485429  64.532490  66.833307
# 27254         2         5  ...   30.380000   14.760000  85.172757  89.614971
#
#        masker_bird  masker_construction  masker_silence  masker_traffic  \
# 0                0                    0               1               0
# 1                0                    0               1               0
# 2                0                    0               0               0
# 3                0                    0               0               1
# 4                0                    0               0               1
# ...            ...                  ...             ...             ...
# 27250            0                    0               0               1
# 27251            0                    0               1               0
# 27252            0                    1               0               0
# 27253            0                    0               1               0
# 27254            0                    0               1               0
#
#        masker_water  masker_wind
# 0                 0            0
# 1                 0            0
# 2                 1            0
# 3                 0            0
# 4                 0            0
# ...             ...          ...
# 27250             0            0
# 27251             0            0
# 27252             0            0
# 27253             0            0
# 27254             0            0
#
# [27255 rows x 166 columns]

# %% [markdown]
# ## Calculate P and E

# %% [markdown]
# Ground truth labels refer to the actual, true, or correct values of the target variable (or labels) in a supervised machine learning task. In other words, these are the known outcomes or responses associated with the input data points. The purpose of ground truth labels is to provide a basis for training and evaluating machine learning models.
#
# <img src="../data/images/PandE_axis.png" alt="Image Description" width="500">
#
# <img src="../data/images/PandE_formulas.png" alt="Image Description" width="800">

# %% [markdown]
# Weights for ISO pleasantness:
# - Pleasant: 1
# - Eventful: 0
# - Chaotic: -sqrt(2)/2
# - Vibrant: sqrt(2)/2
# - Uneventful: 0
# - Calm: sqrt(2)/2
# - Annoying: -1
# - Monotonous: -sqrt(2)/2
#
# Weights for ISO eventfulness:
# - Pleasant: 0
# - Eventful: 1
# - Chaotic: sqrt(2)/2
# - Vibrant: sqrt(2)/2
# - Uneventful: -1
# - Calm: -sqrt(2)/2
# - Annoying: 0
# - Monotonous: -sqrt(2)/2

# %%
# Define attributes to extract from dataframes
attributes = ['pleasant', 'eventful', 'chaotic', 'vibrant', 'uneventful', 'calm', 'annoying', 'monotonous'] 
# Define weights for each attribute in attributes in computation of ISO Pleasantness
ISOPl_weights = [1,0,-np.sqrt(2)/2,np.sqrt(2)/2, 0, np.sqrt(2)/2,-1,-np.sqrt(2)/2] 
# Define weights for each attribute in attributes in computation of ISO Eventfulness
ISOEv_weights = [0,1,np.sqrt(2)/2,np.sqrt(2)/2, -1, -np.sqrt(2)/2,0,-np.sqrt(2)/2] 
# Copy 
responses_with_maskers_PE = responses_with_maskers.copy() 
# These are normalised ISO Pleasantness values (in [-1,1])
responses_with_maskers_PE['P_ground_truth'] = ((responses[attributes] * ISOPl_weights).sum(axis=1)/(4+np.sqrt(32))).values
# These are normalised ISO Eventfulness values (in [-1,1])
responses_with_maskers_PE['E_ground_truth'] = ((responses[attributes] * ISOEv_weights).sum(axis=1)/(4+np.sqrt(32))).values
print(responses_with_maskers_PE.shape, responses_with_maskers_PE)
# Out:
# (27255, 168)        participant  fold_r                          soundscape  \
# 0      ARAUS_00001      -1  R0091_segment_binaural_44100_1.wav
# 1      ARAUS_00001       1  R0079_segment_binaural_44100_1.wav
# 2      ARAUS_00001       1  R0056_segment_binaural_44100_2.wav
# 3      ARAUS_00001       1  R0046_segment_binaural_44100_2.wav
# 4      ARAUS_00001       1  R0092_segment_binaural_44100_1.wav
# ...            ...     ...                                 ...
# 27250  ARAUS_10005       0    R1007_segment_binaural_44100.wav
# 27251  ARAUS_10005       0    R1006_segment_binaural_44100.wav
# 27252  ARAUS_10005       0    R1008_segment_binaural_44100.wav
# 27253  ARAUS_10005       0    R1007_segment_binaural_44100.wav
# 27254  ARAUS_10005      -1  R0091_segment_binaural_44100_1.wav
#
#                        masker  smr  stimulus_index  time_taken  is_attention  \
# 0           silence_00001.wav    0               1      98.328             0
# 1           silence_00001.wav    6               2      77.446             0
# 2             water_00047.wav   -3               3      67.102             0
# 3           traffic_00006.wav    6               4      56.640             0
# 4           traffic_00016.wav   -6               5      51.311             0
# ...                       ...  ...             ...         ...           ...
# 27250       traffic_10001.wav    0              47      43.005             0
# 27251       silence_10001.wav    0              48      34.629             0
# 27252  construction_10001.wav    0              49      31.484             0
# 27253       silence_10001.wav    0              50      35.533             0
# 27254       silence_10001.wav    0              51      37.181             0
#
#        pleasant  eventful  ...    Leq_L_r    Leq_R_r  masker_bird  \
# 0             5         4  ...  85.172757  89.614971            0
# 1             5         2  ...  68.205627  68.885104            0
# 2             4         2  ...  74.789701  75.876626            0
# 3             5         4  ...  68.045045  70.963026            0
# 4             5         4  ...  77.314983  81.262421            0
# ...         ...       ...  ...        ...        ...          ...
# 27250         3         4  ...  65.248280  67.034565            0
# 27251         2         5  ...  69.411266  71.075758            0
# 27252         1         4  ...  78.966513  78.857925            0
# 27253         5         2  ...  64.532490  66.833307            0
# 27254         2         5  ...  85.172757  89.614971            0
#
#        masker_construction  masker_silence  masker_traffic  masker_water  \
# 0                        0               1               0             0
# 1                        0               1               0             0
# 2                        0               0               0             1
# 3                        0               0               1             0
# 4                        0               0               1             0
# ...                    ...             ...             ...           ...
# 27250                    0               0               1             0
# 27251                    0               1               0             0
# 27252                    1               0               0             0
# 27253                    0               1               0             0
# 27254                    0               1               0             0
#
#        masker_wind  P_ground_truth  E_ground_truth
# 0                0    6.035534e-01        0.207107
# 1                0    4.571068e-01       -0.500000
# 2                0    3.535534e-01       -0.250000
# 3                0    4.571068e-01       -0.189340
# 4                0    5.303301e-01       -0.116117
# ...            ...             ...             ...
# 27250            0   -2.299347e-17        0.207107
# 27251            0   -3.964466e-01        0.560660
# 27252            0   -9.267767e-01        0.383883
# 27253            0    6.338835e-01       -0.573223
# 27254            0   -1.338835e-01        0.926777
#
# [27255 rows x 168 columns]

# %% [markdown]
# ## Wav gains for each augmented soundscape

# %% [markdown]
# In ARAUS dataset responses.csv constitute the dataset of +25k augmented soundscapes labeled with psychoacoustic and acoustic parametres. Among these, we can find Leq_r, which constitutes the Leq of channel R for each audio.
#
# In order to generate certain features (the ones we call "ARAUS features" as they aim to replicate the original ARAUS features), it is needed to know the gain or calibration factor that was applyied to the wav files (audios) in order to get the specified Leq. This linear gain (that converts wav to Peak-Pascals), one for each audio, is calculated in this section, and it must be stored.
#
# For the other two set of features (the ones we call "Freesound features" and for the CLAP embedding generation), the audios need to be coherent between each other in terms of energy, meaning that audios that were played with less volume, should have less amplitude than those who were played with higher volume. The factor that gives us this proportionate relation is the gain mentioned in the paragraph above. Therefore, this gain value is also needed for this set of features.
#
# This gain is stored in the new csv, in a new column.

# %%
# Path to folder containing original augmented soundscapes
audioFolderPath="../data/soundscapes_augmented/"
# Prepare output dataframe
columns=responses_with_maskers_PE.columns
newDF=pd.DataFrame(columns=columns)
newDF.insert(loc=6, column='wav_gain', value=None)
# Go over all the audio files in the given directory 
count_clip=0
count_total=0
clipping=[]
for dirpath, dirnames, files in os.walk(audioFolderPath):
    dirpath_split=dirpath.split("soundscapes_augmented")
    # Iterate over all files in the current directory
    files = list(files)
    files.sort()
    for file in files:
        if file.endswith(".mp3") or file.endswith(".wav"):
            print("file ", file)
            print("count total ", count_total)
            # Find the row in responses.csv corresponding to current audio
            audio_path = dirpath + "/"+file
            file_split = file.split("_")
            file_fold = int(file_split[1])
            file_participant = "ARAUS_" + file_split[3]
            file_stimulus = int(file_split[5].split(".")[0])
            audio_info_aug = responses_with_maskers_PE[responses_with_maskers_PE["fold_r"] == file_fold]
            audio_info_aug = audio_info_aug[
                audio_info_aug["stimulus_index"] == file_stimulus
            ]
            audio_info_aug = audio_info_aug[
                audio_info_aug["participant"] == file_participant
            ]
            # Get the original Leq of this audio 
            true_Leq=audio_info_aug["Leq_R_r"].values[0]
            # Load the stereo audio file
            audio_r,fs=load(audio_path, wav_calib=1.0, ch=1)
            audio_l,fs=load(audio_path, wav_calib=1.0, ch=0)
            # Calculate gain from true Leq and "raw" Leq
            rawR_Leq=mean_dB(pressure2leq(audio_r, fs, 0.125))
            gain_dB=true_Leq-rawR_Leq
            gain=10**(gain_dB/20)
            # Add gain info
            audio_info_aug["wav_gain"]=gain
            # Add audio file name
            audio_info_aug["file"]=file.split(".")[0]
            newDF = pd.concat([newDF, audio_info_aug], ignore_index=True)
            # Prepare next iteration
            count_total=count_total+1
# Out:
# file  fold_3_participant_00118_stimulus_37.wav
# count total  0
# file  fold_3_participant_00118_stimulus_38.wav
# count total  1
# file  fold_3_participant_00118_stimulus_39.wav
# count total  2
# file  fold_3_participant_00118_stimulus_40.wav
# count total  3
# file  fold_3_participant_00118_stimulus_41.wav
# count total  4
# /var/folders/87/rtp1hhtx2tgcw5x4mgt4m00m0000gn/T/ipykernel_6656/1421932238.py:53: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   newDF = pd.concat([newDF, audio_info_aug], ignore_index=True)
# file  fold_3_participant_00118_stimulus_42.wav
# count total  5
# file  fold_3_participant_00118_stimulus_43.wav
# count total  6
# file  fold_3_participant_00118_stimulus_44.wav
# count total  7
# file  fold_3_participant_00123_stimulus_02.wav
# count total  8
# file  fold_3_participant_00123_stimulus_03.wav
# count total  9
# file  fold_3_participant_00123_stimulus_04.wav
# count total  10
# file  fold_3_participant_00123_stimulus_05.wav
# count total  11
# file  fold_3_participant_00123_stimulus_06.wav
# count total  12
# file  fold_3_participant_00123_stimulus_07.wav
# count total  13
# file  fold_3_participant_00123_stimulus_08.wav
# count total  14
# file  fold_3_participant_00123_stimulus_09.wav
# count total  15
# file  fold_3_participant_00123_stimulus_10.wav
# count total  16
# file  fold_3_participant_00123_stimulus_11.wav
# count total  17
# file  fold_3_participant_00123_stimulus_12.wav
# count total  18
# file  fold_3_participant_00123_stimulus_13.wav
# count total  19
# file  fold_3_participant_00123_stimulus_14.wav
# count total  20
# file  fold_3_participant_00123_stimulus_15.wav
# count total  21
# file  fold_3_participant_00123_stimulus_17.wav
# count total  22
# file  fold_3_participant_00123_stimulus_18.wav
# count total  23
# file  fold_3_participant_00123_stimulus_19.wav
# count total  24
# file  fold_3_participant_00123_stimulus_20.wav
# count total  25
# file  fold_3_participant_00123_stimulus_21.wav
# count total  26
# file  fold_3_participant_00123_stimulus_22.wav
# count total  27
# file  fold_3_participant_00123_stimulus_23.wav
# count total  28
# file  fold_3_participant_00123_stimulus_24.wav
# count total  29
# file  fold_3_participant_00123_stimulus_25.wav
# count total  30
# file  fold_3_participant_00123_stimulus_26.wav
# count total  31
# file  fold_3_participant_00123_stimulus_27.wav
# count total  32
# file  fold_3_participant_00123_stimulus_28.wav
# count total  33
# file  fold_3_participant_00123_stimulus_29.wav
# count total  34
# file  fold_3_participant_00123_stimulus_30.wav
# count total  35
# file  fold_3_participant_00123_stimulus_31.wav
# count total  36
# file  fold_3_participant_00123_stimulus_32.wav
# count total  37
# file  fold_3_participant_00123_stimulus_33.wav
# count total  38
# file  fold_3_participant_00123_stimulus_34.wav
# count total  39
# file  fold_3_participant_00123_stimulus_35.wav
# count total  40
# file  fold_3_participant_00123_stimulus_36.wav
# count total  41
# file  fold_3_participant_00123_stimulus_37.wav
# count total  42
# file  fold_3_participant_00123_stimulus_38.wav
# count total  43
# file  fold_3_participant_00123_stimulus_39.wav
# count total  44
# file  fold_3_participant_00123_stimulus_40.wav
# count total  45
# file  fold_3_participant_00123_stimulus_41.wav
# count total  46
# file  fold_3_participant_00123_stimulus_42.wav
# count total  47
# file  fold_3_participant_00123_stimulus_43.wav
# count total  48
# file  fold_3_participant_00123_stimulus_44.wav
# count total  49
# file  fold_3_participant_00128_stimulus_02.wav
# count total  50
# file  fold_3_participant_00128_stimulus_03.wav
# count total  51
# file  fold_3_participant_00128_stimulus_04.wav
# count total  52
# file  fold_3_participant_00128_stimulus_05.wav
# count total  53
# file  fold_3_participant_00128_stimulus_06.wav
# count total  54
# file  fold_3_participant_00128_stimulus_07.wav
# count total  55
# file  fold_3_participant_00128_stimulus_08.wav
# count total  56
# file  fold_3_participant_00128_stimulus_09.wav
# count total  57
# file  fold_3_participant_00128_stimulus_10.wav
# count total  58
# file  fold_3_participant_00128_stimulus_11.wav
# count total  59
# file  fold_3_participant_00128_stimulus_12.wav
# count total  60
# file  fold_3_participant_00128_stimulus_13.wav
# count total  61
# file  fold_3_participant_00128_stimulus_14.wav
# count total  62
# file  fold_3_participant_00128_stimulus_15.wav
# count total  63
# file  fold_3_participant_00128_stimulus_16.wav
# count total  64
# file  fold_3_participant_00128_stimulus_17.wav
# count total  65
# file  fold_3_participant_00128_stimulus_18.wav
# count total  66
# file  fold_3_participant_00128_stimulus_19.wav
# count total  67
# file  fold_3_participant_00128_stimulus_20.wav
# count total  68
# file  fold_3_participant_00128_stimulus_21.wav
# count total  69
# file  fold_3_participant_00128_stimulus_22.wav
# count total  70
# file  fold_3_participant_00128_stimulus_24.wav
# count total  71
# file  fold_3_participant_00128_stimulus_25.wav
# count total  72
# file  fold_3_participant_00128_stimulus_26.wav
# count total  73
# file  fold_3_participant_00128_stimulus_27.wav
# count total  74
# file  fold_3_participant_00128_stimulus_28.wav
# count total  75
# file  fold_3_participant_00128_stimulus_29.wav
# count total  76
# file  fold_3_participant_00128_stimulus_30.wav
# count total  77
# file  fold_3_participant_00128_stimulus_31.wav
# count total  78
# file  fold_3_participant_00128_stimulus_32.wav
# count total  79
# file  fold_3_participant_00128_stimulus_33.wav
# count total  80
# file  fold_3_participant_00128_stimulus_34.wav
# count total  81
# file  fold_3_participant_00128_stimulus_35.wav
# count total  82
# file  fold_3_participant_00128_stimulus_36.wav
# count total  83
# file  fold_3_participant_00128_stimulus_37.wav
# count total  84
# file  fold_3_participant_00128_stimulus_38.wav
# count total  85
# file  fold_3_participant_00128_stimulus_39.wav
# count total  86
# file  fold_3_participant_00128_stimulus_40.wav
# count total  87
# file  fold_3_participant_00128_stimulus_41.wav
# count total  88
# file  fold_3_participant_00128_stimulus_42.wav
# count total  89
# file  fold_3_participant_00128_stimulus_43.wav
# count total  90
# file  fold_3_participant_00128_stimulus_44.wav
# count total  91
# file  fold_3_participant_00133_stimulus_02.wav
# count total  92
# file  fold_3_participant_00133_stimulus_03.wav
# count total  93
# file  fold_3_participant_00133_stimulus_04.wav
# count total  94
# file  fold_3_participant_00133_stimulus_05.wav
# count total  95
# file  fold_3_participant_00133_stimulus_06.wav
# count total  96
# file  fold_3_participant_00133_stimulus_07.wav
# count total  97
# file  fold_3_participant_00133_stimulus_08.wav
# count total  98
# file  fold_3_participant_00133_stimulus_09.wav
# count total  99
# file  fold_3_participant_00133_stimulus_10.wav
# count total  100
# file  fold_3_participant_00133_stimulus_11.wav
# count total  101
# file  fold_3_participant_00133_stimulus_12.wav
# count total  102
# file  fold_3_participant_00133_stimulus_13.wav
# count total  103
# file  fold_3_participant_00133_stimulus_14.wav
# count total  104
# file  fold_3_participant_00133_stimulus_15.wav
# count total  105
# file  fold_3_participant_00133_stimulus_16.wav
# count total  106
# file  fold_3_participant_00133_stimulus_18.wav
# count total  107
# file  fold_3_participant_00133_stimulus_19.wav
# count total  108
# file  fold_3_participant_00133_stimulus_20.wav
# count total  109
# file  fold_3_participant_00133_stimulus_21.wav
# count total  110
# file  fold_3_participant_00133_stimulus_22.wav
# count total  111
# file  fold_3_participant_00133_stimulus_23.wav
# count total  112
# file  fold_3_participant_00133_stimulus_24.wav
# count total  113
# file  fold_3_participant_00133_stimulus_25.wav
# count total  114
# file  fold_3_participant_00133_stimulus_26.wav
# count total  115
# file  fold_3_participant_00133_stimulus_27.wav
# count total  116
# file  fold_3_participant_00133_stimulus_28.wav
# count total  117
# file  fold_3_participant_00133_stimulus_29.wav
# count total  118
# file  fold_3_participant_00133_stimulus_30.wav
# count total  119
# file  fold_3_participant_00133_stimulus_31.wav
# count total  120
# file  fold_3_participant_00133_stimulus_32.wav
# count total  121
# file  fold_3_participant_00133_stimulus_33.wav
# count total  122
# file  fold_3_participant_00133_stimulus_34.wav
# count total  123
# file  fold_3_participant_00133_stimulus_35.wav
# count total  124
# file  fold_3_participant_00133_stimulus_36.wav
# count total  125
# file  fold_3_participant_00133_stimulus_37.wav
# count total  126
# file  fold_3_participant_00133_stimulus_38.wav
# count total  127
# file  fold_3_participant_00133_stimulus_39.wav
# count total  128
# file  fold_3_participant_00133_stimulus_40.wav
# count total  129
# file  fold_3_participant_00133_stimulus_41.wav
# count total  130
# file  fold_3_participant_00133_stimulus_42.wav
# count total  131
# file  fold_3_participant_00133_stimulus_43.wav
# count total  132
# file  fold_3_participant_00133_stimulus_44.wav
# count total  133
# file  fold_3_participant_00138_stimulus_02.wav
# count total  134
# file  fold_3_participant_00138_stimulus_03.wav
# count total  135
# file  fold_3_participant_00138_stimulus_04.wav
# count total  136
# file  fold_3_participant_00138_stimulus_05.wav
# count total  137
# file  fold_3_participant_00138_stimulus_06.wav
# count total  138
# file  fold_3_participant_00138_stimulus_07.wav
# count total  139
# file  fold_3_participant_00138_stimulus_08.wav
# count total  140
# file  fold_3_participant_00138_stimulus_09.wav
# count total  141
# file  fold_3_participant_00138_stimulus_10.wav
# count total  142
# file  fold_3_participant_00138_stimulus_11.wav
# count total  143
# file  fold_3_participant_00138_stimulus_12.wav
# count total  144
# file  fold_3_participant_00138_stimulus_13.wav
# count total  145
# file  fold_3_participant_00138_stimulus_14.wav
# count total  146
# file  fold_3_participant_00138_stimulus_15.wav
# count total  147
# file  fold_3_participant_00138_stimulus_16.wav
# count total  148
# file  fold_3_participant_00138_stimulus_17.wav
# count total  149
# file  fold_3_participant_00138_stimulus_18.wav
# count total  150
# file  fold_3_participant_00138_stimulus_19.wav
# count total  151
# file  fold_3_participant_00138_stimulus_20.wav
# count total  152
# file  fold_3_participant_00138_stimulus_21.wav
# count total  153
# file  fold_3_participant_00138_stimulus_22.wav
# count total  154
# file  fold_3_participant_00138_stimulus_24.wav
# count total  155
# file  fold_3_participant_00138_stimulus_25.wav
# count total  156
# file  fold_3_participant_00138_stimulus_26.wav
# count total  157
# file  fold_3_participant_00138_stimulus_27.wav
# count total  158
# file  fold_3_participant_00138_stimulus_28.wav
# count total  159
# file  fold_3_participant_00138_stimulus_29.wav
# count total  160
# file  fold_3_participant_00138_stimulus_30.wav
# count total  161
# file  fold_3_participant_00138_stimulus_31.wav
# count total  162
# file  fold_3_participant_00138_stimulus_32.wav
# count total  163
# file  fold_3_participant_00138_stimulus_33.wav
# count total  164
# file  fold_3_participant_00138_stimulus_34.wav
# count total  165
# file  fold_3_participant_00138_stimulus_35.wav
# count total  166
# file  fold_3_participant_00138_stimulus_36.wav
# count total  167
# file  fold_3_participant_00138_stimulus_37.wav
# count total  168
# file  fold_3_participant_00138_stimulus_38.wav
# count total  169
# file  fold_3_participant_00138_stimulus_39.wav
# count total  170
# file  fold_3_participant_00138_stimulus_40.wav
# count total  171
# file  fold_3_participant_00138_stimulus_41.wav
# count total  172
# file  fold_3_participant_00138_stimulus_42.wav
# count total  173
# file  fold_3_participant_00138_stimulus_43.wav
# count total  174
# file  fold_3_participant_00138_stimulus_44.wav
# count total  175
# file  fold_3_participant_00143_stimulus_02.wav
# count total  176
# file  fold_3_participant_00143_stimulus_03.wav
# count total  177
# file  fold_3_participant_00143_stimulus_04.wav
# count total  178
# file  fold_3_participant_00143_stimulus_05.wav
# count total  179
# file  fold_3_participant_00143_stimulus_06.wav
# count total  180
# file  fold_3_participant_00143_stimulus_07.wav
# count total  181
# file  fold_3_participant_00143_stimulus_08.wav
# count total  182
# file  fold_3_participant_00143_stimulus_09.wav
# count total  183
# file  fold_3_participant_00143_stimulus_10.wav
# count total  184
# file  fold_3_participant_00143_stimulus_11.wav
# count total  185
# file  fold_3_participant_00143_stimulus_12.wav
# count total  186
# file  fold_3_participant_00143_stimulus_13.wav
# count total  187
# file  fold_3_participant_00143_stimulus_14.wav
# count total  188
# file  fold_3_participant_00143_stimulus_15.wav
# count total  189
# file  fold_3_participant_00143_stimulus_16.wav
# count total  190
# file  fold_3_participant_00143_stimulus_17.wav
# count total  191
# file  fold_3_participant_00143_stimulus_19.wav
# count total  192
# file  fold_3_participant_00143_stimulus_20.wav
# count total  193
# file  fold_3_participant_00143_stimulus_21.wav
# count total  194
# file  fold_3_participant_00143_stimulus_22.wav
# count total  195
# file  fold_3_participant_00143_stimulus_23.wav
# count total  196
# file  fold_3_participant_00143_stimulus_24.wav
# count total  197
# file  fold_3_participant_00143_stimulus_25.wav
# count total  198
# file  fold_3_participant_00143_stimulus_26.wav
# count total  199
# file  fold_3_participant_00143_stimulus_27.wav
# count total  200
# file  fold_3_participant_00143_stimulus_28.wav
# count total  201
# file  fold_3_participant_00143_stimulus_29.wav
# count total  202
# file  fold_3_participant_00143_stimulus_30.wav
# count total  203
# file  fold_3_participant_00143_stimulus_31.wav
# count total  204
# file  fold_3_participant_00143_stimulus_32.wav
# count total  205
# file  fold_3_participant_00143_stimulus_33.wav
# count total  206
# file  fold_3_participant_00143_stimulus_34.wav
# count total  207
# file  fold_3_participant_00143_stimulus_35.wav
# count total  208
# file  fold_3_participant_00143_stimulus_36.wav
# count total  209
# file  fold_3_participant_00143_stimulus_37.wav
# count total  210
# file  fold_3_participant_00143_stimulus_38.wav
# count total  211
# file  fold_3_participant_00143_stimulus_39.wav
# count total  212
# file  fold_3_participant_00143_stimulus_40.wav
# count total  213
# file  fold_3_participant_00143_stimulus_41.wav
# count total  214
# file  fold_3_participant_00143_stimulus_42.wav
# count total  215
# file  fold_3_participant_00143_stimulus_43.wav
# count total  216
# file  fold_3_participant_00143_stimulus_44.wav
# count total  217
# file  fold_3_participant_00148_stimulus_02.wav
# count total  218
# file  fold_3_participant_00148_stimulus_03.wav
# count total  219
# file  fold_3_participant_00148_stimulus_04.wav
# count total  220
# file  fold_3_participant_00148_stimulus_05.wav
# count total  221
# file  fold_3_participant_00148_stimulus_06.wav
# count total  222
# file  fold_3_participant_00148_stimulus_07.wav
# count total  223
# file  fold_3_participant_00148_stimulus_08.wav
# count total  224
# file  fold_3_participant_00148_stimulus_09.wav
# count total  225
# file  fold_3_participant_00148_stimulus_10.wav
# count total  226
# file  fold_3_participant_00148_stimulus_11.wav
# count total  227
# file  fold_3_participant_00148_stimulus_12.wav
# count total  228
# file  fold_3_participant_00148_stimulus_13.wav
# count total  229
# file  fold_3_participant_00148_stimulus_14.wav
# count total  230
# file  fold_3_participant_00148_stimulus_15.wav
# count total  231
# file  fold_3_participant_00148_stimulus_16.wav
# count total  232
# file  fold_3_participant_00148_stimulus_17.wav
# count total  233
# file  fold_3_participant_00148_stimulus_18.wav
# count total  234
# file  fold_3_participant_00148_stimulus_19.wav
# count total  235
# file  fold_3_participant_00148_stimulus_20.wav
# count total  236
# file  fold_3_participant_00148_stimulus_21.wav
# count total  237
# file  fold_3_participant_00148_stimulus_22.wav
# count total  238
# file  fold_3_participant_00148_stimulus_24.wav
# count total  239
# file  fold_3_participant_00148_stimulus_25.wav
# count total  240
# file  fold_3_participant_00148_stimulus_26.wav
# count total  241
# file  fold_3_participant_00148_stimulus_27.wav
# count total  242
# file  fold_3_participant_00148_stimulus_28.wav
# count total  243
# file  fold_3_participant_00148_stimulus_29.wav
# count total  244
# file  fold_3_participant_00148_stimulus_30.wav
# count total  245
# file  fold_3_participant_00148_stimulus_31.wav
# count total  246
# file  fold_3_participant_00148_stimulus_32.wav
# count total  247
# file  fold_3_participant_00148_stimulus_33.wav
# count total  248
# file  fold_3_participant_00148_stimulus_34.wav
# count total  249
# file  fold_3_participant_00148_stimulus_35.wav
# count total  250
# file  fold_3_participant_00148_stimulus_36.wav
# count total  251
# file  fold_3_participant_00148_stimulus_37.wav
# count total  252
# file  fold_3_participant_00148_stimulus_38.wav
# count total  253
# file  fold_3_participant_00148_stimulus_39.wav
# count total  254
# file  fold_3_participant_00148_stimulus_40.wav
# count total  255
# file  fold_3_participant_00148_stimulus_41.wav
# count total  256
# file  fold_3_participant_00148_stimulus_42.wav
# count total  257
# file  fold_3_participant_00148_stimulus_43.wav
# count total  258
# file  fold_3_participant_00148_stimulus_44.wav
# count total  259
# file  fold_3_participant_00153_stimulus_02.wav
# count total  260
# file  fold_3_participant_00153_stimulus_03.wav
# count total  261
# file  fold_3_participant_00153_stimulus_04.wav
# count total  262
# file  fold_3_participant_00153_stimulus_05.wav
# count total  263
# file  fold_3_participant_00153_stimulus_06.wav
# count total  264
# file  fold_3_participant_00153_stimulus_07.wav
# count total  265
# file  fold_3_participant_00153_stimulus_08.wav
# count total  266
# file  fold_3_participant_00153_stimulus_09.wav
# count total  267
# file  fold_3_participant_00153_stimulus_10.wav
# count total  268
# file  fold_3_participant_00153_stimulus_11.wav
# count total  269
# file  fold_3_participant_00153_stimulus_12.wav
# count total  270
# file  fold_3_participant_00153_stimulus_13.wav
# count total  271
# file  fold_3_participant_00153_stimulus_14.wav
# count total  272
# file  fold_3_participant_00153_stimulus_15.wav
# count total  273
# file  fold_3_participant_00153_stimulus_16.wav
# count total  274
# file  fold_3_participant_00153_stimulus_17.wav
# count total  275
# file  fold_3_participant_00153_stimulus_18.wav
# count total  276
# file  fold_3_participant_00153_stimulus_19.wav
# count total  277
# file  fold_3_participant_00153_stimulus_21.wav
# count total  278
# file  fold_3_participant_00153_stimulus_22.wav
# count total  279
# file  fold_3_participant_00153_stimulus_23.wav
# count total  280
# file  fold_3_participant_00153_stimulus_24.wav
# count total  281
# file  fold_3_participant_00153_stimulus_25.wav
# count total  282
# file  fold_3_participant_00153_stimulus_26.wav
# count total  283
# file  fold_3_participant_00153_stimulus_27.wav
# count total  284
# file  fold_3_participant_00153_stimulus_28.wav
# count total  285
# file  fold_3_participant_00153_stimulus_29.wav
# count total  286
# file  fold_3_participant_00153_stimulus_30.wav
# count total  287
# file  fold_3_participant_00153_stimulus_31.wav
# count total  288
# file  fold_3_participant_00153_stimulus_32.wav
# count total  289
# file  fold_3_participant_00153_stimulus_33.wav
# count total  290
# file  fold_3_participant_00153_stimulus_34.wav
# count total  291
# file  fold_3_participant_00153_stimulus_35.wav
# count total  292
# file  fold_3_participant_00153_stimulus_36.wav
# count total  293
# file  fold_3_participant_00153_stimulus_37.wav
# count total  294
# file  fold_3_participant_00153_stimulus_38.wav
# count total  295
# file  fold_3_participant_00153_stimulus_39.wav
# count total  296
# file  fold_3_participant_00153_stimulus_40.wav
# count total  297
# file  fold_3_participant_00153_stimulus_41.wav
# count total  298
# file  fold_3_participant_00153_stimulus_42.wav
# count total  299
# file  fold_3_participant_00153_stimulus_43.wav
# count total  300
# file  fold_3_participant_00153_stimulus_44.wav
# count total  301
# file  fold_3_participant_00158_stimulus_02.wav
# count total  302
# file  fold_3_participant_00158_stimulus_03.wav
# count total  303
# file  fold_3_participant_00158_stimulus_04.wav
# count total  304
# file  fold_3_participant_00158_stimulus_05.wav
# count total  305
# file  fold_3_participant_00158_stimulus_06.wav
# count total  306
# file  fold_3_participant_00158_stimulus_07.wav
# count total  307
# file  fold_3_participant_00158_stimulus_08.wav
# count total  308
# file  fold_3_participant_00158_stimulus_09.wav
# count total  309
# file  fold_3_participant_00158_stimulus_10.wav
# count total  310
# file  fold_3_participant_00158_stimulus_11.wav
# count total  311
# file  fold_3_participant_00158_stimulus_12.wav
# count total  312
# file  fold_3_participant_00158_stimulus_13.wav
# count total  313
# file  fold_3_participant_00158_stimulus_14.wav
# count total  314
# file  fold_3_participant_00158_stimulus_15.wav
# count total  315
# file  fold_3_participant_00158_stimulus_16.wav
# count total  316
# file  fold_3_participant_00158_stimulus_17.wav
# count total  317
# file  fold_3_participant_00158_stimulus_18.wav
# count total  318
# file  fold_3_participant_00158_stimulus_19.wav
# count total  319
# file  fold_3_participant_00158_stimulus_20.wav
# count total  320
# file  fold_3_participant_00158_stimulus_21.wav
# count total  321
# file  fold_3_participant_00158_stimulus_22.wav
# count total  322
# file  fold_3_participant_00158_stimulus_24.wav
# count total  323
# file  fold_3_participant_00158_stimulus_25.wav
# count total  324
# file  fold_3_participant_00158_stimulus_26.wav
# count total  325
# file  fold_3_participant_00158_stimulus_27.wav
# count total  326
# file  fold_3_participant_00158_stimulus_28.wav
# count total  327
# file  fold_3_participant_00158_stimulus_29.wav
# count total  328
# file  fold_3_participant_00158_stimulus_30.wav
# count total  329
# file  fold_3_participant_00158_stimulus_31.wav
# count total  330
# file  fold_3_participant_00158_stimulus_32.wav
# count total  331
# file  fold_3_participant_00158_stimulus_33.wav
# count total  332
# file  fold_3_participant_00158_stimulus_34.wav
# count total  333
# file  fold_3_participant_00158_stimulus_35.wav
# count total  334
# file  fold_3_participant_00158_stimulus_36.wav
# count total  335
# file  fold_3_participant_00158_stimulus_37.wav
# count total  336
# file  fold_3_participant_00158_stimulus_38.wav
# count total  337
# file  fold_3_participant_00158_stimulus_39.wav
# count total  338
# file  fold_3_participant_00158_stimulus_40.wav
# count total  339
# file  fold_3_participant_00158_stimulus_41.wav
# count total  340
# file  fold_3_participant_00158_stimulus_42.wav
# count total  341
# file  fold_3_participant_00158_stimulus_43.wav
# count total  342
# file  fold_3_participant_00158_stimulus_44.wav
# count total  343
# file  fold_3_participant_00163_stimulus_02.wav
# count total  344
# file  fold_3_participant_00163_stimulus_03.wav
# count total  345
# file  fold_3_participant_00163_stimulus_04.wav
# count total  346
# file  fold_3_participant_00163_stimulus_05.wav
# count total  347
# file  fold_3_participant_00163_stimulus_06.wav
# count total  348
# file  fold_3_participant_00163_stimulus_07.wav
# count total  349
# file  fold_3_participant_00163_stimulus_08.wav
# count total  350
# file  fold_3_participant_00163_stimulus_09.wav
# count total  351
# file  fold_3_participant_00163_stimulus_10.wav
# count total  352
# file  fold_3_participant_00163_stimulus_11.wav
# count total  353
# file  fold_3_participant_00163_stimulus_12.wav
# count total  354
# file  fold_3_participant_00163_stimulus_13.wav
# count total  355
# file  fold_3_participant_00163_stimulus_14.wav
# count total  356
# file  fold_3_participant_00163_stimulus_15.wav
# count total  357
# file  fold_3_participant_00163_stimulus_16.wav
# count total  358
# file  fold_3_participant_00163_stimulus_17.wav
# count total  359
# file  fold_3_participant_00163_stimulus_19.wav
# count total  360
# file  fold_3_participant_00163_stimulus_20.wav
# count total  361
# file  fold_3_participant_00163_stimulus_21.wav
# count total  362
# file  fold_3_participant_00163_stimulus_22.wav
# count total  363
# file  fold_3_participant_00163_stimulus_23.wav
# count total  364
# file  fold_3_participant_00163_stimulus_24.wav
# count total  365
# file  fold_3_participant_00163_stimulus_25.wav
# count total  366
# file  fold_3_participant_00163_stimulus_26.wav
# count total  367
# file  fold_3_participant_00163_stimulus_27.wav
# count total  368
# file  fold_3_participant_00163_stimulus_28.wav
# count total  369
# file  fold_3_participant_00163_stimulus_29.wav
# count total  370
# file  fold_3_participant_00163_stimulus_30.wav
# count total  371
# file  fold_3_participant_00163_stimulus_31.wav
# count total  372
# file  fold_3_participant_00163_stimulus_32.wav
# count total  373
# file  fold_3_participant_00163_stimulus_33.wav
# count total  374
# file  fold_3_participant_00163_stimulus_34.wav
# count total  375
# file  fold_3_participant_00163_stimulus_35.wav
# count total  376
# file  fold_3_participant_00163_stimulus_36.wav
# count total  377
# file  fold_3_participant_00163_stimulus_37.wav
# count total  378
# file  fold_3_participant_00163_stimulus_38.wav
# count total  379
# file  fold_3_participant_00163_stimulus_39.wav
# count total  380
# file  fold_3_participant_00163_stimulus_40.wav
# count total  381
# file  fold_3_participant_00163_stimulus_41.wav
# count total  382
# file  fold_3_participant_00163_stimulus_42.wav
# count total  383
# file  fold_3_participant_00163_stimulus_43.wav
# count total  384
# file  fold_3_participant_00163_stimulus_44.wav
# count total  385
# file  fold_3_participant_00168_stimulus_02.wav
# count total  386
# file  fold_3_participant_00168_stimulus_03.wav
# count total  387
# file  fold_3_participant_00168_stimulus_04.wav
# count total  388
# file  fold_3_participant_00168_stimulus_05.wav
# count total  389
# file  fold_3_participant_00168_stimulus_06.wav
# count total  390
# file  fold_3_participant_00168_stimulus_07.wav
# count total  391
# file  fold_3_participant_00168_stimulus_08.wav
# count total  392
# file  fold_3_participant_00168_stimulus_09.wav
# count total  393
# file  fold_3_participant_00168_stimulus_10.wav
# count total  394
# file  fold_3_participant_00168_stimulus_11.wav
# count total  395
# file  fold_3_participant_00168_stimulus_12.wav
# count total  396
# file  fold_3_participant_00168_stimulus_13.wav
# count total  397
# file  fold_3_participant_00168_stimulus_14.wav
# count total  398
# file  fold_3_participant_00168_stimulus_15.wav
# count total  399
# file  fold_3_participant_00168_stimulus_16.wav
# count total  400
# file  fold_3_participant_00168_stimulus_18.wav
# count total  401
# file  fold_3_participant_00168_stimulus_19.wav
# count total  402
# file  fold_3_participant_00168_stimulus_20.wav
# count total  403
# file  fold_3_participant_00168_stimulus_21.wav
# count total  404
# file  fold_3_participant_00168_stimulus_22.wav
# count total  405
# file  fold_3_participant_00168_stimulus_23.wav
# count total  406
# file  fold_3_participant_00168_stimulus_24.wav
# count total  407
# file  fold_3_participant_00168_stimulus_25.wav
# count total  408
# file  fold_3_participant_00168_stimulus_26.wav
# count total  409
# file  fold_3_participant_00168_stimulus_27.wav
# count total  410
# file  fold_3_participant_00168_stimulus_28.wav
# count total  411
# file  fold_3_participant_00168_stimulus_29.wav
# count total  412
# file  fold_3_participant_00168_stimulus_30.wav
# count total  413
# file  fold_3_participant_00168_stimulus_31.wav
# count total  414
# file  fold_3_participant_00168_stimulus_32.wav
# count total  415
# file  fold_3_participant_00168_stimulus_33.wav
# count total  416
# file  fold_3_participant_00168_stimulus_34.wav
# count total  417
# file  fold_3_participant_00168_stimulus_35.wav
# count total  418
# file  fold_3_participant_00168_stimulus_36.wav
# count total  419
# file  fold_3_participant_00168_stimulus_37.wav
# count total  420
# file  fold_3_participant_00168_stimulus_38.wav
# count total  421
# file  fold_3_participant_00168_stimulus_39.wav
# count total  422
# file  fold_3_participant_00168_stimulus_40.wav
# count total  423
# file  fold_3_participant_00168_stimulus_41.wav
# count total  424
# file  fold_3_participant_00168_stimulus_42.wav
# count total  425
# file  fold_3_participant_00168_stimulus_43.wav
# count total  426
# file  fold_3_participant_00168_stimulus_44.wav
# count total  427
# file  fold_3_participant_00173_stimulus_02.wav
# count total  428
# file  fold_3_participant_00173_stimulus_03.wav
# count total  429
# file  fold_3_participant_00173_stimulus_04.wav
# count total  430
# file  fold_3_participant_00173_stimulus_05.wav
# count total  431
# file  fold_3_participant_00173_stimulus_06.wav
# count total  432
# file  fold_3_participant_00173_stimulus_07.wav
# count total  433
# file  fold_3_participant_00173_stimulus_08.wav
# count total  434
# file  fold_3_participant_00173_stimulus_09.wav
# count total  435
# file  fold_3_participant_00173_stimulus_10.wav
# count total  436
# file  fold_3_participant_00173_stimulus_11.wav
# count total  437
# file  fold_3_participant_00173_stimulus_12.wav
# count total  438
# file  fold_3_participant_00173_stimulus_13.wav
# count total  439
# file  fold_3_participant_00173_stimulus_14.wav
# count total  440
# file  fold_3_participant_00173_stimulus_15.wav
# count total  441
# file  fold_3_participant_00173_stimulus_16.wav
# count total  442
# file  fold_3_participant_00173_stimulus_17.wav
# count total  443
# file  fold_3_participant_00173_stimulus_18.wav
# count total  444
# file  fold_3_participant_00173_stimulus_19.wav
# count total  445
# file  fold_3_participant_00173_stimulus_21.wav
# count total  446
# file  fold_3_participant_00173_stimulus_22.wav
# count total  447
# file  fold_3_participant_00173_stimulus_23.wav
# count total  448
# file  fold_3_participant_00173_stimulus_24.wav
# count total  449
# file  fold_3_participant_00173_stimulus_25.wav
# count total  450
# file  fold_3_participant_00173_stimulus_26.wav
# count total  451
# file  fold_3_participant_00173_stimulus_27.wav
# count total  452
# file  fold_3_participant_00173_stimulus_28.wav
# count total  453
# file  fold_3_participant_00173_stimulus_29.wav
# count total  454
# file  fold_3_participant_00173_stimulus_30.wav
# count total  455
# file  fold_3_participant_00173_stimulus_31.wav
# count total  456
# file  fold_3_participant_00173_stimulus_32.wav
# count total  457
# file  fold_3_participant_00173_stimulus_33.wav
# count total  458
# file  fold_3_participant_00173_stimulus_34.wav
# count total  459
# file  fold_3_participant_00173_stimulus_35.wav
# count total  460
# file  fold_3_participant_00173_stimulus_36.wav
# count total  461
# file  fold_3_participant_00173_stimulus_37.wav
# count total  462
# file  fold_3_participant_00173_stimulus_38.wav
# count total  463
# file  fold_3_participant_00173_stimulus_39.wav
# count total  464
# file  fold_3_participant_00173_stimulus_40.wav
# count total  465
# file  fold_3_participant_00173_stimulus_41.wav
# count total  466
# file  fold_3_participant_00173_stimulus_42.wav
# count total  467
# file  fold_3_participant_00173_stimulus_43.wav
# count total  468
# file  fold_3_participant_00173_stimulus_44.wav
# count total  469
# file  fold_3_participant_00178_stimulus_02.wav
# count total  470
# file  fold_3_participant_00178_stimulus_03.wav
# count total  471
# file  fold_3_participant_00178_stimulus_04.wav
# count total  472
# file  fold_3_participant_00178_stimulus_05.wav
# count total  473
# file  fold_3_participant_00178_stimulus_06.wav
# count total  474
# file  fold_3_participant_00178_stimulus_07.wav
# count total  475
# file  fold_3_participant_00178_stimulus_08.wav
# count total  476
# file  fold_3_participant_00178_stimulus_09.wav
# count total  477
# file  fold_3_participant_00178_stimulus_10.wav
# count total  478
# file  fold_3_participant_00178_stimulus_11.wav
# count total  479
# file  fold_3_participant_00178_stimulus_12.wav
# count total  480
# file  fold_3_participant_00178_stimulus_13.wav
# count total  481
# file  fold_3_participant_00178_stimulus_14.wav
# count total  482
# file  fold_3_participant_00178_stimulus_15.wav
# count total  483
# file  fold_3_participant_00178_stimulus_16.wav
# count total  484
# file  fold_3_participant_00178_stimulus_17.wav
# count total  485
# file  fold_3_participant_00178_stimulus_18.wav
# count total  486
# file  fold_3_participant_00178_stimulus_19.wav
# count total  487
# file  fold_3_participant_00178_stimulus_20.wav
# count total  488
# file  fold_3_participant_00178_stimulus_21.wav
# count total  489
# file  fold_3_participant_00178_stimulus_22.wav
# count total  490
# file  fold_3_participant_00178_stimulus_23.wav
# count total  491
# file  fold_3_participant_00178_stimulus_24.wav
# count total  492
# file  fold_3_participant_00178_stimulus_26.wav
# count total  493
# file  fold_3_participant_00178_stimulus_27.wav
# count total  494
# file  fold_3_participant_00178_stimulus_28.wav
# count total  495
# file  fold_3_participant_00178_stimulus_29.wav
# count total  496
# file  fold_3_participant_00178_stimulus_30.wav
# count total  497
# file  fold_3_participant_00178_stimulus_31.wav
# count total  498
# file  fold_3_participant_00178_stimulus_32.wav
# count total  499
# file  fold_3_participant_00178_stimulus_33.wav
# count total  500
# file  fold_3_participant_00178_stimulus_34.wav
# count total  501
# file  fold_3_participant_00178_stimulus_35.wav
# count total  502
# file  fold_3_participant_00178_stimulus_36.wav
# count total  503
# file  fold_3_participant_00178_stimulus_37.wav
# count total  504
# file  fold_3_participant_00178_stimulus_38.wav
# count total  505
# file  fold_3_participant_00178_stimulus_39.wav
# count total  506
# file  fold_3_participant_00178_stimulus_40.wav
# count total  507
# file  fold_3_participant_00178_stimulus_41.wav
# count total  508
# file  fold_3_participant_00178_stimulus_42.wav
# count total  509
# file  fold_3_participant_00178_stimulus_43.wav
# count total  510
# file  fold_3_participant_00178_stimulus_44.wav
# count total  511
# file  fold_3_participant_00183_stimulus_02.wav
# count total  512
# file  fold_3_participant_00183_stimulus_03.wav
# count total  513
# file  fold_3_participant_00183_stimulus_04.wav
# count total  514
# file  fold_3_participant_00183_stimulus_05.wav
# count total  515
# file  fold_3_participant_00183_stimulus_06.wav
# count total  516
# file  fold_3_participant_00183_stimulus_07.wav
# count total  517
# file  fold_3_participant_00183_stimulus_08.wav
# count total  518
# file  fold_3_participant_00183_stimulus_09.wav
# count total  519
# file  fold_3_participant_00183_stimulus_10.wav
# count total  520
# file  fold_3_participant_00183_stimulus_11.wav
# count total  521
# file  fold_3_participant_00183_stimulus_12.wav
# count total  522
# file  fold_3_participant_00183_stimulus_13.wav
# count total  523
# file  fold_3_participant_00183_stimulus_14.wav
# count total  524
# file  fold_3_participant_00183_stimulus_15.wav
# count total  525
# file  fold_3_participant_00183_stimulus_16.wav
# count total  526
# file  fold_3_participant_00183_stimulus_17.wav
# count total  527
# file  fold_3_participant_00183_stimulus_18.wav
# count total  528
# file  fold_3_participant_00183_stimulus_19.wav
# count total  529
# file  fold_3_participant_00183_stimulus_20.wav
# count total  530
# file  fold_3_participant_00183_stimulus_21.wav
# count total  531
# file  fold_3_participant_00183_stimulus_22.wav
# count total  532
# file  fold_3_participant_00183_stimulus_23.wav
# count total  533
# file  fold_3_participant_00183_stimulus_24.wav
# count total  534
# file  fold_3_participant_00183_stimulus_25.wav
# count total  535
# file  fold_3_participant_00183_stimulus_27.wav
# count total  536
# file  fold_3_participant_00183_stimulus_28.wav
# count total  537
# file  fold_3_participant_00183_stimulus_29.wav
# count total  538
# file  fold_3_participant_00183_stimulus_30.wav
# count total  539
# file  fold_3_participant_00183_stimulus_31.wav
# count total  540
# file  fold_3_participant_00183_stimulus_32.wav
# count total  541
# file  fold_3_participant_00183_stimulus_33.wav
# count total  542
# file  fold_3_participant_00183_stimulus_34.wav
# count total  543
# file  fold_3_participant_00183_stimulus_35.wav
# count total  544
# file  fold_3_participant_00183_stimulus_36.wav
# count total  545
# file  fold_3_participant_00183_stimulus_37.wav
# count total  546
# file  fold_3_participant_00183_stimulus_38.wav
# count total  547
# file  fold_3_participant_00183_stimulus_39.wav
# count total  548
# file  fold_3_participant_00183_stimulus_40.wav
# count total  549
# file  fold_3_participant_00183_stimulus_41.wav
# count total  550
# file  fold_3_participant_00183_stimulus_42.wav
# count total  551
# file  fold_3_participant_00183_stimulus_43.wav
# count total  552
# file  fold_3_participant_00183_stimulus_44.wav
# count total  553
# file  fold_3_participant_00188_stimulus_02.wav
# count total  554
# file  fold_3_participant_00188_stimulus_03.wav
# count total  555
# file  fold_3_participant_00188_stimulus_04.wav
# count total  556
# file  fold_3_participant_00188_stimulus_05.wav
# count total  557
# file  fold_3_participant_00188_stimulus_06.wav
# count total  558
# file  fold_3_participant_00188_stimulus_07.wav
# count total  559
# file  fold_3_participant_00188_stimulus_08.wav
# count total  560
# file  fold_3_participant_00188_stimulus_09.wav
# count total  561
# file  fold_3_participant_00188_stimulus_10.wav
# count total  562
# file  fold_3_participant_00188_stimulus_11.wav
# count total  563
# file  fold_3_participant_00188_stimulus_12.wav
# count total  564
# file  fold_3_participant_00188_stimulus_13.wav
# count total  565
# file  fold_3_participant_00188_stimulus_14.wav
# count total  566
# file  fold_3_participant_00188_stimulus_15.wav
# count total  567
# file  fold_3_participant_00188_stimulus_16.wav
# count total  568
# file  fold_3_participant_00188_stimulus_17.wav
# count total  569
# file  fold_3_participant_00188_stimulus_18.wav
# count total  570
# file  fold_3_participant_00188_stimulus_19.wav
# count total  571
# file  fold_3_participant_00188_stimulus_20.wav
# count total  572
# file  fold_3_participant_00188_stimulus_21.wav
# count total  573
# file  fold_3_participant_00188_stimulus_22.wav
# count total  574
# file  fold_3_participant_00188_stimulus_24.wav
# count total  575
# file  fold_3_participant_00188_stimulus_25.wav
# count total  576
# file  fold_3_participant_00188_stimulus_26.wav
# count total  577
# file  fold_3_participant_00188_stimulus_27.wav
# count total  578
# file  fold_3_participant_00188_stimulus_28.wav
# count total  579
# file  fold_3_participant_00188_stimulus_29.wav
# count total  580
# file  fold_3_participant_00188_stimulus_30.wav
# count total  581
# file  fold_3_participant_00188_stimulus_31.wav
# count total  582
# file  fold_3_participant_00188_stimulus_32.wav
# count total  583
# file  fold_3_participant_00188_stimulus_33.wav
# count total  584
# file  fold_3_participant_00188_stimulus_34.wav
# count total  585
# file  fold_3_participant_00188_stimulus_35.wav
# count total  586
# file  fold_3_participant_00188_stimulus_36.wav
# count total  587
# file  fold_3_participant_00188_stimulus_37.wav
# count total  588
# file  fold_3_participant_00188_stimulus_38.wav
# count total  589
# file  fold_3_participant_00188_stimulus_39.wav
# count total  590
# file  fold_3_participant_00188_stimulus_40.wav
# count total  591
# file  fold_3_participant_00188_stimulus_41.wav
# count total  592
# file  fold_3_participant_00188_stimulus_42.wav
# count total  593
# file  fold_3_participant_00188_stimulus_43.wav
# count total  594
# file  fold_3_participant_00188_stimulus_44.wav
# count total  595
# file  fold_3_participant_00193_stimulus_02.wav
# count total  596
# file  fold_3_participant_00193_stimulus_03.wav
# count total  597
# file  fold_3_participant_00193_stimulus_04.wav
# count total  598
# file  fold_3_participant_00193_stimulus_05.wav
# count total  599
# file  fold_3_participant_00193_stimulus_06.wav
# count total  600
# file  fold_3_participant_00193_stimulus_07.wav
# count total  601
# file  fold_3_participant_00193_stimulus_08.wav
# count total  602
# file  fold_3_participant_00193_stimulus_09.wav
# count total  603
# file  fold_3_participant_00193_stimulus_10.wav
# count total  604
# file  fold_3_participant_00193_stimulus_11.wav
# count total  605
# file  fold_3_participant_00193_stimulus_12.wav
# count total  606
# file  fold_3_participant_00193_stimulus_13.wav
# count total  607
# file  fold_3_participant_00193_stimulus_14.wav
# count total  608
# file  fold_3_participant_00193_stimulus_15.wav
# count total  609
# file  fold_3_participant_00193_stimulus_16.wav
# count total  610
# file  fold_3_participant_00193_stimulus_17.wav
# count total  611
# file  fold_3_participant_00193_stimulus_18.wav
# count total  612
# file  fold_3_participant_00193_stimulus_19.wav
# count total  613
# file  fold_3_participant_00193_stimulus_20.wav
# count total  614
# file  fold_3_participant_00193_stimulus_21.wav
# count total  615
# file  fold_3_participant_00193_stimulus_22.wav
# count total  616
# file  fold_3_participant_00193_stimulus_23.wav
# count total  617
# file  fold_3_participant_00193_stimulus_24.wav
# count total  618
# file  fold_3_participant_00193_stimulus_26.wav
# count total  619
# file  fold_3_participant_00193_stimulus_27.wav
# count total  620
# file  fold_3_participant_00193_stimulus_28.wav
# count total  621
# file  fold_3_participant_00193_stimulus_29.wav
# count total  622
# file  fold_3_participant_00193_stimulus_30.wav
# count total  623
# file  fold_3_participant_00193_stimulus_31.wav
# count total  624
# file  fold_3_participant_00193_stimulus_32.wav
# count total  625
# file  fold_3_participant_00193_stimulus_33.wav
# count total  626
# file  fold_3_participant_00193_stimulus_34.wav
# count total  627
# file  fold_3_participant_00193_stimulus_35.wav
# count total  628
# file  fold_3_participant_00193_stimulus_36.wav
# count total  629
# file  fold_3_participant_00193_stimulus_37.wav
# count total  630
# file  fold_3_participant_00193_stimulus_38.wav
# count total  631
# file  fold_3_participant_00193_stimulus_39.wav
# count total  632
# file  fold_3_participant_00193_stimulus_40.wav
# count total  633
# file  fold_3_participant_00193_stimulus_41.wav
# count total  634
# file  fold_3_participant_00193_stimulus_42.wav
# count total  635
# file  fold_3_participant_00193_stimulus_43.wav
# count total  636
# file  fold_3_participant_00193_stimulus_44.wav
# count total  637
# file  fold_3_participant_00198_stimulus_02.wav
# count total  638
# file  fold_3_participant_00198_stimulus_03.wav
# count total  639
# file  fold_3_participant_00198_stimulus_04.wav
# count total  640
# file  fold_3_participant_00198_stimulus_05.wav
# count total  641
# file  fold_3_participant_00198_stimulus_06.wav
# count total  642
# file  fold_3_participant_00198_stimulus_07.wav
# count total  643
# file  fold_3_participant_00198_stimulus_08.wav
# count total  644
# file  fold_3_participant_00198_stimulus_09.wav
# count total  645
# file  fold_3_participant_00198_stimulus_10.wav
# count total  646
# file  fold_3_participant_00198_stimulus_11.wav
# count total  647
# file  fold_3_participant_00198_stimulus_12.wav
# count total  648
# file  fold_3_participant_00198_stimulus_13.wav
# count total  649
# file  fold_3_participant_00198_stimulus_14.wav
# count total  650
# file  fold_3_participant_00198_stimulus_15.wav
# count total  651
# file  fold_3_participant_00198_stimulus_16.wav
# count total  652
# file  fold_3_participant_00198_stimulus_17.wav
# count total  653
# file  fold_3_participant_00198_stimulus_18.wav
# count total  654
# file  fold_3_participant_00198_stimulus_20.wav
# count total  655
# file  fold_3_participant_00198_stimulus_21.wav
# count total  656
# file  fold_3_participant_00198_stimulus_22.wav
# count total  657
# file  fold_3_participant_00198_stimulus_23.wav
# count total  658
# file  fold_3_participant_00198_stimulus_24.wav
# count total  659
# file  fold_3_participant_00198_stimulus_25.wav
# count total  660
# file  fold_3_participant_00198_stimulus_26.wav
# count total  661
# file  fold_3_participant_00198_stimulus_27.wav
# count total  662
# file  fold_3_participant_00198_stimulus_28.wav
# count total  663
# file  fold_3_participant_00198_stimulus_29.wav
# count total  664
# file  fold_3_participant_00198_stimulus_30.wav
# count total  665
# file  fold_3_participant_00198_stimulus_31.wav
# count total  666
# file  fold_3_participant_00198_stimulus_32.wav
# count total  667
# file  fold_3_participant_00198_stimulus_33.wav
# count total  668
# file  fold_3_participant_00198_stimulus_34.wav
# count total  669
# file  fold_3_participant_00198_stimulus_35.wav
# count total  670
# file  fold_3_participant_00198_stimulus_36.wav
# count total  671
# file  fold_3_participant_00198_stimulus_37.wav
# count total  672
# file  fold_3_participant_00198_stimulus_38.wav
# count total  673
# file  fold_3_participant_00198_stimulus_39.wav
# count total  674
# file  fold_3_participant_00198_stimulus_40.wav
# count total  675
# file  fold_3_participant_00198_stimulus_41.wav
# count total  676
# file  fold_3_participant_00198_stimulus_42.wav
# count total  677
# file  fold_3_participant_00198_stimulus_43.wav
# count total  678
# file  fold_3_participant_00198_stimulus_44.wav
# count total  679
# file  fold_3_participant_00203_stimulus_02.wav
# count total  680
# file  fold_3_participant_00203_stimulus_03.wav
# count total  681
# file  fold_3_participant_00203_stimulus_04.wav
# count total  682
# file  fold_3_participant_00203_stimulus_05.wav
# count total  683
# file  fold_3_participant_00203_stimulus_06.wav
# count total  684
# file  fold_3_participant_00203_stimulus_07.wav
# count total  685
# file  fold_3_participant_00203_stimulus_08.wav
# count total  686
# file  fold_3_participant_00203_stimulus_09.wav
# count total  687
# file  fold_3_participant_00203_stimulus_10.wav
# count total  688
# file  fold_3_participant_00203_stimulus_11.wav
# count total  689
# file  fold_3_participant_00203_stimulus_12.wav
# count total  690
# file  fold_3_participant_00203_stimulus_13.wav
# count total  691
# file  fold_3_participant_00203_stimulus_14.wav
# count total  692
# file  fold_3_participant_00203_stimulus_15.wav
# count total  693
# file  fold_3_participant_00203_stimulus_16.wav
# count total  694
# file  fold_3_participant_00203_stimulus_17.wav
# count total  695
# file  fold_3_participant_00203_stimulus_18.wav
# count total  696
# file  fold_3_participant_00203_stimulus_19.wav
# count total  697
# file  fold_3_participant_00203_stimulus_20.wav
# count total  698
# file  fold_3_participant_00203_stimulus_21.wav
# count total  699
# file  fold_3_participant_00203_stimulus_22.wav
# count total  700
# file  fold_3_participant_00203_stimulus_24.wav
# count total  701
# file  fold_3_participant_00203_stimulus_25.wav
# count total  702
# file  fold_3_participant_00203_stimulus_26.wav
# count total  703
# file  fold_3_participant_00203_stimulus_27.wav
# count total  704
# file  fold_3_participant_00203_stimulus_28.wav
# count total  705
# file  fold_3_participant_00203_stimulus_29.wav
# count total  706
# file  fold_3_participant_00203_stimulus_30.wav
# count total  707
# file  fold_3_participant_00203_stimulus_31.wav
# count total  708
# file  fold_3_participant_00203_stimulus_32.wav
# count total  709
# file  fold_3_participant_00203_stimulus_33.wav
# count total  710
# file  fold_3_participant_00203_stimulus_34.wav
# count total  711
# file  fold_3_participant_00203_stimulus_35.wav
# count total  712
# file  fold_3_participant_00203_stimulus_36.wav
# count total  713
# file  fold_3_participant_00203_stimulus_37.wav
# count total  714
# file  fold_3_participant_00203_stimulus_38.wav
# count total  715
# file  fold_3_participant_00203_stimulus_39.wav
# count total  716
# file  fold_3_participant_00203_stimulus_40.wav
# count total  717
# file  fold_3_participant_00203_stimulus_41.wav
# count total  718
# file  fold_3_participant_00203_stimulus_42.wav
# count total  719
# file  fold_3_participant_00203_stimulus_43.wav
# count total  720
# file  fold_3_participant_00203_stimulus_44.wav
# count total  721
# file  fold_3_participant_00208_stimulus_02.wav
# count total  722
# file  fold_3_participant_00208_stimulus_03.wav
# count total  723
# file  fold_3_participant_00208_stimulus_04.wav
# count total  724
# file  fold_3_participant_00208_stimulus_05.wav
# count total  725
# file  fold_3_participant_00208_stimulus_06.wav
# count total  726
# file  fold_3_participant_00208_stimulus_07.wav
# count total  727
# file  fold_3_participant_00208_stimulus_08.wav
# count total  728
# file  fold_3_participant_00208_stimulus_09.wav
# count total  729
# file  fold_3_participant_00208_stimulus_10.wav
# count total  730
# file  fold_3_participant_00208_stimulus_11.wav
# count total  731
# file  fold_3_participant_00208_stimulus_12.wav
# count total  732
# file  fold_3_participant_00208_stimulus_13.wav
# count total  733
# file  fold_3_participant_00208_stimulus_14.wav
# count total  734
# file  fold_3_participant_00208_stimulus_15.wav
# count total  735
# file  fold_3_participant_00208_stimulus_16.wav
# count total  736
# file  fold_3_participant_00208_stimulus_17.wav
# count total  737
# file  fold_3_participant_00208_stimulus_18.wav
# count total  738
# file  fold_3_participant_00208_stimulus_19.wav
# count total  739
# file  fold_3_participant_00208_stimulus_20.wav
# count total  740
# file  fold_3_participant_00208_stimulus_21.wav
# count total  741
# file  fold_3_participant_00208_stimulus_22.wav
# count total  742
# file  fold_3_participant_00208_stimulus_24.wav
# count total  743
# file  fold_3_participant_00208_stimulus_25.wav
# ...
# count total  25197
# file  fold_4_participant_00209_stimulus_39.wav
# count total  25198
# file  fold_4_participant_00209_stimulus_40.wav
# count total  25199
# file  fold_4_participant_00209_stimulus_41.wav
# count total  25200
# file  fold_4_participant_00209_stimulus_42.wav
# count total  25201
# file  fold_4_participant_00209_stimulus_43.wav
# count total  25202
# file  fold_4_participant_00209_stimulus_44.wav
# count total  25203
# file  fold_4_participant_00214_stimulus_02.wav
# count total  25204
# file  fold_4_participant_00214_stimulus_03.wav
# count total  25205
# file  fold_4_participant_00214_stimulus_04.wav
# count total  25206
# file  fold_4_participant_00214_stimulus_05.wav
# count total  25207
# file  fold_4_participant_00214_stimulus_06.wav
# count total  25208
# file  fold_4_participant_00214_stimulus_07.wav
# count total  25209
# file  fold_4_participant_00214_stimulus_08.wav
# count total  25210
# file  fold_4_participant_00214_stimulus_09.wav
# count total  25211
# file  fold_4_participant_00214_stimulus_10.wav
# count total  25212
# file  fold_4_participant_00214_stimulus_11.wav
# count total  25213
# file  fold_4_participant_00214_stimulus_12.wav
# count total  25214
# file  fold_4_participant_00214_stimulus_13.wav
# count total  25215
# file  fold_4_participant_00214_stimulus_14.wav
# count total  25216
# file  fold_4_participant_00214_stimulus_15.wav
# count total  25217
# file  fold_4_participant_00214_stimulus_16.wav
# count total  25218
# file  fold_4_participant_00214_stimulus_17.wav
# count total  25219
# file  fold_4_participant_00214_stimulus_18.wav
# count total  25220
# file  fold_4_participant_00214_stimulus_19.wav
# count total  25221
# file  fold_4_participant_00214_stimulus_20.wav
# count total  25222
# file  fold_4_participant_00214_stimulus_21.wav
# count total  25223
# file  fold_4_participant_00214_stimulus_22.wav
# count total  25224
# file  fold_4_participant_00214_stimulus_23.wav
# count total  25225
# file  fold_4_participant_00214_stimulus_24.wav
# count total  25226
# file  fold_4_participant_00214_stimulus_25.wav
# count total  25227
# file  fold_4_participant_00214_stimulus_27.wav
# count total  25228
# file  fold_4_participant_00214_stimulus_28.wav
# count total  25229
# file  fold_4_participant_00214_stimulus_29.wav
# count total  25230
# file  fold_4_participant_00214_stimulus_30.wav
# count total  25231
# file  fold_4_participant_00214_stimulus_31.wav
# count total  25232
# file  fold_4_participant_00214_stimulus_32.wav
# count total  25233
# file  fold_4_participant_00214_stimulus_33.wav
# count total  25234
# file  fold_4_participant_00214_stimulus_34.wav
# count total  25235
# file  fold_4_participant_00214_stimulus_35.wav
# count total  25236
# file  fold_4_participant_00214_stimulus_36.wav
# count total  25237
# file  fold_4_participant_00214_stimulus_37.wav
# count total  25238
# file  fold_4_participant_00214_stimulus_38.wav
# count total  25239
# file  fold_4_participant_00214_stimulus_39.wav
# count total  25240
# file  fold_4_participant_00214_stimulus_40.wav
# count total  25241
# file  fold_4_participant_00214_stimulus_41.wav
# count total  25242
# file  fold_4_participant_00214_stimulus_42.wav
# count total  25243
# file  fold_4_participant_00214_stimulus_43.wav
# count total  25244
# file  fold_4_participant_00214_stimulus_44.wav
# count total  25245
# file  fold_4_participant_00219_stimulus_02.wav
# count total  25246
# file  fold_4_participant_00219_stimulus_03.wav
# count total  25247
# file  fold_4_participant_00219_stimulus_04.wav
# count total  25248
# file  fold_4_participant_00219_stimulus_05.wav
# count total  25249
# file  fold_4_participant_00219_stimulus_06.wav
# count total  25250
# file  fold_4_participant_00219_stimulus_07.wav
# count total  25251
# file  fold_4_participant_00219_stimulus_08.wav
# count total  25252
# file  fold_4_participant_00219_stimulus_09.wav
# count total  25253
# file  fold_4_participant_00219_stimulus_10.wav
# count total  25254
# file  fold_4_participant_00219_stimulus_11.wav
# count total  25255
# file  fold_4_participant_00219_stimulus_12.wav
# count total  25256
# file  fold_4_participant_00219_stimulus_13.wav
# count total  25257
# file  fold_4_participant_00219_stimulus_14.wav
# count total  25258
# file  fold_4_participant_00219_stimulus_15.wav
# count total  25259
# file  fold_4_participant_00219_stimulus_16.wav
# count total  25260
# file  fold_4_participant_00219_stimulus_18.wav
# count total  25261
# file  fold_4_participant_00219_stimulus_19.wav
# count total  25262
# file  fold_4_participant_00219_stimulus_20.wav
# count total  25263
# file  fold_4_participant_00219_stimulus_21.wav
# count total  25264
# file  fold_4_participant_00219_stimulus_22.wav
# count total  25265
# file  fold_4_participant_00219_stimulus_23.wav
# count total  25266
# file  fold_4_participant_00219_stimulus_24.wav
# count total  25267
# file  fold_4_participant_00219_stimulus_25.wav
# count total  25268
# file  fold_4_participant_00219_stimulus_26.wav
# count total  25269
# file  fold_4_participant_00219_stimulus_27.wav
# count total  25270
# file  fold_4_participant_00219_stimulus_28.wav
# count total  25271
# file  fold_4_participant_00219_stimulus_29.wav
# count total  25272
# file  fold_4_participant_00219_stimulus_30.wav
# count total  25273
# file  fold_4_participant_00219_stimulus_31.wav
# count total  25274
# file  fold_4_participant_00219_stimulus_32.wav
# count total  25275
# file  fold_4_participant_00219_stimulus_33.wav
# count total  25276
# file  fold_4_participant_00219_stimulus_34.wav
# count total  25277
# file  fold_4_participant_00219_stimulus_35.wav
# count total  25278
# file  fold_4_participant_00219_stimulus_36.wav
# count total  25279
# file  fold_4_participant_00219_stimulus_37.wav
# count total  25280
# file  fold_4_participant_00219_stimulus_38.wav
# count total  25281
# file  fold_4_participant_00219_stimulus_39.wav
# count total  25282
# file  fold_4_participant_00219_stimulus_40.wav
# count total  25283
# file  fold_4_participant_00219_stimulus_41.wav
# count total  25284
# file  fold_4_participant_00219_stimulus_42.wav
# count total  25285
# file  fold_4_participant_00219_stimulus_43.wav
# count total  25286
# file  fold_4_participant_00219_stimulus_44.wav
# count total  25287
# file  fold_4_participant_00224_stimulus_02.wav
# count total  25288
# file  fold_4_participant_00224_stimulus_03.wav
# count total  25289
# file  fold_4_participant_00224_stimulus_04.wav
# count total  25290
# file  fold_4_participant_00224_stimulus_05.wav
# count total  25291
# file  fold_4_participant_00224_stimulus_06.wav
# count total  25292
# file  fold_4_participant_00224_stimulus_07.wav
# count total  25293
# file  fold_4_participant_00224_stimulus_08.wav
# count total  25294
# file  fold_4_participant_00224_stimulus_09.wav
# count total  25295
# file  fold_4_participant_00224_stimulus_10.wav
# count total  25296
# file  fold_4_participant_00224_stimulus_11.wav
# count total  25297
# file  fold_4_participant_00224_stimulus_12.wav
# count total  25298
# file  fold_4_participant_00224_stimulus_13.wav
# count total  25299
# file  fold_4_participant_00224_stimulus_14.wav
# count total  25300
# file  fold_4_participant_00224_stimulus_15.wav
# count total  25301
# file  fold_4_participant_00224_stimulus_17.wav
# count total  25302
# file  fold_4_participant_00224_stimulus_18.wav
# count total  25303
# file  fold_4_participant_00224_stimulus_19.wav
# count total  25304
# file  fold_4_participant_00224_stimulus_20.wav
# count total  25305
# file  fold_4_participant_00224_stimulus_21.wav
# count total  25306
# file  fold_4_participant_00224_stimulus_22.wav
# count total  25307
# file  fold_4_participant_00224_stimulus_23.wav
# count total  25308
# file  fold_4_participant_00224_stimulus_24.wav
# count total  25309
# file  fold_4_participant_00224_stimulus_25.wav
# count total  25310
# file  fold_4_participant_00224_stimulus_26.wav
# count total  25311
# file  fold_4_participant_00224_stimulus_27.wav
# count total  25312
# file  fold_4_participant_00224_stimulus_28.wav
# count total  25313
# file  fold_4_participant_00224_stimulus_29.wav
# count total  25314
# file  fold_4_participant_00224_stimulus_30.wav
# count total  25315
# file  fold_4_participant_00224_stimulus_31.wav
# count total  25316
# file  fold_4_participant_00224_stimulus_32.wav
# count total  25317
# file  fold_4_participant_00224_stimulus_33.wav
# count total  25318
# file  fold_4_participant_00224_stimulus_34.wav
# count total  25319
# file  fold_4_participant_00224_stimulus_35.wav
# count total  25320
# file  fold_4_participant_00224_stimulus_36.wav
# count total  25321
# file  fold_4_participant_00224_stimulus_37.wav
# count total  25322
# file  fold_4_participant_00224_stimulus_38.wav
# count total  25323
# file  fold_4_participant_00224_stimulus_39.wav
# count total  25324
# file  fold_4_participant_00224_stimulus_40.wav
# count total  25325
# file  fold_4_participant_00224_stimulus_41.wav
# count total  25326
# file  fold_4_participant_00224_stimulus_42.wav
# count total  25327
# file  fold_4_participant_00224_stimulus_43.wav
# count total  25328
# file  fold_4_participant_00224_stimulus_44.wav
# count total  25329
# file  fold_4_participant_00229_stimulus_02.wav
# count total  25330
# file  fold_4_participant_00229_stimulus_03.wav
# count total  25331
# file  fold_4_participant_00229_stimulus_04.wav
# count total  25332
# file  fold_4_participant_00229_stimulus_05.wav
# count total  25333
# file  fold_4_participant_00229_stimulus_06.wav
# count total  25334
# file  fold_4_participant_00229_stimulus_07.wav
# count total  25335
# file  fold_4_participant_00229_stimulus_08.wav
# count total  25336
# file  fold_4_participant_00229_stimulus_09.wav
# count total  25337
# file  fold_4_participant_00229_stimulus_10.wav
# count total  25338
# file  fold_4_participant_00229_stimulus_11.wav
# count total  25339
# file  fold_4_participant_00229_stimulus_12.wav
# count total  25340
# file  fold_4_participant_00229_stimulus_13.wav
# count total  25341
# file  fold_4_participant_00229_stimulus_14.wav
# count total  25342
# file  fold_4_participant_00229_stimulus_15.wav
# count total  25343
# file  fold_4_participant_00229_stimulus_16.wav
# count total  25344
# file  fold_4_participant_00229_stimulus_17.wav
# count total  25345
# file  fold_4_participant_00229_stimulus_18.wav
# count total  25346
# file  fold_4_participant_00229_stimulus_19.wav
# count total  25347
# file  fold_4_participant_00229_stimulus_20.wav
# count total  25348
# file  fold_4_participant_00229_stimulus_21.wav
# count total  25349
# file  fold_4_participant_00229_stimulus_22.wav
# count total  25350
# file  fold_4_participant_00229_stimulus_23.wav
# count total  25351
# file  fold_4_participant_00229_stimulus_24.wav
# count total  25352
# file  fold_4_participant_00229_stimulus_25.wav
# count total  25353
# file  fold_4_participant_00229_stimulus_27.wav
# count total  25354
# file  fold_4_participant_00229_stimulus_28.wav
# count total  25355
# file  fold_4_participant_00229_stimulus_29.wav
# count total  25356
# file  fold_4_participant_00229_stimulus_30.wav
# count total  25357
# file  fold_4_participant_00229_stimulus_31.wav
# count total  25358
# file  fold_4_participant_00229_stimulus_32.wav
# count total  25359
# file  fold_4_participant_00229_stimulus_33.wav
# count total  25360
# file  fold_4_participant_00229_stimulus_34.wav
# count total  25361
# file  fold_4_participant_00229_stimulus_35.wav
# count total  25362
# file  fold_4_participant_00229_stimulus_36.wav
# count total  25363
# file  fold_4_participant_00229_stimulus_37.wav
# count total  25364
# file  fold_4_participant_00229_stimulus_38.wav
# count total  25365
# file  fold_4_participant_00229_stimulus_39.wav
# count total  25366
# file  fold_4_participant_00229_stimulus_40.wav
# count total  25367
# file  fold_4_participant_00229_stimulus_41.wav
# count total  25368
# file  fold_4_participant_00229_stimulus_42.wav
# count total  25369
# file  fold_4_participant_00229_stimulus_43.wav
# count total  25370
# file  fold_4_participant_00229_stimulus_44.wav
# count total  25371
# file  fold_4_participant_00234_stimulus_02.wav
# count total  25372
# file  fold_4_participant_00234_stimulus_03.wav
# count total  25373
# file  fold_4_participant_00234_stimulus_04.wav
# count total  25374
# file  fold_4_participant_00234_stimulus_05.wav
# count total  25375
# file  fold_4_participant_00234_stimulus_06.wav
# count total  25376
# file  fold_4_participant_00234_stimulus_07.wav
# count total  25377
# file  fold_4_participant_00234_stimulus_08.wav
# count total  25378
# file  fold_4_participant_00234_stimulus_09.wav
# count total  25379
# file  fold_4_participant_00234_stimulus_10.wav
# count total  25380
# file  fold_4_participant_00234_stimulus_11.wav
# count total  25381
# file  fold_4_participant_00234_stimulus_12.wav
# count total  25382
# file  fold_4_participant_00234_stimulus_13.wav
# count total  25383
# file  fold_4_participant_00234_stimulus_14.wav
# count total  25384
# file  fold_4_participant_00234_stimulus_15.wav
# count total  25385
# file  fold_4_participant_00234_stimulus_16.wav
# count total  25386
# file  fold_4_participant_00234_stimulus_17.wav
# count total  25387
# file  fold_4_participant_00234_stimulus_18.wav
# count total  25388
# file  fold_4_participant_00234_stimulus_19.wav
# count total  25389
# file  fold_4_participant_00234_stimulus_20.wav
# count total  25390
# file  fold_4_participant_00234_stimulus_21.wav
# count total  25391
# file  fold_4_participant_00234_stimulus_22.wav
# count total  25392
# file  fold_4_participant_00234_stimulus_23.wav
# count total  25393
# file  fold_4_participant_00234_stimulus_24.wav
# count total  25394
# file  fold_4_participant_00234_stimulus_26.wav
# count total  25395
# file  fold_4_participant_00234_stimulus_27.wav
# count total  25396
# file  fold_4_participant_00234_stimulus_28.wav
# count total  25397
# file  fold_4_participant_00234_stimulus_29.wav
# count total  25398
# file  fold_4_participant_00234_stimulus_30.wav
# count total  25399
# file  fold_4_participant_00234_stimulus_31.wav
# count total  25400
# file  fold_4_participant_00234_stimulus_32.wav
# count total  25401
# file  fold_4_participant_00234_stimulus_33.wav
# count total  25402
# file  fold_4_participant_00234_stimulus_34.wav
# count total  25403
# file  fold_4_participant_00234_stimulus_35.wav
# count total  25404
# file  fold_4_participant_00234_stimulus_36.wav
# count total  25405
# file  fold_4_participant_00234_stimulus_37.wav
# count total  25406
# file  fold_4_participant_00234_stimulus_38.wav
# count total  25407
# file  fold_4_participant_00234_stimulus_39.wav
# count total  25408
# file  fold_4_participant_00234_stimulus_40.wav
# count total  25409
# file  fold_4_participant_00234_stimulus_41.wav
# count total  25410
# file  fold_4_participant_00234_stimulus_42.wav
# count total  25411
# file  fold_4_participant_00234_stimulus_43.wav
# count total  25412
# file  fold_4_participant_00234_stimulus_44.wav
# count total  25413
# file  fold_4_participant_00239_stimulus_02.wav
# count total  25414
# file  fold_4_participant_00239_stimulus_03.wav
# count total  25415
# file  fold_4_participant_00239_stimulus_04.wav
# count total  25416
# file  fold_4_participant_00239_stimulus_05.wav
# count total  25417
# file  fold_4_participant_00239_stimulus_06.wav
# count total  25418
# file  fold_4_participant_00239_stimulus_07.wav
# count total  25419
# file  fold_4_participant_00239_stimulus_08.wav
# count total  25420
# file  fold_4_participant_00239_stimulus_09.wav
# count total  25421
# file  fold_4_participant_00239_stimulus_10.wav
# count total  25422
# file  fold_4_participant_00239_stimulus_11.wav
# count total  25423
# file  fold_4_participant_00239_stimulus_12.wav
# count total  25424
# file  fold_4_participant_00239_stimulus_13.wav
# count total  25425
# file  fold_4_participant_00239_stimulus_14.wav
# count total  25426
# file  fold_4_participant_00239_stimulus_15.wav
# count total  25427
# file  fold_4_participant_00239_stimulus_16.wav
# count total  25428
# file  fold_4_participant_00239_stimulus_17.wav
# count total  25429
# file  fold_4_participant_00239_stimulus_18.wav
# count total  25430
# file  fold_4_participant_00239_stimulus_20.wav
# count total  25431
# file  fold_4_participant_00239_stimulus_21.wav
# count total  25432
# file  fold_4_participant_00239_stimulus_22.wav
# count total  25433
# file  fold_4_participant_00239_stimulus_23.wav
# count total  25434
# file  fold_4_participant_00239_stimulus_24.wav
# count total  25435
# file  fold_4_participant_00239_stimulus_25.wav
# count total  25436
# file  fold_4_participant_00239_stimulus_26.wav
# count total  25437
# file  fold_4_participant_00239_stimulus_27.wav
# count total  25438
# file  fold_4_participant_00239_stimulus_28.wav
# count total  25439

# %% [markdown]
# ## 2.4) Save new generated dataset

# %%
# Save new dataset
newDF.to_csv("../data/responses_SoundLights.csv", index=False)
