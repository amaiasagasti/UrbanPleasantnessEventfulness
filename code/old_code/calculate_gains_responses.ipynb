# %% [markdown]
# # Generating gains for wav calibration on augmented soundscapes

# %% [markdown]
# In ARAUS dataset responses.csv constitute the dataset of +25k augmented soundscapes labeled with psychoacoustic and acoustic parametres. Among these, we can find Leq_r, which constitutes the Leq of channel R for each audio. These value is calculated according to the formula below. We calculate the Leq on the digital signal channel R, without any wav calibration. The obtained value is sustracted from the corresponding Leq_r. The difference is converted to lineal, and it constitutes the wav calibration we need to apply to the audio.

# %%
# Add MOSQITO to the Python path
import sys
import os
sys.path.append('..')

# Import numpy
import numpy as np
import pandas as pd
# Import plot function
import matplotlib.pyplot as plt
# Import mosqito functions
#from mosqito.utils import load
from scipy.io import wavfile
from scipy.signal import resample
from maad.spl import pressure2leq, pressure2dBSPL
from maad.util import mean_dB
import librosa

# Import MOSQITO color sheme [Optional]
from mosqito import COLORS

# %%
def load(file, wav_calib=None, mat_signal="", mat_fs="", ch=None):
    """Extract the signal and its time axis from .wav or .uff file,
    resample the signal to 48 kHz, and affects its sampling frequency
    and time signal values.

    Parameters
    ----------
    file : string
        string path to the signal file
    wav_calib : float, optional
        Wav file calibration factor [Pa/FS]. Level of the signal in Pa_peak
        corresponding to the full scale of the .wav file. If None, a
        calibration factor of 1 is considered. Default to None.
    mat_signal : string
        in case of a .mat file, name of the signal variable
    mat_fs : string
        in case of a .mat file, name of the sampling frequency variable

    Outputs
    -------
    signal : numpy.array
        time signal values
    fs : integer
        sampling frequency
    """

    # load the .wav file content
    if file[-3:] == "wav" or file[-3:] == "WAV":
        fs, signal = wavfile.read(file)

        # manage multichannel files
        if signal.ndim > 1:
            signal = signal[:, ch] # signal[:, 0] for first channel, signal[:, 1] for second ch

        # calibration factor for the signal to be in Pa
        if wav_calib is None:
            wav_calib = 1
            print("[Info] A calibration of 1 Pa/FS is considered")
        if isinstance(signal[0], np.int16):
            signal = wav_calib * signal / (2**15 - 1)
        elif isinstance(signal[0], np.int32):
            signal = wav_calib * signal / (2**31 - 1)
        elif isinstance(signal[0], np.float):
            signal = wav_calib * signal

    else:
        raise ValueError("""ERROR: only .wav .mat or .uff files are supported""")

    # resample to 48kHz to allow calculation
    if fs != 48000:
        signal = resample(signal, int(48000 * len(signal) / fs))
        fs = 48000

    return signal, fs

# %%
data_augmented = pd.read_csv("../data/responses_complete.csv")
# For each audio...
audios_path = "../data/soundscapes_augmented/"
n_audios=data_augmented.shape[0]
gain_values=np.zeros(n_audios)
i=0
for file in sorted(os.listdir(audios_path)):
        if file.endswith('.mp3') or file.endswith('.wav'):
            print("file name ", file)
            # locate audio in dataset
            file_split=file.split("_")
            file_fold=int(file_split[1])
            file_participant="ARAUS_"+file_split[3]
            file_stimulus=int(file_split[5].split(".")[0])
            audio_info_aug = data_augmented[
                (data_augmented['fold_r'] == file_fold) &
                (data_augmented['stimulus_index'] == file_stimulus) &
                (data_augmented['participant'] == file_participant)
            ]
            row_index = audio_info_aug.index[0]
            """ audio_info_aug = audio_info_aug[audio_info_aug['stimulus_index'] == file_stimulus]
            audio_info_aug = audio_info_aug[audio_info_aug['participant'] == file_participant] # Row of info from responses.csv """
            # audio path
            audio_path=audios_path+file
            #Get Leq of raw digital audio to calculate audio gain needed
            rawR, fs = load(audio_path, wav_calib=1, ch=1) #R
            rawR_Leq_avg=mean_dB(pressure2leq(rawR, fs, 0.125))
            trueLeq=audio_info_aug["Leq_R_r"].values[0]
            difference=trueLeq-rawR_Leq_avg
            gain_values[row_index]=10**(difference/20)
            i=i+1
            print("Done audio number ", i, "/",n_audios)
# Out:
# file name  fold_0_participant_10001_stimulus_02.wav
# Done audio number  1 / 27255
# file name  fold_0_participant_10001_stimulus_03.wav
# Done audio number  2 / 27255
# file name  fold_0_participant_10001_stimulus_04.wav
# Done audio number  3 / 27255
# file name  fold_0_participant_10001_stimulus_05.wav
# Done audio number  4 / 27255
# file name  fold_0_participant_10001_stimulus_06.wav
# Done audio number  5 / 27255
# file name  fold_0_participant_10001_stimulus_07.wav
# Done audio number  6 / 27255
# file name  fold_0_participant_10001_stimulus_08.wav
# Done audio number  7 / 27255
# file name  fold_0_participant_10001_stimulus_09.wav
# Done audio number  8 / 27255
# file name  fold_0_participant_10001_stimulus_10.wav
# Done audio number  9 / 27255
# file name  fold_0_participant_10001_stimulus_11.wav
# Done audio number  10 / 27255
# file name  fold_0_participant_10001_stimulus_12.wav
# Done audio number  11 / 27255
# file name  fold_0_participant_10001_stimulus_13.wav
# Done audio number  12 / 27255
# file name  fold_0_participant_10001_stimulus_14.wav
# Done audio number  13 / 27255
# file name  fold_0_participant_10001_stimulus_15.wav
# Done audio number  14 / 27255
# file name  fold_0_participant_10001_stimulus_16.wav
# Done audio number  15 / 27255
# file name  fold_0_participant_10001_stimulus_17.wav
# Done audio number  16 / 27255
# file name  fold_0_participant_10001_stimulus_18.wav
# Done audio number  17 / 27255
# file name  fold_0_participant_10001_stimulus_19.wav
# Done audio number  18 / 27255
# file name  fold_0_participant_10001_stimulus_21.wav
# Done audio number  19 / 27255
# file name  fold_0_participant_10001_stimulus_22.wav
# Done audio number  20 / 27255
# file name  fold_0_participant_10001_stimulus_23.wav
# Done audio number  21 / 27255
# file name  fold_0_participant_10001_stimulus_24.wav
# Done audio number  22 / 27255
# file name  fold_0_participant_10001_stimulus_25.wav
# Done audio number  23 / 27255
# file name  fold_0_participant_10001_stimulus_26.wav
# Done audio number  24 / 27255
# file name  fold_0_participant_10001_stimulus_27.wav
# Done audio number  25 / 27255
# file name  fold_0_participant_10001_stimulus_28.wav
# Done audio number  26 / 27255
# file name  fold_0_participant_10001_stimulus_29.wav
# Done audio number  27 / 27255
# file name  fold_0_participant_10001_stimulus_30.wav
# Done audio number  28 / 27255
# file name  fold_0_participant_10001_stimulus_31.wav
# Done audio number  29 / 27255
# file name  fold_0_participant_10001_stimulus_32.wav
# Done audio number  30 / 27255
# file name  fold_0_participant_10001_stimulus_33.wav
# Done audio number  31 / 27255
# file name  fold_0_participant_10001_stimulus_34.wav
# Done audio number  32 / 27255
# file name  fold_0_participant_10001_stimulus_35.wav
# Done audio number  33 / 27255
# file name  fold_0_participant_10001_stimulus_36.wav
# Done audio number  34 / 27255
# file name  fold_0_participant_10001_stimulus_37.wav
# Done audio number  35 / 27255
# file name  fold_0_participant_10001_stimulus_38.wav
# Done audio number  36 / 27255
# file name  fold_0_participant_10001_stimulus_39.wav
# Done audio number  37 / 27255
# file name  fold_0_participant_10001_stimulus_40.wav
# Done audio number  38 / 27255
# file name  fold_0_participant_10001_stimulus_41.wav
# Done audio number  39 / 27255
# file name  fold_0_participant_10001_stimulus_42.wav
# Done audio number  40 / 27255
# file name  fold_0_participant_10001_stimulus_43.wav
# Done audio number  41 / 27255
# file name  fold_0_participant_10001_stimulus_44.wav
# Done audio number  42 / 27255
# file name  fold_0_participant_10001_stimulus_45.wav
# Done audio number  43 / 27255
# file name  fold_0_participant_10001_stimulus_46.wav
# Done audio number  44 / 27255
# file name  fold_0_participant_10001_stimulus_47.wav
# Done audio number  45 / 27255
# file name  fold_0_participant_10001_stimulus_48.wav
# Done audio number  46 / 27255
# file name  fold_0_participant_10001_stimulus_49.wav
# Done audio number  47 / 27255
# file name  fold_0_participant_10001_stimulus_50.wav
# Done audio number  48 / 27255
# file name  fold_0_participant_10002_stimulus_02.wav
# Done audio number  49 / 27255
# file name  fold_0_participant_10002_stimulus_03.wav
# Done audio number  50 / 27255
# file name  fold_0_participant_10002_stimulus_04.wav
# Done audio number  51 / 27255
# file name  fold_0_participant_10002_stimulus_05.wav
# Done audio number  52 / 27255
# file name  fold_0_participant_10002_stimulus_06.wav
# Done audio number  53 / 27255
# file name  fold_0_participant_10002_stimulus_07.wav
# Done audio number  54 / 27255
# file name  fold_0_participant_10002_stimulus_08.wav
# Done audio number  55 / 27255
# file name  fold_0_participant_10002_stimulus_09.wav
# Done audio number  56 / 27255
# file name  fold_0_participant_10002_stimulus_10.wav
# Done audio number  57 / 27255
# file name  fold_0_participant_10002_stimulus_11.wav
# Done audio number  58 / 27255
# file name  fold_0_participant_10002_stimulus_12.wav
# Done audio number  59 / 27255
# file name  fold_0_participant_10002_stimulus_13.wav
# Done audio number  60 / 27255
# file name  fold_0_participant_10002_stimulus_14.wav
# Done audio number  61 / 27255
# file name  fold_0_participant_10002_stimulus_15.wav
# Done audio number  62 / 27255
# file name  fold_0_participant_10002_stimulus_16.wav
# Done audio number  63 / 27255
# file name  fold_0_participant_10002_stimulus_17.wav
# Done audio number  64 / 27255
# file name  fold_0_participant_10002_stimulus_18.wav
# Done audio number  65 / 27255
# file name  fold_0_participant_10002_stimulus_19.wav
# Done audio number  66 / 27255
# file name  fold_0_participant_10002_stimulus_20.wav
# Done audio number  67 / 27255
# file name  fold_0_participant_10002_stimulus_22.wav
# Done audio number  68 / 27255
# file name  fold_0_participant_10002_stimulus_23.wav
# Done audio number  69 / 27255
# file name  fold_0_participant_10002_stimulus_24.wav
# Done audio number  70 / 27255
# file name  fold_0_participant_10002_stimulus_25.wav
# Done audio number  71 / 27255
# file name  fold_0_participant_10002_stimulus_26.wav
# Done audio number  72 / 27255
# file name  fold_0_participant_10002_stimulus_27.wav
# Done audio number  73 / 27255
# file name  fold_0_participant_10002_stimulus_28.wav
# Done audio number  74 / 27255
# file name  fold_0_participant_10002_stimulus_29.wav
# Done audio number  75 / 27255
# file name  fold_0_participant_10002_stimulus_30.wav
# Done audio number  76 / 27255
# file name  fold_0_participant_10002_stimulus_31.wav
# Done audio number  77 / 27255
# file name  fold_0_participant_10002_stimulus_32.wav
# Done audio number  78 / 27255
# file name  fold_0_participant_10002_stimulus_33.wav
# Done audio number  79 / 27255
# file name  fold_0_participant_10002_stimulus_34.wav
# Done audio number  80 / 27255
# file name  fold_0_participant_10002_stimulus_35.wav
# Done audio number  81 / 27255
# file name  fold_0_participant_10002_stimulus_36.wav
# Done audio number  82 / 27255
# file name  fold_0_participant_10002_stimulus_37.wav
# Done audio number  83 / 27255
# file name  fold_0_participant_10002_stimulus_38.wav
# Done audio number  84 / 27255
# file name  fold_0_participant_10002_stimulus_39.wav
# Done audio number  85 / 27255
# file name  fold_0_participant_10002_stimulus_40.wav
# Done audio number  86 / 27255
# file name  fold_0_participant_10002_stimulus_41.wav
# Done audio number  87 / 27255
# file name  fold_0_participant_10002_stimulus_42.wav
# Done audio number  88 / 27255
# file name  fold_0_participant_10002_stimulus_43.wav
# Done audio number  89 / 27255
# file name  fold_0_participant_10002_stimulus_44.wav
# Done audio number  90 / 27255
# file name  fold_0_participant_10002_stimulus_45.wav
# Done audio number  91 / 27255
# file name  fold_0_participant_10002_stimulus_46.wav
# Done audio number  92 / 27255
# file name  fold_0_participant_10002_stimulus_47.wav
# Done audio number  93 / 27255
# file name  fold_0_participant_10002_stimulus_48.wav
# Done audio number  94 / 27255
# file name  fold_0_participant_10002_stimulus_49.wav
# Done audio number  95 / 27255
# file name  fold_0_participant_10002_stimulus_50.wav
# Done audio number  96 / 27255
# file name  fold_0_participant_10003_stimulus_02.wav
# Done audio number  97 / 27255
# file name  fold_0_participant_10003_stimulus_03.wav
# Done audio number  98 / 27255
# file name  fold_0_participant_10003_stimulus_04.wav
# Done audio number  99 / 27255
# file name  fold_0_participant_10003_stimulus_05.wav
# Done audio number  100 / 27255
# file name  fold_0_participant_10003_stimulus_06.wav
# Done audio number  101 / 27255
# file name  fold_0_participant_10003_stimulus_07.wav
# Done audio number  102 / 27255
# file name  fold_0_participant_10003_stimulus_08.wav
# Done audio number  103 / 27255
# file name  fold_0_participant_10003_stimulus_09.wav
# Done audio number  104 / 27255
# file name  fold_0_participant_10003_stimulus_10.wav
# Done audio number  105 / 27255
# file name  fold_0_participant_10003_stimulus_11.wav
# Done audio number  106 / 27255
# file name  fold_0_participant_10003_stimulus_12.wav
# Done audio number  107 / 27255
# file name  fold_0_participant_10003_stimulus_13.wav
# Done audio number  108 / 27255
# file name  fold_0_participant_10003_stimulus_14.wav
# Done audio number  109 / 27255
# file name  fold_0_participant_10003_stimulus_15.wav
# Done audio number  110 / 27255
# file name  fold_0_participant_10003_stimulus_16.wav
# Done audio number  111 / 27255
# file name  fold_0_participant_10003_stimulus_17.wav
# Done audio number  112 / 27255
# file name  fold_0_participant_10003_stimulus_18.wav
# Done audio number  113 / 27255
# file name  fold_0_participant_10003_stimulus_19.wav
# Done audio number  114 / 27255
# file name  fold_0_participant_10003_stimulus_20.wav
# Done audio number  115 / 27255
# file name  fold_0_participant_10003_stimulus_21.wav
# Done audio number  116 / 27255
# file name  fold_0_participant_10003_stimulus_22.wav
# Done audio number  117 / 27255
# file name  fold_0_participant_10003_stimulus_23.wav
# Done audio number  118 / 27255
# file name  fold_0_participant_10003_stimulus_24.wav
# Done audio number  119 / 27255
# file name  fold_0_participant_10003_stimulus_26.wav
# Done audio number  120 / 27255
# file name  fold_0_participant_10003_stimulus_27.wav
# Done audio number  121 / 27255
# file name  fold_0_participant_10003_stimulus_28.wav
# Done audio number  122 / 27255
# file name  fold_0_participant_10003_stimulus_29.wav
# Done audio number  123 / 27255
# file name  fold_0_participant_10003_stimulus_30.wav
# Done audio number  124 / 27255
# file name  fold_0_participant_10003_stimulus_31.wav
# Done audio number  125 / 27255
# file name  fold_0_participant_10003_stimulus_32.wav
# Done audio number  126 / 27255
# file name  fold_0_participant_10003_stimulus_33.wav
# Done audio number  127 / 27255
# file name  fold_0_participant_10003_stimulus_34.wav
# Done audio number  128 / 27255
# file name  fold_0_participant_10003_stimulus_35.wav
# Done audio number  129 / 27255
# file name  fold_0_participant_10003_stimulus_36.wav
# Done audio number  130 / 27255
# file name  fold_0_participant_10003_stimulus_37.wav
# Done audio number  131 / 27255
# file name  fold_0_participant_10003_stimulus_38.wav
# Done audio number  132 / 27255
# file name  fold_0_participant_10003_stimulus_39.wav
# Done audio number  133 / 27255
# file name  fold_0_participant_10003_stimulus_40.wav
# Done audio number  134 / 27255
# file name  fold_0_participant_10003_stimulus_41.wav
# Done audio number  135 / 27255
# file name  fold_0_participant_10003_stimulus_42.wav
# Done audio number  136 / 27255
# file name  fold_0_participant_10003_stimulus_43.wav
# Done audio number  137 / 27255
# file name  fold_0_participant_10003_stimulus_44.wav
# Done audio number  138 / 27255
# file name  fold_0_participant_10003_stimulus_45.wav
# Done audio number  139 / 27255
# file name  fold_0_participant_10003_stimulus_46.wav
# Done audio number  140 / 27255
# file name  fold_0_participant_10003_stimulus_47.wav
# Done audio number  141 / 27255
# file name  fold_0_participant_10003_stimulus_48.wav
# Done audio number  142 / 27255
# file name  fold_0_participant_10003_stimulus_49.wav
# Done audio number  143 / 27255
# file name  fold_0_participant_10003_stimulus_50.wav
# Done audio number  144 / 27255
# file name  fold_0_participant_10004_stimulus_02.wav
# Done audio number  145 / 27255
# file name  fold_0_participant_10004_stimulus_03.wav
# Done audio number  146 / 27255
# file name  fold_0_participant_10004_stimulus_04.wav
# Done audio number  147 / 27255
# file name  fold_0_participant_10004_stimulus_05.wav
# Done audio number  148 / 27255
# file name  fold_0_participant_10004_stimulus_06.wav
# Done audio number  149 / 27255
# file name  fold_0_participant_10004_stimulus_07.wav
# Done audio number  150 / 27255
# file name  fold_0_participant_10004_stimulus_08.wav
# Done audio number  151 / 27255
# file name  fold_0_participant_10004_stimulus_09.wav
# Done audio number  152 / 27255
# file name  fold_0_participant_10004_stimulus_10.wav
# Done audio number  153 / 27255
# file name  fold_0_participant_10004_stimulus_11.wav
# Done audio number  154 / 27255
# file name  fold_0_participant_10004_stimulus_12.wav
# Done audio number  155 / 27255
# file name  fold_0_participant_10004_stimulus_13.wav
# Done audio number  156 / 27255
# file name  fold_0_participant_10004_stimulus_14.wav
# Done audio number  157 / 27255
# file name  fold_0_participant_10004_stimulus_15.wav
# Done audio number  158 / 27255
# file name  fold_0_participant_10004_stimulus_17.wav
# Done audio number  159 / 27255
# file name  fold_0_participant_10004_stimulus_18.wav
# Done audio number  160 / 27255
# file name  fold_0_participant_10004_stimulus_19.wav
# Done audio number  161 / 27255
# file name  fold_0_participant_10004_stimulus_20.wav
# Done audio number  162 / 27255
# file name  fold_0_participant_10004_stimulus_21.wav
# Done audio number  163 / 27255
# file name  fold_0_participant_10004_stimulus_22.wav
# Done audio number  164 / 27255
# file name  fold_0_participant_10004_stimulus_23.wav
# Done audio number  165 / 27255
# file name  fold_0_participant_10004_stimulus_24.wav
# Done audio number  166 / 27255
# file name  fold_0_participant_10004_stimulus_25.wav
# Done audio number  167 / 27255
# file name  fold_0_participant_10004_stimulus_26.wav
# Done audio number  168 / 27255
# file name  fold_0_participant_10004_stimulus_27.wav
# Done audio number  169 / 27255
# file name  fold_0_participant_10004_stimulus_28.wav
# Done audio number  170 / 27255
# file name  fold_0_participant_10004_stimulus_29.wav
# Done audio number  171 / 27255
# file name  fold_0_participant_10004_stimulus_30.wav
# Done audio number  172 / 27255
# file name  fold_0_participant_10004_stimulus_31.wav
# Done audio number  173 / 27255
# file name  fold_0_participant_10004_stimulus_32.wav
# Done audio number  174 / 27255
# file name  fold_0_participant_10004_stimulus_33.wav
# Done audio number  175 / 27255
# file name  fold_0_participant_10004_stimulus_34.wav
# Done audio number  176 / 27255
# file name  fold_0_participant_10004_stimulus_35.wav
# Done audio number  177 / 27255
# file name  fold_0_participant_10004_stimulus_36.wav
# Done audio number  178 / 27255
# file name  fold_0_participant_10004_stimulus_37.wav
# Done audio number  179 / 27255
# file name  fold_0_participant_10004_stimulus_38.wav
# Done audio number  180 / 27255
# file name  fold_0_participant_10004_stimulus_39.wav
# Done audio number  181 / 27255
# file name  fold_0_participant_10004_stimulus_40.wav
# Done audio number  182 / 27255
# file name  fold_0_participant_10004_stimulus_41.wav
# Done audio number  183 / 27255
# file name  fold_0_participant_10004_stimulus_42.wav
# Done audio number  184 / 27255
# file name  fold_0_participant_10004_stimulus_43.wav
# Done audio number  185 / 27255
# file name  fold_0_participant_10004_stimulus_44.wav
# Done audio number  186 / 27255
# file name  fold_0_participant_10004_stimulus_45.wav
# Done audio number  187 / 27255
# file name  fold_0_participant_10004_stimulus_46.wav
# Done audio number  188 / 27255
# file name  fold_0_participant_10004_stimulus_47.wav
# Done audio number  189 / 27255
# file name  fold_0_participant_10004_stimulus_48.wav
# Done audio number  190 / 27255
# file name  fold_0_participant_10004_stimulus_49.wav
# Done audio number  191 / 27255
# file name  fold_0_participant_10004_stimulus_50.wav
# Done audio number  192 / 27255
# file name  fold_0_participant_10005_stimulus_02.wav
# Done audio number  193 / 27255
# file name  fold_0_participant_10005_stimulus_03.wav
# Done audio number  194 / 27255
# file name  fold_0_participant_10005_stimulus_04.wav
# Done audio number  195 / 27255
# file name  fold_0_participant_10005_stimulus_05.wav
# Done audio number  196 / 27255
# file name  fold_0_participant_10005_stimulus_06.wav
# Done audio number  197 / 27255
# file name  fold_0_participant_10005_stimulus_07.wav
# Done audio number  198 / 27255
# file name  fold_0_participant_10005_stimulus_08.wav
# Done audio number  199 / 27255
# file name  fold_0_participant_10005_stimulus_09.wav
# Done audio number  200 / 27255
# file name  fold_0_participant_10005_stimulus_10.wav
# Done audio number  201 / 27255
# file name  fold_0_participant_10005_stimulus_11.wav
# Done audio number  202 / 27255
# file name  fold_0_participant_10005_stimulus_12.wav
# Done audio number  203 / 27255
# file name  fold_0_participant_10005_stimulus_13.wav
# Done audio number  204 / 27255
# file name  fold_0_participant_10005_stimulus_14.wav
# Done audio number  205 / 27255
# file name  fold_0_participant_10005_stimulus_15.wav
# Done audio number  206 / 27255
# file name  fold_0_participant_10005_stimulus_16.wav
# Done audio number  207 / 27255
# file name  fold_0_participant_10005_stimulus_17.wav
# Done audio number  208 / 27255
# file name  fold_0_participant_10005_stimulus_18.wav
# Done audio number  209 / 27255
# file name  fold_0_participant_10005_stimulus_19.wav
# Done audio number  210 / 27255
# file name  fold_0_participant_10005_stimulus_20.wav
# Done audio number  211 / 27255
# file name  fold_0_participant_10005_stimulus_21.wav
# Done audio number  212 / 27255
# file name  fold_0_participant_10005_stimulus_23.wav
# Done audio number  213 / 27255
# file name  fold_0_participant_10005_stimulus_24.wav
# Done audio number  214 / 27255
# file name  fold_0_participant_10005_stimulus_25.wav
# Done audio number  215 / 27255
# file name  fold_0_participant_10005_stimulus_26.wav
# Done audio number  216 / 27255
# file name  fold_0_participant_10005_stimulus_27.wav
# Done audio number  217 / 27255
# file name  fold_0_participant_10005_stimulus_28.wav
# Done audio number  218 / 27255
# file name  fold_0_participant_10005_stimulus_29.wav
# Done audio number  219 / 27255
# file name  fold_0_participant_10005_stimulus_30.wav
# Done audio number  220 / 27255
# file name  fold_0_participant_10005_stimulus_31.wav
# Done audio number  221 / 27255
# file name  fold_0_participant_10005_stimulus_32.wav
# Done audio number  222 / 27255
# file name  fold_0_participant_10005_stimulus_33.wav
# Done audio number  223 / 27255
# file name  fold_0_participant_10005_stimulus_34.wav
# Done audio number  224 / 27255
# file name  fold_0_participant_10005_stimulus_35.wav
# Done audio number  225 / 27255
# file name  fold_0_participant_10005_stimulus_36.wav
# Done audio number  226 / 27255
# file name  fold_0_participant_10005_stimulus_37.wav
# Done audio number  227 / 27255
# file name  fold_0_participant_10005_stimulus_38.wav
# Done audio number  228 / 27255
# file name  fold_0_participant_10005_stimulus_39.wav
# Done audio number  229 / 27255
# file name  fold_0_participant_10005_stimulus_40.wav
# Done audio number  230 / 27255
# file name  fold_0_participant_10005_stimulus_41.wav
# Done audio number  231 / 27255
# file name  fold_0_participant_10005_stimulus_42.wav
# Done audio number  232 / 27255
# file name  fold_0_participant_10005_stimulus_43.wav
# Done audio number  233 / 27255
# file name  fold_0_participant_10005_stimulus_44.wav
# Done audio number  234 / 27255
# file name  fold_0_participant_10005_stimulus_45.wav
# Done audio number  235 / 27255
# file name  fold_0_participant_10005_stimulus_46.wav
# Done audio number  236 / 27255
# file name  fold_0_participant_10005_stimulus_47.wav
# Done audio number  237 / 27255
# file name  fold_0_participant_10005_stimulus_48.wav
# Done audio number  238 / 27255
# file name  fold_0_participant_10005_stimulus_49.wav
# Done audio number  239 / 27255
# file name  fold_0_participant_10005_stimulus_50.wav
# Done audio number  240 / 27255
# file name  fold_1_participant_00001_stimulus_02.wav
# Done audio number  241 / 27255
# file name  fold_1_participant_00001_stimulus_03.wav
# Done audio number  242 / 27255
# file name  fold_1_participant_00001_stimulus_04.wav
# Done audio number  243 / 27255
# file name  fold_1_participant_00001_stimulus_05.wav
# Done audio number  244 / 27255
# file name  fold_1_participant_00001_stimulus_06.wav
# Done audio number  245 / 27255
# file name  fold_1_participant_00001_stimulus_07.wav
# Done audio number  246 / 27255
# file name  fold_1_participant_00001_stimulus_08.wav
# Done audio number  247 / 27255
# file name  fold_1_participant_00001_stimulus_09.wav
# Done audio number  248 / 27255
# file name  fold_1_participant_00001_stimulus_10.wav
# Done audio number  249 / 27255
# file name  fold_1_participant_00001_stimulus_11.wav
# Done audio number  250 / 27255
# file name  fold_1_participant_00001_stimulus_12.wav
# Done audio number  251 / 27255
# file name  fold_1_participant_00001_stimulus_13.wav
# Done audio number  252 / 27255
# file name  fold_1_participant_00001_stimulus_14.wav
# Done audio number  253 / 27255
# file name  fold_1_participant_00001_stimulus_15.wav
# Done audio number  254 / 27255
# file name  fold_1_participant_00001_stimulus_16.wav
# Done audio number  255 / 27255
# file name  fold_1_participant_00001_stimulus_17.wav
# Done audio number  256 / 27255
# file name  fold_1_participant_00001_stimulus_18.wav
# Done audio number  257 / 27255
# file name  fold_1_participant_00001_stimulus_19.wav
# Done audio number  258 / 27255
# file name  fold_1_participant_00001_stimulus_21.wav
# Done audio number  259 / 27255
# file name  fold_1_participant_00001_stimulus_22.wav
# Done audio number  260 / 27255
# file name  fold_1_participant_00001_stimulus_23.wav
# Done audio number  261 / 27255
# file name  fold_1_participant_00001_stimulus_24.wav
# Done audio number  262 / 27255
# file name  fold_1_participant_00001_stimulus_25.wav
# Done audio number  263 / 27255
# file name  fold_1_participant_00001_stimulus_26.wav
# Done audio number  264 / 27255
# file name  fold_1_participant_00001_stimulus_27.wav
# Done audio number  265 / 27255
# file name  fold_1_participant_00001_stimulus_28.wav
# Done audio number  266 / 27255
# file name  fold_1_participant_00001_stimulus_29.wav
# Done audio number  267 / 27255
# file name  fold_1_participant_00001_stimulus_30.wav
# Done audio number  268 / 27255
# file name  fold_1_participant_00001_stimulus_31.wav
# Done audio number  269 / 27255
# file name  fold_1_participant_00001_stimulus_32.wav
# Done audio number  270 / 27255
# file name  fold_1_participant_00001_stimulus_33.wav
# Done audio number  271 / 27255
# file name  fold_1_participant_00001_stimulus_34.wav
# Done audio number  272 / 27255
# file name  fold_1_participant_00001_stimulus_35.wav
# Done audio number  273 / 27255
# file name  fold_1_participant_00001_stimulus_36.wav
# Done audio number  274 / 27255
# file name  fold_1_participant_00001_stimulus_37.wav
# Done audio number  275 / 27255
# file name  fold_1_participant_00001_stimulus_38.wav
# Done audio number  276 / 27255
# file name  fold_1_participant_00001_stimulus_39.wav
# Done audio number  277 / 27255
# file name  fold_1_participant_00001_stimulus_40.wav
# Done audio number  278 / 27255
# file name  fold_1_participant_00001_stimulus_41.wav
# Done audio number  279 / 27255
# file name  fold_1_participant_00001_stimulus_42.wav
# Done audio number  280 / 27255
# file name  fold_1_participant_00001_stimulus_43.wav
# Done audio number  281 / 27255
# file name  fold_1_participant_00001_stimulus_44.wav
# Done audio number  282 / 27255
# file name  fold_1_participant_00006_stimulus_02.wav
# Done audio number  283 / 27255
# file name  fold_1_participant_00006_stimulus_03.wav
# Done audio number  284 / 27255
# file name  fold_1_participant_00006_stimulus_04.wav
# Done audio number  285 / 27255
# file name  fold_1_participant_00006_stimulus_05.wav
# Done audio number  286 / 27255
# file name  fold_1_participant_00006_stimulus_06.wav
# Done audio number  287 / 27255
# file name  fold_1_participant_00006_stimulus_07.wav
# Done audio number  288 / 27255
# file name  fold_1_participant_00006_stimulus_08.wav
# Done audio number  289 / 27255
# file name  fold_1_participant_00006_stimulus_09.wav
# Done audio number  290 / 27255
# file name  fold_1_participant_00006_stimulus_10.wav
# Done audio number  291 / 27255
# file name  fold_1_participant_00006_stimulus_11.wav
# Done audio number  292 / 27255
# file name  fold_1_participant_00006_stimulus_12.wav
# Done audio number  293 / 27255
# file name  fold_1_participant_00006_stimulus_13.wav
# Done audio number  294 / 27255
# file name  fold_1_participant_00006_stimulus_14.wav
# Done audio number  295 / 27255
# file name  fold_1_participant_00006_stimulus_15.wav
# Done audio number  296 / 27255
# file name  fold_1_participant_00006_stimulus_16.wav
# Done audio number  297 / 27255
# file name  fold_1_participant_00006_stimulus_17.wav
# Done audio number  298 / 27255
# file name  fold_1_participant_00006_stimulus_18.wav
# Done audio number  299 / 27255
# file name  fold_1_participant_00006_stimulus_19.wav
# Done audio number  300 / 27255
# file name  fold_1_participant_00006_stimulus_20.wav
# Done audio number  301 / 27255
# file name  fold_1_participant_00006_stimulus_22.wav
# Done audio number  302 / 27255
# file name  fold_1_participant_00006_stimulus_23.wav
# Done audio number  303 / 27255
# file name  fold_1_participant_00006_stimulus_24.wav
# Done audio number  304 / 27255
# file name  fold_1_participant_00006_stimulus_25.wav
# Done audio number  305 / 27255
# file name  fold_1_participant_00006_stimulus_26.wav
# Done audio number  306 / 27255
# file name  fold_1_participant_00006_stimulus_27.wav
# Done audio number  307 / 27255
# file name  fold_1_participant_00006_stimulus_28.wav
# Done audio number  308 / 27255
# file name  fold_1_participant_00006_stimulus_29.wav
# Done audio number  309 / 27255
# file name  fold_1_participant_00006_stimulus_30.wav
# Done audio number  310 / 27255
# file name  fold_1_participant_00006_stimulus_31.wav
# Done audio number  311 / 27255
# file name  fold_1_participant_00006_stimulus_32.wav
# Done audio number  312 / 27255
# file name  fold_1_participant_00006_stimulus_33.wav
# Done audio number  313 / 27255
# file name  fold_1_participant_00006_stimulus_34.wav
# Done audio number  314 / 27255
# file name  fold_1_participant_00006_stimulus_35.wav
# Done audio number  315 / 27255
# file name  fold_1_participant_00006_stimulus_36.wav
# Done audio number  316 / 27255
# file name  fold_1_participant_00006_stimulus_37.wav
# Done audio number  317 / 27255
# file name  fold_1_participant_00006_stimulus_38.wav
# Done audio number  318 / 27255
# file name  fold_1_participant_00006_stimulus_39.wav
# Done audio number  319 / 27255
# file name  fold_1_participant_00006_stimulus_40.wav
# Done audio number  320 / 27255
# file name  fold_1_participant_00006_stimulus_41.wav
# Done audio number  321 / 27255
# file name  fold_1_participant_00006_stimulus_42.wav
# Done audio number  322 / 27255
# file name  fold_1_participant_00006_stimulus_43.wav
# Done audio number  323 / 27255
# file name  fold_1_participant_00006_stimulus_44.wav
# Done audio number  324 / 27255
# file name  fold_1_participant_00011_stimulus_02.wav
# Done audio number  325 / 27255
# file name  fold_1_participant_00011_stimulus_03.wav
# Done audio number  326 / 27255
# file name  fold_1_participant_00011_stimulus_04.wav
# Done audio number  327 / 27255
# file name  fold_1_participant_00011_stimulus_05.wav
# Done audio number  328 / 27255
# file name  fold_1_participant_00011_stimulus_06.wav
# Done audio number  329 / 27255
# file name  fold_1_participant_00011_stimulus_07.wav
# Done audio number  330 / 27255
# file name  fold_1_participant_00011_stimulus_08.wav
# Done audio number  331 / 27255
# file name  fold_1_participant_00011_stimulus_09.wav
# Done audio number  332 / 27255
# file name  fold_1_participant_00011_stimulus_10.wav
# Done audio number  333 / 27255
# file name  fold_1_participant_00011_stimulus_11.wav
# Done audio number  334 / 27255
# file name  fold_1_participant_00011_stimulus_12.wav
# Done audio number  335 / 27255
# file name  fold_1_participant_00011_stimulus_13.wav
# Done audio number  336 / 27255
# file name  fold_1_participant_00011_stimulus_14.wav
# Done audio number  337 / 27255
# file name  fold_1_participant_00011_stimulus_15.wav
# Done audio number  338 / 27255
# file name  fold_1_participant_00011_stimulus_16.wav
# Done audio number  339 / 27255
# file name  fold_1_participant_00011_stimulus_17.wav
# Done audio number  340 / 27255
# file name  fold_1_participant_00011_stimulus_18.wav
# Done audio number  341 / 27255
# file name  fold_1_participant_00011_stimulus_19.wav
# Done audio number  342 / 27255
# file name  fold_1_participant_00011_stimulus_20.wav
# Done audio number  343 / 27255
# file name  fold_1_participant_00011_stimulus_21.wav
# Done audio number  344 / 27255
# file name  fold_1_participant_00011_stimulus_23.wav
# Done audio number  345 / 27255
# file name  fold_1_participant_00011_stimulus_24.wav
# Done audio number  346 / 27255
# file name  fold_1_participant_00011_stimulus_25.wav
# Done audio number  347 / 27255
# file name  fold_1_participant_00011_stimulus_26.wav
# Done audio number  348 / 27255
# file name  fold_1_participant_00011_stimulus_27.wav
# Done audio number  349 / 27255
# file name  fold_1_participant_00011_stimulus_28.wav
# Done audio number  350 / 27255
# file name  fold_1_participant_00011_stimulus_29.wav
# Done audio number  351 / 27255
# file name  fold_1_participant_00011_stimulus_30.wav
# Done audio number  352 / 27255
# file name  fold_1_participant_00011_stimulus_31.wav
# Done audio number  353 / 27255
# file name  fold_1_participant_00011_stimulus_32.wav
# Done audio number  354 / 27255
# file name  fold_1_participant_00011_stimulus_33.wav
# Done audio number  355 / 27255
# file name  fold_1_participant_00011_stimulus_34.wav
# Done audio number  356 / 27255
# file name  fold_1_participant_00011_stimulus_35.wav
# Done audio number  357 / 27255
# file name  fold_1_participant_00011_stimulus_36.wav
# Done audio number  358 / 27255
# file name  fold_1_participant_00011_stimulus_37.wav
# Done audio number  359 / 27255
# file name  fold_1_participant_00011_stimulus_38.wav
# Done audio number  360 / 27255
# file name  fold_1_participant_00011_stimulus_39.wav
# Done audio number  361 / 27255
# file name  fold_1_participant_00011_stimulus_40.wav
# Done audio number  362 / 27255
# file name  fold_1_participant_00011_stimulus_41.wav
# Done audio number  363 / 27255
# file name  fold_1_participant_00011_stimulus_42.wav
# Done audio number  364 / 27255
# file name  fold_1_participant_00011_stimulus_43.wav
# Done audio number  365 / 27255
# file name  fold_1_participant_00011_stimulus_44.wav
# Done audio number  366 / 27255
# file name  fold_1_participant_00016_stimulus_02.wav
# Done audio number  367 / 27255
# file name  fold_1_participant_00016_stimulus_03.wav
# Done audio number  368 / 27255
# file name  fold_1_participant_00016_stimulus_04.wav
# Done audio number  369 / 27255
# file name  fold_1_participant_00016_stimulus_05.wav
# Done audio number  370 / 27255
# file name  fold_1_participant_00016_stimulus_06.wav
# Done audio number  371 / 27255
# file name  fold_1_participant_00016_stimulus_07.wav
# Done audio number  372 / 27255
# file name  fold_1_participant_00016_stimulus_08.wav
# Done audio number  373 / 27255
# file name  fold_1_participant_00016_stimulus_09.wav
# Done audio number  374 / 27255
# file name  fold_1_participant_00016_stimulus_10.wav
# Done audio number  375 / 27255
# file name  fold_1_participant_00016_stimulus_11.wav
# Done audio number  376 / 27255
# file name  fold_1_participant_00016_stimulus_12.wav
# Done audio number  377 / 27255
# file name  fold_1_participant_00016_stimulus_13.wav
# Done audio number  378 / 27255
# file name  fold_1_participant_00016_stimulus_14.wav
# Done audio number  379 / 27255
# file name  fold_1_participant_00016_stimulus_15.wav
# Done audio number  380 / 27255
# file name  fold_1_participant_00016_stimulus_16.wav
# Done audio number  381 / 27255
# file name  fold_1_participant_00016_stimulus_18.wav
# Done audio number  382 / 27255
# file name  fold_1_participant_00016_stimulus_19.wav
# Done audio number  383 / 27255
# file name  fold_1_participant_00016_stimulus_20.wav
# Done audio number  384 / 27255
# file name  fold_1_participant_00016_stimulus_21.wav
# Done audio number  385 / 27255
# file name  fold_1_participant_00016_stimulus_22.wav
# Done audio number  386 / 27255
# file name  fold_1_participant_00016_stimulus_23.wav
# Done audio number  387 / 27255
# file name  fold_1_participant_00016_stimulus_24.wav
# Done audio number  388 / 27255
# file name  fold_1_participant_00016_stimulus_25.wav
# Done audio number  389 / 27255
# file name  fold_1_participant_00016_stimulus_26.wav
# Done audio number  390 / 27255
# file name  fold_1_participant_00016_stimulus_27.wav
# Done audio number  391 / 27255
# file name  fold_1_participant_00016_stimulus_28.wav
# Done audio number  392 / 27255
# file name  fold_1_participant_00016_stimulus_29.wav
# Done audio number  393 / 27255
# file name  fold_1_participant_00016_stimulus_30.wav
# Done audio number  394 / 27255
# file name  fold_1_participant_00016_stimulus_31.wav
# Done audio number  395 / 27255
# file name  fold_1_participant_00016_stimulus_32.wav
# Done audio number  396 / 27255
# file name  fold_1_participant_00016_stimulus_33.wav
# Done audio number  397 / 27255
# file name  fold_1_participant_00016_stimulus_34.wav
# Done audio number  398 / 27255
# file name  fold_1_participant_00016_stimulus_35.wav
# Done audio number  399 / 27255
# file name  fold_1_participant_00016_stimulus_36.wav
# Done audio number  400 / 27255
# file name  fold_1_participant_00016_stimulus_37.wav
# Done audio number  401 / 27255
# file name  fold_1_participant_00016_stimulus_38.wav
# Done audio number  402 / 27255
# file name  fold_1_participant_00016_stimulus_39.wav
# Done audio number  403 / 27255
# file name  fold_1_participant_00016_stimulus_40.wav
# Done audio number  404 / 27255
# file name  fold_1_participant_00016_stimulus_41.wav
# Done audio number  405 / 27255
# file name  fold_1_participant_00016_stimulus_42.wav
# Done audio number  406 / 27255
# file name  fold_1_participant_00016_stimulus_43.wav
# Done audio number  407 / 27255
# file name  fold_1_participant_00016_stimulus_44.wav
# Done audio number  408 / 27255
# file name  fold_1_participant_00021_stimulus_02.wav
# Done audio number  409 / 27255
# file name  fold_1_participant_00021_stimulus_03.wav
# Done audio number  410 / 27255
# file name  fold_1_participant_00021_stimulus_04.wav
# Done audio number  411 / 27255
# file name  fold_1_participant_00021_stimulus_05.wav
# Done audio number  412 / 27255
# file name  fold_1_participant_00021_stimulus_06.wav
# Done audio number  413 / 27255
# file name  fold_1_participant_00021_stimulus_07.wav
# Done audio number  414 / 27255
# file name  fold_1_participant_00021_stimulus_08.wav
# Done audio number  415 / 27255
# file name  fold_1_participant_00021_stimulus_09.wav
# Done audio number  416 / 27255
# file name  fold_1_participant_00021_stimulus_10.wav
# Done audio number  417 / 27255
# file name  fold_1_participant_00021_stimulus_11.wav
# Done audio number  418 / 27255
# file name  fold_1_participant_00021_stimulus_12.wav
# Done audio number  419 / 27255
# file name  fold_1_participant_00021_stimulus_13.wav
# Done audio number  420 / 27255
# file name  fold_1_participant_00021_stimulus_14.wav
# Done audio number  421 / 27255
# file name  fold_1_participant_00021_stimulus_15.wav
# Done audio number  422 / 27255
# file name  fold_1_participant_00021_stimulus_16.wav
# Done audio number  423 / 27255
# file name  fold_1_participant_00021_stimulus_17.wav
# Done audio number  424 / 27255
# file name  fold_1_participant_00021_stimulus_18.wav
# Done audio number  425 / 27255
# file name  fold_1_participant_00021_stimulus_20.wav
# Done audio number  426 / 27255
# file name  fold_1_participant_00021_stimulus_21.wav
# Done audio number  427 / 27255
# file name  fold_1_participant_00021_stimulus_22.wav
# Done audio number  428 / 27255
# file name  fold_1_participant_00021_stimulus_23.wav
# Done audio number  429 / 27255
# file name  fold_1_participant_00021_stimulus_24.wav
# Done audio number  430 / 27255
# file name  fold_1_participant_00021_stimulus_25.wav
# Done audio number  431 / 27255
# file name  fold_1_participant_00021_stimulus_26.wav
# Done audio number  432 / 27255
# file name  fold_1_participant_00021_stimulus_27.wav
# Done audio number  433 / 27255
# file name  fold_1_participant_00021_stimulus_28.wav
# Done audio number  434 / 27255
# file name  fold_1_participant_00021_stimulus_29.wav
# Done audio number  435 / 27255
# file name  fold_1_participant_00021_stimulus_30.wav
# Done audio number  436 / 27255
# file name  fold_1_participant_00021_stimulus_31.wav
# Done audio number  437 / 27255
# file name  fold_1_participant_00021_stimulus_32.wav
# Done audio number  438 / 27255
# file name  fold_1_participant_00021_stimulus_33.wav
# Done audio number  439 / 27255
# file name  fold_1_participant_00021_stimulus_34.wav
# Done audio number  440 / 27255
# file name  fold_1_participant_00021_stimulus_35.wav
# Done audio number  441 / 27255
# file name  fold_1_participant_00021_stimulus_36.wav
# Done audio number  442 / 27255
# file name  fold_1_participant_00021_stimulus_37.wav
# Done audio number  443 / 27255
# file name  fold_1_participant_00021_stimulus_38.wav
# Done audio number  444 / 27255
# file name  fold_1_participant_00021_stimulus_39.wav
# Done audio number  445 / 27255
# file name  fold_1_participant_00021_stimulus_40.wav
# Done audio number  446 / 27255
# file name  fold_1_participant_00021_stimulus_41.wav
# Done audio number  447 / 27255
# file name  fold_1_participant_00021_stimulus_42.wav
# Done audio number  448 / 27255
# file name  fold_1_participant_00021_stimulus_43.wav
# Done audio number  449 / 27255
# file name  fold_1_participant_00021_stimulus_44.wav
# Done audio number  450 / 27255
# file name  fold_1_participant_00026_stimulus_02.wav
# Done audio number  451 / 27255
# file name  fold_1_participant_00026_stimulus_03.wav
# Done audio number  452 / 27255
# file name  fold_1_participant_00026_stimulus_04.wav
# Done audio number  453 / 27255
# file name  fold_1_participant_00026_stimulus_05.wav
# Done audio number  454 / 27255
# file name  fold_1_participant_00026_stimulus_06.wav
# Done audio number  455 / 27255
# file name  fold_1_participant_00026_stimulus_07.wav
# Done audio number  456 / 27255
# file name  fold_1_participant_00026_stimulus_08.wav
# Done audio number  457 / 27255
# file name  fold_1_participant_00026_stimulus_09.wav
# Done audio number  458 / 27255
# file name  fold_1_participant_00026_stimulus_10.wav
# Done audio number  459 / 27255
# file name  fold_1_participant_00026_stimulus_11.wav
# Done audio number  460 / 27255
# file name  fold_1_participant_00026_stimulus_12.wav
# Done audio number  461 / 27255
# file name  fold_1_participant_00026_stimulus_13.wav
# Done audio number  462 / 27255
# file name  fold_1_participant_00026_stimulus_14.wav
# Done audio number  463 / 27255
# file name  fold_1_participant_00026_stimulus_15.wav
# Done audio number  464 / 27255
# file name  fold_1_participant_00026_stimulus_16.wav
# Done audio number  465 / 27255
# file name  fold_1_participant_00026_stimulus_17.wav
# Done audio number  466 / 27255
# file name  fold_1_participant_00026_stimulus_18.wav
# Done audio number  467 / 27255
# file name  fold_1_participant_00026_stimulus_19.wav
# Done audio number  468 / 27255
# file name  fold_1_participant_00026_stimulus_21.wav
# Done audio number  469 / 27255
# file name  fold_1_participant_00026_stimulus_22.wav
# Done audio number  470 / 27255
# file name  fold_1_participant_00026_stimulus_23.wav
# Done audio number  471 / 27255
# file name  fold_1_participant_00026_stimulus_24.wav
# Done audio number  472 / 27255
# file name  fold_1_participant_00026_stimulus_25.wav
# Done audio number  473 / 27255
# file name  fold_1_participant_00026_stimulus_26.wav
# Done audio number  474 / 27255
# file name  fold_1_participant_00026_stimulus_27.wav
# Done audio number  475 / 27255
# file name  fold_1_participant_00026_stimulus_28.wav
# Done audio number  476 / 27255
# file name  fold_1_participant_00026_stimulus_29.wav
# Done audio number  477 / 27255
# file name  fold_1_participant_00026_stimulus_30.wav
# Done audio number  478 / 27255
# file name  fold_1_participant_00026_stimulus_31.wav
# Done audio number  479 / 27255
# file name  fold_1_participant_00026_stimulus_32.wav
# Done audio number  480 / 27255
# file name  fold_1_participant_00026_stimulus_33.wav
# Done audio number  481 / 27255
# file name  fold_1_participant_00026_stimulus_34.wav
# Done audio number  482 / 27255
# file name  fold_1_participant_00026_stimulus_35.wav
# Done audio number  483 / 27255
# file name  fold_1_participant_00026_stimulus_36.wav
# Done audio number  484 / 27255
# file name  fold_1_participant_00026_stimulus_37.wav
# Done audio number  485 / 27255
# file name  fold_1_participant_00026_stimulus_38.wav
# Done audio number  486 / 27255
# file name  fold_1_participant_00026_stimulus_39.wav
# Done audio number  487 / 27255
# file name  fold_1_participant_00026_stimulus_40.wav
# Done audio number  488 / 27255
# file name  fold_1_participant_00026_stimulus_41.wav
# Done audio number  489 / 27255
# file name  fold_1_participant_00026_stimulus_42.wav
# Done audio number  490 / 27255
# file name  fold_1_participant_00026_stimulus_43.wav
# Done audio number  491 / 27255
# file name  fold_1_participant_00026_stimulus_44.wav
# Done audio number  492 / 27255
# file name  fold_1_participant_00031_stimulus_02.wav
# Done audio number  493 / 27255
# file name  fold_1_participant_00031_stimulus_03.wav
# Done audio number  494 / 27255
# file name  fold_1_participant_00031_stimulus_04.wav
# Done audio number  495 / 27255
# file name  fold_1_participant_00031_stimulus_05.wav
# Done audio number  496 / 27255
# file name  fold_1_participant_00031_stimulus_06.wav
# Done audio number  497 / 27255
# file name  fold_1_participant_00031_stimulus_07.wav
# Done audio number  498 / 27255
# file name  fold_1_participant_00031_stimulus_08.wav
# Done audio number  499 / 27255
# file name  fold_1_participant_00031_stimulus_09.wav
# Done audio number  500 / 27255
# file name  fold_1_participant_00031_stimulus_10.wav
# Done audio number  501 / 27255
# file name  fold_1_participant_00031_stimulus_11.wav
# Done audio number  502 / 27255
# file name  fold_1_participant_00031_stimulus_12.wav
# Done audio number  503 / 27255
# file name  fold_1_participant_00031_stimulus_13.wav
# Done audio number  504 / 27255
# file name  fold_1_participant_00031_stimulus_14.wav
# Done audio number  505 / 27255
# file name  fold_1_participant_00031_stimulus_15.wav
# Done audio number  506 / 27255
# file name  fold_1_participant_00031_stimulus_16.wav
# Done audio number  507 / 27255
# file name  fold_1_participant_00031_stimulus_17.wav
# Done audio number  508 / 27255
# file name  fold_1_participant_00031_stimulus_18.wav
# Done audio number  509 / 27255
# file name  fold_1_participant_00031_stimulus_19.wav
# Done audio number  510 / 27255
# file name  fold_1_participant_00031_stimulus_20.wav
# Done audio number  511 / 27255
# file name  fold_1_participant_00031_stimulus_21.wav
# Done audio number  512 / 27255
# file name  fold_1_participant_00031_stimulus_22.wav
# Done audio number  513 / 27255
# file name  fold_1_participant_00031_stimulus_23.wav
# Done audio number  514 / 27255
# file name  fold_1_participant_00031_stimulus_24.wav
# Done audio number  515 / 27255
# file name  fold_1_participant_00031_stimulus_25.wav
# Done audio number  516 / 27255
# file name  fold_1_participant_00031_stimulus_27.wav
# Done audio number  517 / 27255
# file name  fold_1_participant_00031_stimulus_28.wav
# Done audio number  518 / 27255
# file name  fold_1_participant_00031_stimulus_29.wav
# Done audio number  519 / 27255
# file name  fold_1_participant_00031_stimulus_30.wav
# Done audio number  520 / 27255
# file name  fold_1_participant_00031_stimulus_31.wav
# Done audio number  521 / 27255
# file name  fold_1_participant_00031_stimulus_32.wav
# Done audio number  522 / 27255
# file name  fold_1_participant_00031_stimulus_33.wav
# Done audio number  523 / 27255
# file name  fold_1_participant_00031_stimulus_34.wav
# Done audio number  524 / 27255
# file name  fold_1_participant_00031_stimulus_35.wav
# Done audio number  525 / 27255
# file name  fold_1_participant_00031_stimulus_36.wav
# Done audio number  526 / 27255
# file name  fold_1_participant_00031_stimulus_37.wav
# Done audio number  527 / 27255
# file name  fold_1_participant_00031_stimulus_38.wav
# Done audio number  528 / 27255
# file name  fold_1_participant_00031_stimulus_39.wav
# Done audio number  529 / 27255
# file name  fold_1_participant_00031_stimulus_40.wav
# Done audio number  530 / 27255
# file name  fold_1_participant_00031_stimulus_41.wav
# Done audio number  531 / 27255
# file name  fold_1_participant_00031_stimulus_42.wav
# Done audio number  532 / 27255
# file name  fold_1_participant_00031_stimulus_43.wav
# Done audio number  533 / 27255
# file name  fold_1_participant_00031_stimulus_44.wav
# Done audio number  534 / 27255
# file name  fold_1_participant_00036_stimulus_02.wav
# Done audio number  535 / 27255
# file name  fold_1_participant_00036_stimulus_03.wav
# Done audio number  536 / 27255
# file name  fold_1_participant_00036_stimulus_04.wav
# Done audio number  537 / 27255
# file name  fold_1_participant_00036_stimulus_05.wav
# Done audio number  538 / 27255
# file name  fold_1_participant_00036_stimulus_06.wav
# Done audio number  539 / 27255
# file name  fold_1_participant_00036_stimulus_07.wav
# Done audio number  540 / 27255
# file name  fold_1_participant_00036_stimulus_08.wav
# Done audio number  541 / 27255
# file name  fold_1_participant_00036_stimulus_09.wav
# Done audio number  542 / 27255
# file name  fold_1_participant_00036_stimulus_10.wav
# Done audio number  543 / 27255
# file name  fold_1_participant_00036_stimulus_11.wav
# Done audio number  544 / 27255
# file name  fold_1_participant_00036_stimulus_12.wav
# Done audio number  545 / 27255
# file name  fold_1_participant_00036_stimulus_13.wav
# Done audio number  546 / 27255
# file name  fold_1_participant_00036_stimulus_14.wav
# Done audio number  547 / 27255
# file name  fold_1_participant_00036_stimulus_15.wav
# Done audio number  548 / 27255
# file name  fold_1_participant_00036_stimulus_16.wav
# Done audio number  549 / 27255
# file name  fold_1_participant_00036_stimulus_17.wav
# Done audio number  550 / 27255
# file name  fold_1_participant_00036_stimulus_18.wav
# Done audio number  551 / 27255
# file name  fold_1_participant_00036_stimulus_19.wav
# Done audio number  552 / 27255
# file name  fold_1_participant_00036_stimulus_20.wav
# Done audio number  553 / 27255
# file name  fold_1_participant_00036_stimulus_22.wav
# Done audio number  554 / 27255
# file name  fold_1_participant_00036_stimulus_23.wav
# Done audio number  555 / 27255
# file name  fold_1_participant_00036_stimulus_24.wav
# Done audio number  556 / 27255
# file name  fold_1_participant_00036_stimulus_25.wav
# Done audio number  557 / 27255
# file name  fold_1_participant_00036_stimulus_26.wav
# Done audio number  558 / 27255
# file name  fold_1_participant_00036_stimulus_27.wav
# Done audio number  559 / 27255
# file name  fold_1_participant_00036_stimulus_28.wav
# Done audio number  560 / 27255
# file name  fold_1_participant_00036_stimulus_29.wav
# Done audio number  561 / 27255
# file name  fold_1_participant_00036_stimulus_30.wav
# Done audio number  562 / 27255
# file name  fold_1_participant_00036_stimulus_31.wav
# Done audio number  563 / 27255
# file name  fold_1_participant_00036_stimulus_32.wav
# Done audio number  564 / 27255
# file name  fold_1_participant_00036_stimulus_33.wav
# Done audio number  565 / 27255
# file name  fold_1_participant_00036_stimulus_34.wav
# Done audio number  566 / 27255
# file name  fold_1_participant_00036_stimulus_35.wav
# Done audio number  567 / 27255
# file name  fold_1_participant_00036_stimulus_36.wav
# Done audio number  568 / 27255
# file name  fold_1_participant_00036_stimulus_37.wav
# Done audio number  569 / 27255
# file name  fold_1_participant_00036_stimulus_38.wav
# Done audio number  570 / 27255
# file name  fold_1_participant_00036_stimulus_39.wav
# Done audio number  571 / 27255
# file name  fold_1_participant_00036_stimulus_40.wav
# Done audio number  572 / 27255
# file name  fold_1_participant_00036_stimulus_41.wav
# Done audio number  573 / 27255
# file name  fold_1_participant_00036_stimulus_42.wav
# Done audio number  574 / 27255
# file name  fold_1_participant_00036_stimulus_43.wav
# Done audio number  575 / 27255
# file name  fold_1_participant_00036_stimulus_44.wav
# Done audio number  576 / 27255
# file name  fold_1_participant_00041_stimulus_02.wav
# Done audio number  577 / 27255
# file name  fold_1_participant_00041_stimulus_03.wav
# Done audio number  578 / 27255
# file name  fold_1_participant_00041_stimulus_04.wav
# Done audio number  579 / 27255
# ...
# file name  fold_5_participant_00580_stimulus_24.wav
# Done audio number  25253 / 27255
# file name  fold_5_participant_00580_stimulus_26.wav
# Done audio number  25254 / 27255
# file name  fold_5_participant_00580_stimulus_27.wav
# Done audio number  25255 / 27255
# file name  fold_5_participant_00580_stimulus_28.wav
# Done audio number  25256 / 27255
# file name  fold_5_participant_00580_stimulus_29.wav
# Done audio number  25257 / 27255
# file name  fold_5_participant_00580_stimulus_30.wav
# Done audio number  25258 / 27255
# file name  fold_5_participant_00580_stimulus_31.wav
# Done audio number  25259 / 27255
# file name  fold_5_participant_00580_stimulus_32.wav
# Done audio number  25260 / 27255
# file name  fold_5_participant_00580_stimulus_33.wav
# Done audio number  25261 / 27255
# file name  fold_5_participant_00580_stimulus_34.wav
# Done audio number  25262 / 27255
# file name  fold_5_participant_00580_stimulus_35.wav
# Done audio number  25263 / 27255
# file name  fold_5_participant_00580_stimulus_36.wav
# Done audio number  25264 / 27255
# file name  fold_5_participant_00580_stimulus_37.wav
# Done audio number  25265 / 27255
# file name  fold_5_participant_00580_stimulus_38.wav
# Done audio number  25266 / 27255
# file name  fold_5_participant_00580_stimulus_39.wav
# Done audio number  25267 / 27255
# file name  fold_5_participant_00580_stimulus_40.wav
# Done audio number  25268 / 27255
# file name  fold_5_participant_00580_stimulus_41.wav
# Done audio number  25269 / 27255
# file name  fold_5_participant_00580_stimulus_42.wav
# Done audio number  25270 / 27255
# file name  fold_5_participant_00580_stimulus_43.wav
# Done audio number  25271 / 27255
# file name  fold_5_participant_00580_stimulus_44.wav
# Done audio number  25272 / 27255
# file name  fold_5_participant_00585_stimulus_02.wav
# Done audio number  25273 / 27255
# file name  fold_5_participant_00585_stimulus_03.wav
# Done audio number  25274 / 27255
# file name  fold_5_participant_00585_stimulus_04.wav
# Done audio number  25275 / 27255
# file name  fold_5_participant_00585_stimulus_05.wav
# Done audio number  25276 / 27255
# file name  fold_5_participant_00585_stimulus_06.wav
# Done audio number  25277 / 27255
# file name  fold_5_participant_00585_stimulus_07.wav
# Done audio number  25278 / 27255
# file name  fold_5_participant_00585_stimulus_08.wav
# Done audio number  25279 / 27255
# file name  fold_5_participant_00585_stimulus_09.wav
# Done audio number  25280 / 27255
# file name  fold_5_participant_00585_stimulus_10.wav
# Done audio number  25281 / 27255
# file name  fold_5_participant_00585_stimulus_11.wav
# Done audio number  25282 / 27255
# file name  fold_5_participant_00585_stimulus_12.wav
# Done audio number  25283 / 27255
# file name  fold_5_participant_00585_stimulus_13.wav
# Done audio number  25284 / 27255
# file name  fold_5_participant_00585_stimulus_14.wav
# Done audio number  25285 / 27255
# file name  fold_5_participant_00585_stimulus_15.wav
# Done audio number  25286 / 27255
# file name  fold_5_participant_00585_stimulus_16.wav
# Done audio number  25287 / 27255
# file name  fold_5_participant_00585_stimulus_17.wav
# Done audio number  25288 / 27255
# file name  fold_5_participant_00585_stimulus_18.wav
# Done audio number  25289 / 27255
# file name  fold_5_participant_00585_stimulus_19.wav
# Done audio number  25290 / 27255
# file name  fold_5_participant_00585_stimulus_20.wav
# Done audio number  25291 / 27255
# file name  fold_5_participant_00585_stimulus_21.wav
# Done audio number  25292 / 27255
# file name  fold_5_participant_00585_stimulus_22.wav
# Done audio number  25293 / 27255
# file name  fold_5_participant_00585_stimulus_23.wav
# Done audio number  25294 / 27255
# file name  fold_5_participant_00585_stimulus_24.wav
# Done audio number  25295 / 27255
# file name  fold_5_participant_00585_stimulus_25.wav
# Done audio number  25296 / 27255
# file name  fold_5_participant_00585_stimulus_27.wav
# Done audio number  25297 / 27255
# file name  fold_5_participant_00585_stimulus_28.wav
# Done audio number  25298 / 27255
# file name  fold_5_participant_00585_stimulus_29.wav
# Done audio number  25299 / 27255
# file name  fold_5_participant_00585_stimulus_30.wav
# Done audio number  25300 / 27255
# file name  fold_5_participant_00585_stimulus_31.wav
# Done audio number  25301 / 27255
# file name  fold_5_participant_00585_stimulus_32.wav
# Done audio number  25302 / 27255
# file name  fold_5_participant_00585_stimulus_33.wav
# Done audio number  25303 / 27255
# file name  fold_5_participant_00585_stimulus_34.wav
# Done audio number  25304 / 27255
# file name  fold_5_participant_00585_stimulus_35.wav
# Done audio number  25305 / 27255
# file name  fold_5_participant_00585_stimulus_36.wav
# Done audio number  25306 / 27255
# file name  fold_5_participant_00585_stimulus_37.wav
# Done audio number  25307 / 27255
# file name  fold_5_participant_00585_stimulus_38.wav
# Done audio number  25308 / 27255
# file name  fold_5_participant_00585_stimulus_39.wav
# Done audio number  25309 / 27255
# file name  fold_5_participant_00585_stimulus_40.wav
# Done audio number  25310 / 27255
# file name  fold_5_participant_00585_stimulus_41.wav
# Done audio number  25311 / 27255
# file name  fold_5_participant_00585_stimulus_42.wav
# Done audio number  25312 / 27255
# file name  fold_5_participant_00585_stimulus_43.wav
# Done audio number  25313 / 27255
# file name  fold_5_participant_00585_stimulus_44.wav
# Done audio number  25314 / 27255
# file name  fold_5_participant_00590_stimulus_02.wav
# Done audio number  25315 / 27255
# file name  fold_5_participant_00590_stimulus_03.wav
# Done audio number  25316 / 27255
# file name  fold_5_participant_00590_stimulus_04.wav
# Done audio number  25317 / 27255
# file name  fold_5_participant_00590_stimulus_05.wav
# Done audio number  25318 / 27255
# file name  fold_5_participant_00590_stimulus_06.wav
# Done audio number  25319 / 27255
# file name  fold_5_participant_00590_stimulus_07.wav
# Done audio number  25320 / 27255
# file name  fold_5_participant_00590_stimulus_08.wav
# Done audio number  25321 / 27255
# file name  fold_5_participant_00590_stimulus_09.wav
# Done audio number  25322 / 27255
# file name  fold_5_participant_00590_stimulus_10.wav
# Done audio number  25323 / 27255
# file name  fold_5_participant_00590_stimulus_11.wav
# Done audio number  25324 / 27255
# file name  fold_5_participant_00590_stimulus_12.wav
# Done audio number  25325 / 27255
# file name  fold_5_participant_00590_stimulus_13.wav
# Done audio number  25326 / 27255
# file name  fold_5_participant_00590_stimulus_14.wav
# Done audio number  25327 / 27255
# file name  fold_5_participant_00590_stimulus_15.wav
# Done audio number  25328 / 27255
# file name  fold_5_participant_00590_stimulus_16.wav
# Done audio number  25329 / 27255
# file name  fold_5_participant_00590_stimulus_17.wav
# Done audio number  25330 / 27255
# file name  fold_5_participant_00590_stimulus_18.wav
# Done audio number  25331 / 27255
# file name  fold_5_participant_00590_stimulus_19.wav
# Done audio number  25332 / 27255
# file name  fold_5_participant_00590_stimulus_20.wav
# Done audio number  25333 / 27255
# file name  fold_5_participant_00590_stimulus_21.wav
# Done audio number  25334 / 27255
# file name  fold_5_participant_00590_stimulus_22.wav
# Done audio number  25335 / 27255
# file name  fold_5_participant_00590_stimulus_23.wav
# Done audio number  25336 / 27255
# file name  fold_5_participant_00590_stimulus_24.wav
# Done audio number  25337 / 27255
# file name  fold_5_participant_00590_stimulus_26.wav
# Done audio number  25338 / 27255
# file name  fold_5_participant_00590_stimulus_27.wav
# Done audio number  25339 / 27255
# file name  fold_5_participant_00590_stimulus_28.wav
# Done audio number  25340 / 27255
# file name  fold_5_participant_00590_stimulus_29.wav
# Done audio number  25341 / 27255
# file name  fold_5_participant_00590_stimulus_30.wav
# Done audio number  25342 / 27255
# file name  fold_5_participant_00590_stimulus_31.wav
# Done audio number  25343 / 27255
# file name  fold_5_participant_00590_stimulus_32.wav
# Done audio number  25344 / 27255
# file name  fold_5_participant_00590_stimulus_33.wav
# Done audio number  25345 / 27255
# file name  fold_5_participant_00590_stimulus_34.wav
# Done audio number  25346 / 27255
# file name  fold_5_participant_00590_stimulus_35.wav
# Done audio number  25347 / 27255
# file name  fold_5_participant_00590_stimulus_36.wav
# Done audio number  25348 / 27255
# file name  fold_5_participant_00590_stimulus_37.wav
# Done audio number  25349 / 27255
# file name  fold_5_participant_00590_stimulus_38.wav
# Done audio number  25350 / 27255
# file name  fold_5_participant_00590_stimulus_39.wav
# Done audio number  25351 / 27255
# file name  fold_5_participant_00590_stimulus_40.wav
# Done audio number  25352 / 27255
# file name  fold_5_participant_00590_stimulus_41.wav
# Done audio number  25353 / 27255
# file name  fold_5_participant_00590_stimulus_42.wav
# Done audio number  25354 / 27255
# file name  fold_5_participant_00590_stimulus_43.wav
# Done audio number  25355 / 27255
# file name  fold_5_participant_00590_stimulus_44.wav
# Done audio number  25356 / 27255
# file name  fold_5_participant_00595_stimulus_02.wav
# Done audio number  25357 / 27255
# file name  fold_5_participant_00595_stimulus_03.wav
# Done audio number  25358 / 27255
# file name  fold_5_participant_00595_stimulus_04.wav
# Done audio number  25359 / 27255
# file name  fold_5_participant_00595_stimulus_05.wav
# Done audio number  25360 / 27255
# file name  fold_5_participant_00595_stimulus_06.wav
# Done audio number  25361 / 27255
# file name  fold_5_participant_00595_stimulus_07.wav
# Done audio number  25362 / 27255
# file name  fold_5_participant_00595_stimulus_08.wav
# Done audio number  25363 / 27255
# file name  fold_5_participant_00595_stimulus_09.wav
# Done audio number  25364 / 27255
# file name  fold_5_participant_00595_stimulus_10.wav
# Done audio number  25365 / 27255
# file name  fold_5_participant_00595_stimulus_11.wav
# Done audio number  25366 / 27255
# file name  fold_5_participant_00595_stimulus_12.wav
# Done audio number  25367 / 27255
# file name  fold_5_participant_00595_stimulus_13.wav
# Done audio number  25368 / 27255
# file name  fold_5_participant_00595_stimulus_14.wav
# Done audio number  25369 / 27255
# file name  fold_5_participant_00595_stimulus_15.wav
# Done audio number  25370 / 27255
# file name  fold_5_participant_00595_stimulus_16.wav
# Done audio number  25371 / 27255
# file name  fold_5_participant_00595_stimulus_17.wav
# Done audio number  25372 / 27255
# file name  fold_5_participant_00595_stimulus_18.wav
# Done audio number  25373 / 27255
# file name  fold_5_participant_00595_stimulus_19.wav
# Done audio number  25374 / 27255
# file name  fold_5_participant_00595_stimulus_20.wav
# Done audio number  25375 / 27255
# file name  fold_5_participant_00595_stimulus_22.wav
# Done audio number  25376 / 27255
# file name  fold_5_participant_00595_stimulus_23.wav
# Done audio number  25377 / 27255
# file name  fold_5_participant_00595_stimulus_24.wav
# Done audio number  25378 / 27255
# file name  fold_5_participant_00595_stimulus_25.wav
# Done audio number  25379 / 27255
# file name  fold_5_participant_00595_stimulus_26.wav
# Done audio number  25380 / 27255
# file name  fold_5_participant_00595_stimulus_27.wav
# Done audio number  25381 / 27255
# file name  fold_5_participant_00595_stimulus_28.wav
# Done audio number  25382 / 27255
# file name  fold_5_participant_00595_stimulus_29.wav
# Done audio number  25383 / 27255
# file name  fold_5_participant_00595_stimulus_30.wav
# Done audio number  25384 / 27255
# file name  fold_5_participant_00595_stimulus_31.wav
# Done audio number  25385 / 27255
# file name  fold_5_participant_00595_stimulus_32.wav
# Done audio number  25386 / 27255
# file name  fold_5_participant_00595_stimulus_33.wav
# Done audio number  25387 / 27255
# file name  fold_5_participant_00595_stimulus_34.wav
# Done audio number  25388 / 27255
# file name  fold_5_participant_00595_stimulus_35.wav
# Done audio number  25389 / 27255
# file name  fold_5_participant_00595_stimulus_36.wav
# Done audio number  25390 / 27255
# file name  fold_5_participant_00595_stimulus_37.wav
# Done audio number  25391 / 27255
# file name  fold_5_participant_00595_stimulus_38.wav
# Done audio number  25392 / 27255
# file name  fold_5_participant_00595_stimulus_39.wav
# Done audio number  25393 / 27255
# file name  fold_5_participant_00595_stimulus_40.wav
# Done audio number  25394 / 27255
# file name  fold_5_participant_00595_stimulus_41.wav
# Done audio number  25395 / 27255
# file name  fold_5_participant_00595_stimulus_42.wav
# Done audio number  25396 / 27255
# file name  fold_5_participant_00595_stimulus_43.wav
# Done audio number  25397 / 27255
# file name  fold_5_participant_00595_stimulus_44.wav
# Done audio number  25398 / 27255
# file name  fold_5_participant_00600_stimulus_02.wav
# Done audio number  25399 / 27255
# file name  fold_5_participant_00600_stimulus_03.wav
# Done audio number  25400 / 27255
# file name  fold_5_participant_00600_stimulus_04.wav
# Done audio number  25401 / 27255
# file name  fold_5_participant_00600_stimulus_05.wav
# Done audio number  25402 / 27255
# file name  fold_5_participant_00600_stimulus_06.wav
# Done audio number  25403 / 27255
# file name  fold_5_participant_00600_stimulus_07.wav
# Done audio number  25404 / 27255
# file name  fold_5_participant_00600_stimulus_08.wav
# Done audio number  25405 / 27255
# file name  fold_5_participant_00600_stimulus_09.wav
# Done audio number  25406 / 27255
# file name  fold_5_participant_00600_stimulus_10.wav
# Done audio number  25407 / 27255
# file name  fold_5_participant_00600_stimulus_11.wav
# Done audio number  25408 / 27255
# file name  fold_5_participant_00600_stimulus_12.wav
# Done audio number  25409 / 27255
# file name  fold_5_participant_00600_stimulus_13.wav
# Done audio number  25410 / 27255
# file name  fold_5_participant_00600_stimulus_14.wav
# Done audio number  25411 / 27255
# file name  fold_5_participant_00600_stimulus_15.wav
# Done audio number  25412 / 27255
# file name  fold_5_participant_00600_stimulus_16.wav
# Done audio number  25413 / 27255
# file name  fold_5_participant_00600_stimulus_18.wav
# Done audio number  25414 / 27255
# file name  fold_5_participant_00600_stimulus_19.wav
# Done audio number  25415 / 27255
# file name  fold_5_participant_00600_stimulus_20.wav
# Done audio number  25416 / 27255
# file name  fold_5_participant_00600_stimulus_21.wav
# Done audio number  25417 / 27255
# file name  fold_5_participant_00600_stimulus_22.wav
# Done audio number  25418 / 27255
# file name  fold_5_participant_00600_stimulus_23.wav
# Done audio number  25419 / 27255
# file name  fold_5_participant_00600_stimulus_24.wav
# Done audio number  25420 / 27255
# file name  fold_5_participant_00600_stimulus_25.wav
# Done audio number  25421 / 27255
# file name  fold_5_participant_00600_stimulus_26.wav
# Done audio number  25422 / 27255
# file name  fold_5_participant_00600_stimulus_27.wav
# Done audio number  25423 / 27255
# file name  fold_5_participant_00600_stimulus_28.wav
# Done audio number  25424 / 27255
# file name  fold_5_participant_00600_stimulus_29.wav
# Done audio number  25425 / 27255
# file name  fold_5_participant_00600_stimulus_30.wav
# Done audio number  25426 / 27255
# file name  fold_5_participant_00600_stimulus_31.wav
# Done audio number  25427 / 27255
# file name  fold_5_participant_00600_stimulus_32.wav
# Done audio number  25428 / 27255
# file name  fold_5_participant_00600_stimulus_33.wav
# Done audio number  25429 / 27255
# file name  fold_5_participant_00600_stimulus_34.wav
# Done audio number  25430 / 27255
# file name  fold_5_participant_00600_stimulus_35.wav
# Done audio number  25431 / 27255
# file name  fold_5_participant_00600_stimulus_36.wav
# Done audio number  25432 / 27255
# file name  fold_5_participant_00600_stimulus_37.wav
# Done audio number  25433 / 27255
# file name  fold_5_participant_00600_stimulus_38.wav
# Done audio number  25434 / 27255
# file name  fold_5_participant_00600_stimulus_39.wav
# Done audio number  25435 / 27255
# file name  fold_5_participant_00600_stimulus_40.wav
# Done audio number  25436 / 27255
# file name  fold_5_participant_00600_stimulus_41.wav
# Done audio number  25437 / 27255
# file name  fold_5_participant_00600_stimulus_42.wav
# Done audio number  25438 / 27255
# file name  fold_5_participant_00600_stimulus_43.wav
# Done audio number  25439 / 27255
# file name  fold_5_participant_00600_stimulus_44.wav
# Done audio number  25440 / 27255

# %%
# Create a new column with the generated values
data_augmented_copy=data_augmented.copy(deep=True)
data_augmented_copy.insert(loc=6, column='wav_gain', value=gain_values)

# %%
print(data_augmented_copy.columns)
# Out:
# Index(['participant', 'fold_r', 'soundscape', 'masker', 'smr',
#        'stimulus_index', 'wav_gain', 'time_taken', 'is_attention', 'pleasant',
#        ...
#        'Leq_L_r', 'Leq_R_r', 'masker_bird', 'masker_construction',
#        'masker_silence', 'masker_traffic', 'masker_water', 'masker_wind',
#        'P_ground_truth', 'E_ground_truth'],
#       dtype='object', length=169)

# %%
# Save new dataset

data_augmented_copy.to_csv("../data/responses_wav_gains.csv", index=False)
