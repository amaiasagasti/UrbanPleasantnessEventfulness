# %%
feature_list=['lowlevel.average_loudness', 'lowlevel.dynamic_complexity', 'lowlevel.loudness_ebu128.integrated', 'lowlevel.loudness_ebu128.loudness_range', 'lowlevel.sound_start_frame', 'lowlevel.sound_stop_frame', 'metadata.audio_properties.analysis.equal_loudness', 'metadata.audio_properties.analysis.length', 'metadata.audio_properties.analysis.sample_rate', 'metadata.audio_properties.analysis.start_time', 'metadata.audio_properties.bit_rate', 'metadata.audio_properties.length', 'metadata.audio_properties.lossless', 'metadata.audio_properties.number_channels', 'metadata.audio_properties.sample_rate', 'rhythm.bpm', 'rhythm.bpm_histogram_first_peak_bpm', 'rhythm.bpm_histogram_first_peak_spread', 'rhythm.bpm_histogram_first_peak_weight', 'rhythm.bpm_histogram_second_peak_bpm', 'rhythm.bpm_histogram_second_peak_spread', 'rhythm.bpm_histogram_second_peak_weight', 'rhythm.bpm_loop', 'rhythm.bpm_loop_confidence', 'rhythm.onset_rate', 'sfx.duration', 'sfx.max_to_total', 'sfx.pitch_after_max_to_before_max_energy_ratio', 'sfx.pitch_max_to_total', 'sfx.pitch_min_to_total', 'sfx.strongdecay', 'sfx.tc_to_total', 'tonal.key.strength', 'lowlevel.barkbands_crest_avg', 'lowlevel.barkbands_crest_median', 'lowlevel.barkbands_crest_max', 'lowlevel.barkbands_crest_p05', 'lowlevel.barkbands_crest_p10', 'lowlevel.barkbands_crest_p20', 'lowlevel.barkbands_crest_p30', 'lowlevel.barkbands_crest_p40', 'lowlevel.barkbands_crest_p50', 'lowlevel.barkbands_crest_p60', 'lowlevel.barkbands_crest_p70', 'lowlevel.barkbands_crest_p80', 'lowlevel.barkbands_crest_p90', 'lowlevel.barkbands_crest_p95', 'lowlevel.barkbands_flatness_db_avg', 'lowlevel.barkbands_flatness_db_median', 'lowlevel.barkbands_flatness_db_max', 'lowlevel.barkbands_flatness_db_p05', 'lowlevel.barkbands_flatness_db_p10', 'lowlevel.barkbands_flatness_db_p20', 'lowlevel.barkbands_flatness_db_p30', 'lowlevel.barkbands_flatness_db_p40', 'lowlevel.barkbands_flatness_db_p50', 'lowlevel.barkbands_flatness_db_p60', 'lowlevel.barkbands_flatness_db_p70', 'lowlevel.barkbands_flatness_db_p80', 'lowlevel.barkbands_flatness_db_p90', 'lowlevel.barkbands_flatness_db_p95', 'lowlevel.barkbands_kurtosis_avg', 'lowlevel.barkbands_kurtosis_median', 'lowlevel.barkbands_kurtosis_max', 'lowlevel.barkbands_kurtosis_p05', 'lowlevel.barkbands_kurtosis_p10', 'lowlevel.barkbands_kurtosis_p20', 'lowlevel.barkbands_kurtosis_p30', 'lowlevel.barkbands_kurtosis_p40', 'lowlevel.barkbands_kurtosis_p50', 'lowlevel.barkbands_kurtosis_p60', 'lowlevel.barkbands_kurtosis_p70', 'lowlevel.barkbands_kurtosis_p80', 'lowlevel.barkbands_kurtosis_p90', 'lowlevel.barkbands_kurtosis_p95', 'lowlevel.barkbands_skewness_avg', 'lowlevel.barkbands_skewness_median', 'lowlevel.barkbands_skewness_max', 'lowlevel.barkbands_skewness_p05', 'lowlevel.barkbands_skewness_p10', 'lowlevel.barkbands_skewness_p20', 'lowlevel.barkbands_skewness_p30', 'lowlevel.barkbands_skewness_p40', 'lowlevel.barkbands_skewness_p50', 'lowlevel.barkbands_skewness_p60', 'lowlevel.barkbands_skewness_p70', 'lowlevel.barkbands_skewness_p80', 'lowlevel.barkbands_skewness_p90', 'lowlevel.barkbands_skewness_p95', 'lowlevel.barkbands_spread_avg', 'lowlevel.barkbands_spread_median', 'lowlevel.barkbands_spread_max', 'lowlevel.barkbands_spread_p05', 'lowlevel.barkbands_spread_p10', 'lowlevel.barkbands_spread_p20', 'lowlevel.barkbands_spread_p30', 'lowlevel.barkbands_spread_p40', 'lowlevel.barkbands_spread_p50', 'lowlevel.barkbands_spread_p60', 'lowlevel.barkbands_spread_p70', 'lowlevel.barkbands_spread_p80', 'lowlevel.barkbands_spread_p90', 'lowlevel.barkbands_spread_p95', 'lowlevel.dissonance_avg', 'lowlevel.dissonance_median', 'lowlevel.dissonance_max', 'lowlevel.dissonance_p05', 'lowlevel.dissonance_p10', 'lowlevel.dissonance_p20', 'lowlevel.dissonance_p30', 'lowlevel.dissonance_p40', 'lowlevel.dissonance_p50', 'lowlevel.dissonance_p60', 'lowlevel.dissonance_p70', 'lowlevel.dissonance_p80', 'lowlevel.dissonance_p90', 'lowlevel.dissonance_p95', 'lowlevel.erbbands_crest_avg', 'lowlevel.erbbands_crest_median', 'lowlevel.erbbands_crest_max', 'lowlevel.erbbands_crest_p05', 'lowlevel.erbbands_crest_p10', 'lowlevel.erbbands_crest_p20', 'lowlevel.erbbands_crest_p30', 'lowlevel.erbbands_crest_p40', 'lowlevel.erbbands_crest_p50', 'lowlevel.erbbands_crest_p60', 'lowlevel.erbbands_crest_p70', 'lowlevel.erbbands_crest_p80', 'lowlevel.erbbands_crest_p90', 'lowlevel.erbbands_crest_p95', 'lowlevel.erbbands_flatness_db_avg', 'lowlevel.erbbands_flatness_db_median', 'lowlevel.erbbands_flatness_db_max', 'lowlevel.erbbands_flatness_db_p05', 'lowlevel.erbbands_flatness_db_p10', 'lowlevel.erbbands_flatness_db_p20', 'lowlevel.erbbands_flatness_db_p30', 'lowlevel.erbbands_flatness_db_p40', 'lowlevel.erbbands_flatness_db_p50', 'lowlevel.erbbands_flatness_db_p60', 'lowlevel.erbbands_flatness_db_p70', 'lowlevel.erbbands_flatness_db_p80', 'lowlevel.erbbands_flatness_db_p90', 'lowlevel.erbbands_flatness_db_p95', 'lowlevel.erbbands_kurtosis_avg', 'lowlevel.erbbands_kurtosis_median', 'lowlevel.erbbands_kurtosis_max', 'lowlevel.erbbands_kurtosis_p05', 'lowlevel.erbbands_kurtosis_p10', 'lowlevel.erbbands_kurtosis_p20', 'lowlevel.erbbands_kurtosis_p30', 'lowlevel.erbbands_kurtosis_p40', 'lowlevel.erbbands_kurtosis_p50', 'lowlevel.erbbands_kurtosis_p60', 'lowlevel.erbbands_kurtosis_p70', 'lowlevel.erbbands_kurtosis_p80', 'lowlevel.erbbands_kurtosis_p90', 'lowlevel.erbbands_kurtosis_p95', 'lowlevel.erbbands_skewness_avg', 'lowlevel.erbbands_skewness_median', 'lowlevel.erbbands_skewness_max', 'lowlevel.erbbands_skewness_p05', 'lowlevel.erbbands_skewness_p10', 'lowlevel.erbbands_skewness_p20', 'lowlevel.erbbands_skewness_p30', 'lowlevel.erbbands_skewness_p40', 'lowlevel.erbbands_skewness_p50', 'lowlevel.erbbands_skewness_p60', 'lowlevel.erbbands_skewness_p70', 'lowlevel.erbbands_skewness_p80', 'lowlevel.erbbands_skewness_p90', 'lowlevel.erbbands_skewness_p95', 'lowlevel.erbbands_spread_avg', 'lowlevel.erbbands_spread_median', 'lowlevel.erbbands_spread_max', 'lowlevel.erbbands_spread_p05', 'lowlevel.erbbands_spread_p10', 'lowlevel.erbbands_spread_p20', 'lowlevel.erbbands_spread_p30', 'lowlevel.erbbands_spread_p40', 'lowlevel.erbbands_spread_p50', 'lowlevel.erbbands_spread_p60', 'lowlevel.erbbands_spread_p70', 'lowlevel.erbbands_spread_p80', 'lowlevel.erbbands_spread_p90', 'lowlevel.erbbands_spread_p95', 'lowlevel.hfc_avg', 'lowlevel.hfc_median', 'lowlevel.hfc_max', 'lowlevel.hfc_p05', 'lowlevel.hfc_p10', 'lowlevel.hfc_p20', 'lowlevel.hfc_p30', 'lowlevel.hfc_p40', 'lowlevel.hfc_p50', 'lowlevel.hfc_p60', 'lowlevel.hfc_p70', 'lowlevel.hfc_p80', 'lowlevel.hfc_p90', 'lowlevel.hfc_p95', 'lowlevel.loudness_ebu128.momentary_avg', 'lowlevel.loudness_ebu128.momentary_median', 'lowlevel.loudness_ebu128.momentary_max', 'lowlevel.loudness_ebu128.momentary_p05', 'lowlevel.loudness_ebu128.momentary_p10', 'lowlevel.loudness_ebu128.momentary_p20', 'lowlevel.loudness_ebu128.momentary_p30', 'lowlevel.loudness_ebu128.momentary_p40', 'lowlevel.loudness_ebu128.momentary_p50', 'lowlevel.loudness_ebu128.momentary_p60', 'lowlevel.loudness_ebu128.momentary_p70', 'lowlevel.loudness_ebu128.momentary_p80', 'lowlevel.loudness_ebu128.momentary_p90', 'lowlevel.loudness_ebu128.momentary_p95', 'lowlevel.loudness_ebu128.short_term_avg', 'lowlevel.loudness_ebu128.short_term_median', 'lowlevel.loudness_ebu128.short_term_max', 'lowlevel.loudness_ebu128.short_term_p05', 'lowlevel.loudness_ebu128.short_term_p10', 'lowlevel.loudness_ebu128.short_term_p20', 'lowlevel.loudness_ebu128.short_term_p30', 'lowlevel.loudness_ebu128.short_term_p40', 'lowlevel.loudness_ebu128.short_term_p50', 'lowlevel.loudness_ebu128.short_term_p60', 'lowlevel.loudness_ebu128.short_term_p70', 'lowlevel.loudness_ebu128.short_term_p80', 'l
', 'lowlevel.pitch_p40', 'lowlevel.pitch_p50', 'lowlevel.pitch_p60', 'lowlevel.pitch_p70', 'lowlevel.pitch_p80', 'lowlevel.pitch_p90', 'lowlevel.pitch_p95', 'lowlevel.pitch_instantaneous_confidence_avg', 'lowlevel.pitch_instantaneous_confidence_median', 'lowlevel.pitch_instantaneous_confidence_max', 'lowlevel.pitch_instantaneous_confidence_p05', 'lowlevel.pitch_instantaneous_confidence_p10', 'lowlevel.pitch_instantaneous_confidence_p20', 'lowlevel.pitch_instantaneous_confidence_p30', 'lowlevel.pitch_instantaneous_confidence_p40', 'lowlevel.pitch_instantaneous_confidence_p50', 'lowlevel.pitch_instantaneous_confidence_p60', 'lowlevel.pitch_instantaneous_confidence_p70', 'lowlevel.pitch_instantaneous_confidence_p80', 'lowlevel.pitch_instantaneous_confidence_p90', 'lowlevel.pitch_instantaneous_confidence_p95', 'lowlevel.pitch_salience_avg', 'lowlevel.pitch_salience_median', 'lowlevel.pitch_salience_max', 'lowlevel.pitch_salience_p05', 'lowlevel.pitch_salience_p10', 'lowlevel.pitch_salience_p20', 'lowlevel.pitch_salience_p30', 'lowlevel.pitch_salience_p40', 'lowlevel.pitch_salience_p50', 'lowlevel.pitch_salience_p60', 'lowlevel.pitch_salience_p70', 'lowlevel.pitch_salience_p80', 'lowlevel.pitch_salience_p90', 'lowlevel.pitch_salience_p95', 'lowlevel.silence_rate_20dB_avg', 'lowlevel.silence_rate_20dB_median', 'lowlevel.silence_rate_20dB_max', 'lowlevel.silence_rate_20dB_p05', 'lowlevel.silence_rate_20dB_p10', 'lowlevel.silence_rate_20dB_p20', 'lowlevel.silence_rate_20dB_p30', 'lowlevel.silence_rate_20dB_p40', 'lowlevel.silence_rate_20dB_p50', 'lowlevel.silence_rate_20dB_p60', 'lowlevel.silence_rate_20dB_p70', 'lowlevel.silence_rate_20dB_p80', 'lowlevel.silence_rate_20dB_p90', 'lowlevel.silence_rate_20dB_p95', 'lowlevel.silence_rate_30dB_avg', 'lowlevel.silence_rate_30dB_median', 'lowlevel.silence_rate_30dB_max', 'lowlevel.silence_rate_30dB_p05', 'lowlevel.silence_rate_30dB_p10', 'lowlevel.silence_rate_30dB_p20', 'lowlevel.silence_rate_30dB_p30', 'lowlevel.silence_rate_30dB_p40', 'lowlevel.silence_rate_30dB_p50', 'lowlevel.silence_rate_30dB_p60', 'lowlevel.silence_rate_30dB_p70', 'lowlevel.silence_rate_30dB_p80', 'lowlevel.silence_rate_30dB_p90', 'lowlevel.silence_rate_30dB_p95', 'lowlevel.silence_rate_60dB_avg', 'lowlevel.silence_rate_60dB_median', 'lowlevel.silence_rate_60dB_max', 'lowlevel.silence_rate_60dB_p05', 'lowlevel.silence_rate_60dB_p10', 'lowlevel.silence_rate_60dB_p20', 'lowlevel.silence_rate_60dB_p30', 'lowlevel.silence_rate_60dB_p40', 'lowlevel.silence_rate_60dB_p50', 'lowlevel.silence_rate_60dB_p60
ropy_p05', 'lowlevel.spectral_entropy_p10', 'lowlevel.spectral_entropy_p20', 'lowlevel.spectral_entropy_p30', 'lowlevel.spectral_entropy_p40', 'lowlevel.spectral_entropy_p50', 'lowlevel.spectral_entropy_p60', 'lowlevel.spectral_entropy_p70', 'lowlevel.spectral_entropy_p80', 'lowlevel.spectral_entropy_p90', 'lowlevel.spectral_entropy_p95', 'lowlevel.spectral_flatness_db_avg', 'lowlevel.spectral_flatness_db_median', 'lowlevel.spectral_flatness_db_max', 'lowlevel.spectral_flatness_db_p05', 'lowlevel.spectral_flatness_db_p10', 'lowlevel.spectral_flatness_db_p20', 'lowlevel.spectral_flatness_db_p30', 'lowlevel.spectral_flatness_db_p40', 'lowlevel.spectral_flatness_db_p50', 'lowlevel.spectral_flatness_db_p60', 'lowlevel.spectral_flatness_db_p70', 'lowlevel.spectral_flatness_db_p80', 'lowlevel.spectral_flatness_db_p90', 'lowlevel.spectral_flatness_db_p95', 'lowlevel.spectral_flux_avg', 'lowlevel.spectral_flux_median', 'lowlevel.spectral_flux_max', 'lowlevel.spectral_flux_p05', 'lowlevel.spectral_flux_p10', 'lowlevel.spectral_flux_p20', 'lowlevel.spectral_flux_p30', 'lowlevel.spectral_flux_p40', 'lowlevel.spectral_flux_p50', 'lowlevel.spectral_flux_p60', 'lowlevel.spectral_flux_p70', 'lowlevel.spectral_flux_p80', 'lowlevel.spectral_flux_p90', 'lowlevel.spectral_flux_p95', 'lowlevel.spectral_kurtosis_avg', 'lowlevel.spectral_kurtosis_median', 'lowlevel.spectral_kurtosis_max', 'lowlevel.spectral_kurtosis_p05', 'lowlevel.spectral_kurtosis_p10', 'lowlevel.spectral_kurtosis_p20', 'lowlevel.spectral_kurtosis_p30', 'lowlevel.spectral_kurtosis_p40', 'lowlevel.spectral_kurtosis_p50', 'lowlevel.spectral_kurtosis_p60', 'lowlevel.spectral_kurtosis_p70', 'lowlevel.spectral_kurtosis_p80', 'lowlevel.spectral_kurtosis_p90', 'lowlevel.spectral_kurtosis_p95', 'lowlevel.spectral_rms_avg', 'lowlevel.spectral_rms_median', 'lowlevel.spectral_rms_max', 'lowlevel.spectral_rms_p05', 'lowlevel.spectral_rms_p10', 'lowlevel.spectral_rms_p20', 'lowlevel.spectral_rms_p30', 'lowlevel.spectral_rms_p40', 'lowlevel.spectral_rms_p50', 'lowlevel.spectral_rms_p60', 'lowlevel.spectral_rms_p70', 'lowlevel.spectral_rms_p80', 'lowlevel.spectral_rms_p90', 'lowlevel.spectral_rms_p95', 'lowlevel.spectral_rolloff_avg', 'lowlevel.spectral_rolloff_median', 'lowlevel.spectral_rolloff_max', 'lowlevel.spectral_rolloff_p05', 'lowlevel.spectral_rolloff_p10', 'lowlevel.spectral_rolloff_p20', 'lowlevel.spectral_rolloff_p30', 'lowlevel.spectral_rolloff_p40', 'lowlevel.spectral_rolloff_p50', 'lowlevel.spectral_rolloff_p60', 'lowlevel.spectral_rolloff_p70', 'lowlevel.spectral_rolloff_p80', 'lowlevel.spectral_rolloff_p90', 'lowlevel.spectral_rolloff_p95', 'lowlevel.spectral_skewness_avg', 'lowlevel.spectral_skewness_median', 'lowlevel.spectral_skewness_max', 'lowlevel.spectral_skewness_p05', 'lowlevel.spectral_skewness_p10', 'lowlevel.spectral_skewness_p20', 'lowlevel.spectral_skewness_p30', 'lowlevel.spectral_skewness_p40', 'lowlevel.spectral_skewness_p50', 'lowlevel.spectral_skewness_p60', 'lowlevel.spectral_skewness_p70', 'lowlevel.spectral_skewness_p80', 'lowlevel.spectral_skewness_p90', 'lowlevel.spectral_skewness_p95', 'lowlevel.spectral_spread_avg', 'lowlevel.spectral_spread_median', 'lowlevel.spectral_spread_max', 'lowlevel.spectral_spread_p05', 'lowlevel.spectral_spread_p10', 'lowlevel.spectral_spread_p20', 'lowlevel.spectral_spread_p30', 'lowlevel.spectral_spread_p40', 'lowlevel.spectral_spread_p50', 'lowlevel.spectral_spread_p60', 'lowlevel.spectral_spread_p70', 'lowlevel.spectral_spread_p80', 'lowlevel.spectral_spread_p90', 'lowlevel.spectral_spread_p95', 'lowlevel.spectral_strongpeak_avg', 'lowlevel.spectral_strongpeak_median', 'lowlevel.spectral_strongpeak_max', 'lowlevel.spectral_strongpeak_p05', 'lowlevel.spectral_strongpeak_p10', 'lowlevel.spectral_strongpeak_p20', 'lowlevel.spectral_strongpeak_p30', 'lowlevel.spectral_strongpeak_p40', 'lowlevel.spectral_strongpeak_p50', 'lowlevel.spectral_strongpeak_p60', 'lowlevel.spectral_strongpeak_p70', 'lowlevel.spectral_strongpeak_p80', 'lowlevel.spectral_strongpeak_p90', 'lowlevel.spectral_strongpeak_p95', 'lowlevel.zerocrossingrate_avg', 'lowlevel.zerocrossingrate_median', 'lowlevel.zerocrossingrate_max', 'lowlevel.zerocrossingrate_p05', 'lowlevel.zerocrossingrate_p10', 'lowlevel.zerocrossingrate_p20', 'lowlevel.zerocrossingrate_p30', 'lowlevel.zerocrossingrate_p40', 'lowlevel.zerocrossingrate_p50', 'lowlevel.zerocrossingrate_p60', 'lowlevel.zerocrossingrate_p70', 'lowlevel.zerocrossingrate_p80', 'lowlevel.zerocrossingrate_p90', 'lowlevel.zerocrossingrate_p95', 'rhythm.beats_loudness_avg', 'rhythm.beats_loudness_median', 'rhythm.beats_loudness_max', 'rhythm.beats_loudness_p05', 'rhythm.beats_loudness_p10', 'rhythm.beats_loudness_p20', 'rhythm.beats_loudness_p30', 'rhythm.beats_loudness_p40', 'rhythm.beats_loudness_p50', 'rhythm.beats_loudness_p60', 'rhythm.beats_loudness_p70', 'rhythm.beats_loudness_p80', 'rhythm.beats_loudness_p90', 'rhythm.beats_loudness_p95', 'sfx.der_av_after_max_avg', 'sfx.der_av_after_max_median', 'sfx.der_av_after_max_max', 'sfx.der_av_after_max_p05', 'sfx.der_av_after_max_p10', 'sfx.der_av_after_max_p20', 'sfx.der_av_after
yratio_p90', 'sfx.oddtoevenharmonicenergyratio_p95', 'sfx.pitch_centroid_avg', 'sfx.pitch_centroid_median', 'sfx.pitch_centroid_max', 'sfx.pitch_centroid_p05', 'sfx.pitch_centroid_p10', 'sfx.pitch_centroid_p20', 'sfx.pitch_centroid_p30', 'sfx.pitch_centroid_p40', 'sfx.pitch_centroid_p50', 'sfx.pitch_centroid_p60', 'sfx.pitch_centroid_p70', 'sfx.pitch_centroid_p80', 'sfx.pitch_centroid_p90', 'sfx.pitch_centroid_p95', 'sfx.temporal_centroid_avg', 'sfx.temporal_centroid_median', 'sfx.temporal_centroid_max', 'sfx.temporal_centroid_p05', 'sfx.temporal_centroid_p10', 'sfx.temporal_centroid_p20', 'sfx.temporal_centroid_p30', 'sfx.temporal_centroid_p40', 'sfx.temporal_centroid_p50', 'sfx.temporal_centroid_p60', 'sfx.temporal_centroid_p70', 'sfx.temporal_centroid_p80', 'sfx.temporal_centroid_p90', 'sfx.temporal_centroid_p95', 'sfx.temporal_decrease_avg', 'sfx.temporal_decrease_median', 'sfx.temporal_decrease_max', 'sfx.temporal_decrease_p05', 'sfx.temporal_decrease_p10', 'sfx.temporal_decrease_p20', 'sfx.temporal_decrease_p30', 'sfx.temporal_decrease_p40', 'sfx.temporal_decrease_p50', 'sfx.temporal_decrease_p60', 'sfx.temporal_decrease_p70', 'sfx.temporal_decrease_p80', 'sfx.temporal_decrease_p90', 'sfx.temporal_decrease_p95', 'sfx.temporal_kurtosis_avg', 'sfx.temporal_kurtosis_median', 'sfx.temporal_kurtosis_max', 'sfx.temporal_kurtosis_p05', 'sfx.temporal_kurtosis_p10', 'sfx.temporal_kurtosis_p20', 'sfx.temporal_kurtosis_p30', 'sfx.temporal_kurtosis_p40', 'sfx.temporal_kurtosis_p50', 'sfx.temporal_kurtosis_p60', 'sfx.temporal_kurtosis_p70', 'sfx.temporal_kurtosis_p80', 'sfx.temporal_kurtosis_p90', 'sfx.temporal_kurtosis_p95', 'sfx.temporal_skewness_avg', 'sfx.temporal_skewness_median', 'sfx.temporal_skewness_max', 'sfx.temporal_skewness_p05', 'sfx.temporal_skewness_p10', 'sfx.temporal_skewness_p20', 'sfx.temporal_skewness_p30', 'sfx.temporal_skewness_p40', 'sfx.temporal_skewness_p50', 'sfx.temporal_skewness_p60', 'sfx.temporal_skewness_p70', 'sfx.temporal_skewness_p80', 'sfx.temporal_skewness_p90', 'sfx.temporal_skewness_p95', 'sfx.temporal_spread_avg', 'sfx.temporal_spread_median', 'sfx.temporal_spread_max', 'sfx.temporal_spread_p05', 'sfx.temporal_spread_p10', 'sfx.temporal_spread_p20', 'sfx.temporal_spread_p30', 'sfx.temporal_spread_p40', 'sfx.temporal_spread_p50', 'sfx.temporal_spread_p60', 'sfx.temporal_spread_p70', 'sfx.temporal_spread_p80', 'sfx.temporal_spread_p90', 'sfx.temporal_spread_p95', 'tonal.hpcp_crest_avg', 'tonal.hpcp_crest_median', 'tonal.hpcp_crest_max', 'tonal.hpcp_crest_p05', 'tonal.hpcp_crest_p10', 'tonal.hpcp_crest_p20', 'tonal.hpcp_crest_p30', 'tonal.hpcp_crest_p40', 'tonal.hpcp_crest_p50', 'tonal.hpcp_crest_p60', 'tonal.hpcp_crest_p70', 'tonal.hpcp_crest_p80', 'tonal.hpcp_crest_p90', 'tonal.hpcp_crest_p95', 'tonal.hpcp_entropy_avg', 'tonal.hpcp_entropy_median', 'tonal.hpcp_entropy_max', 'tonal.hpcp_entropy_p05', 'tonal.hpcp_entropy_p10', 'tonal.hpcp_entropy_p20', 'tonal.hpcp_entropy_p30', 'tonal.hpcp_entropy_p40', 'tonal.hpcp_entropy_p50', 'tonal.hpcp_entropy_p60', 'tonal.hpcp_entropy_p70', 'tonal.hpcp_entropy_p80', 'tonal.hpcp_entropy_p90', 'tonal.hpcp_entropy_p95', 'tonal.tuning_frequency_avg', 'tonal.tuning_frequency_median', 'tonal.tuning_frequency_max', 'tonal.tuning_frequency_p05', 'tonal.tuning_frequency_p10', 'tonal.tuning_frequency_p20', 'tonal.tuning_frequency_p30', 'tonal.tuning_frequency_p40', 'tonal.tuning_frequency_p50', 'tonal.tuning_frequency_p60', 'tonal.tuning_frequency_p70', 'tonal.tuning_frequency_p80', 'tonal.tuning_frequency_p90', 'tonal.tuning_frequency_p95', 'rhythm.beats_position_avg', 'rhythm.beats_position_median', 'rhythm.beats_position_max', 'rhythm.beats_position_p05', 'rhythm.beats_position_p10', 'rhythm.beats_position_p20', 'rhythm.beats_position_p30', 'rhythm.beats_position_p40', 'rhythm.beats_position_p50', 'rhythm.beats_position_p60', 'rhythm.beats_position_p70', 'rhythm.beats_position_p80', 'rhythm.beats_position_p90', 'rhythm.beats_position_p95', 'rhythm.bpm_histogram_avg', 'rhythm.bpm_histogram_median', 'rhythm.bpm_histogram_max', 'rhythm.bpm_histogram_p05', 'rhythm.bpm_histogram_p10', 'rhythm.bpm_histogram_p20', 'rhythm.bpm_histogram_p30', 'rhythm.bpm_histogram_p40', 'rhythm.bpm_histogram_p50', 'rhythm.bpm_histogram_p60', 'rhythm.bpm_histogram_p70', 'rhythm.bpm_histogram_p80', 'rhythm.bpm_histogram_p90', 'rhythm.bpm_histogram_p95', 'rhythm.bpm_intervals_avg', 'rhythm.bpm_intervals_median', 'rhythm.bpm_intervals_max', 'rhythm.bpm_intervals_p05', 'rhythm.bpm_intervals_p10', 'rhythm.bpm_intervals_p20', 'rhythm.bpm_intervals_p30', 'rhythm.bpm_intervals_p40', 'rhythm.bpm_intervals_p50', 'rhythm.bpm_intervals_p60', 'rhythm.bpm_intervals_p70', 'rhythm.bpm_intervals_p80', 'rhythm.bpm_intervals_p90', 'rhythm.bpm_intervals_p95', 'rhythm.onset_times_avg', 'rhythm.onset_times_median', 'rhythm.onset_times_max', 'rhythm.onset_times_p05', 'rhythm.onset_times_p10', 'rhythm.onset_times_p20', 'rhythm.onset
s_max', 'lowlevel.spectral_contrast_coeffs_p05', 'lowlevel.spectral_contrast_coeffs_p10', 'lowlevel.spectral_contrast_coeffs_p20', 'lowlevel.spectral_contrast_coeffs_p30', 'lowlevel.spectral_contrast_coeffs_p40', 'lowlevel.spectral_contrast_coeffs_p50', 'lowlevel.spectral_contrast_coeffs_p60', 'lowlevel.spectral_contrast_coeffs_p70', 'lowlevel.spectral_contrast_coeffs_p80', 'lowlevel.spectral_contrast_coeffs_p90', 'lowlevel.spectral_contrast_coeffs_p95', 'lowlevel.spectral_contrast_valleys_avg', 'lowlevel.spectral_contrast_valleys_median', 'lowlevel.spectral_contrast_valleys_max', 'lowlevel.spectral_contrast_valleys_p05', 'lowlevel.spectral_contrast_valleys_p10', 'lowlevel.spectral_contrast_valleys_p20', 'lowlevel.spectral_contrast_valleys_p30', 'lowlevel.spectral_contrast_valleys_p40', 'lowlevel.spectral_contrast_valleys_p50', 'lowlevel.spectral_contrast_valleys_p60', 'lowlevel.spectral_contrast_valleys_p70', 'lowlevel.spectral_contrast_valleys_p80', 'lowlevel.spectral_contrast_valleys_p90', 'lowlevel.spectral_contrast_valleys_p95', 'rhythm.beats_loudness_band_ratio_avg', 'rhythm.beats_loudness_band_ratio_median', 'rhythm.beats_loudness_band_ratio_max', 'rhythm.beats_loudness_band_ratio_p05', 'rhythm.beats_loudness_band_ratio_p10', 'rhythm.beats_loudness_band_ratio_p20', 'rhythm.beats_loudness_band_ratio_p30', 'rhythm.beats_loudness_band_ratio_p40', 'rhythm.beats_loudness_band_ratio_p50', 'rhythm.beats_loudness_band_ratio_p60', 'rhythm.beats_loudness_band_ratio_p70', 'rhythm.beats_loudness_band_ratio_p80', 'rhythm.beats_loudness_band_ratio_p90', 'rhythm.beats_loudness_band_ratio_p95', 'sfx.tristimulus_avg', 'sfx.tristimulus_median', 'sfx.tristimulus_max', 'sfx.tristimulus_p05', 'sfx.tristimulus_p10', 'sfx.tristimulus_p20', 'sfx.tristimulus_p30', 'sfx.tristimulus_p40', 'sfx.tristimulus_p50', 'sfx.tristimulus_p60', 'sfx.tristimulus_p70', 'sfx.tristimulus_p80', 'sfx.tristimulus_p90', 'sfx.tristimulus_p95', 'tonal.hpcp_avg', 'tonal.hpcp_median', 'tonal.hpcp_max', 'tonal.hpcp_p05', 'tonal.hpcp_p10', 'tonal.hpcp_p20', 'tonal.hpcp_p30', 'tonal.hpcp_p40', 'tonal.hpcp_p50', 'tonal.hpcp_p60', 'tonal.hpcp_p70', 'tonal.hpcp_p80', 'tonal.hpcp_p90', 'tonal.hpcp_p95', 'metadata.audio_properties.analysis.downmix', 'metadata.audio_properties.codec', 'metadata.audio_properties.md5_encoded', 'metadata.tags.file_name', 'metadata.version.essentia', 'metadata.version.essentia_git_sha', 'metadata.version.extractor', 'tonal.key.key', 'tonal.key.scale']

# %%
from essentia.standard import FreesoundExtractor
from Mosqito.loadFiles import load
import numpy as np
import pandas as pd
import os


def calculate_stats(vector: np.array, stats: list, descriptor_name):
    output = {}
    """ if(np.ndim(vector)==1):
        along_axis=0
    elif(np.ndim(vector)==2):
        along_axis=1 """
    for i, stat in enumerate(stats):
        
        if stat == "avg":
            output[descriptor_name+"_avg"] = [np.mean(vector, axis=0)]
        if stat == "median":
            output[descriptor_name+"_median"] = [np.median(vector, axis=0)]
        if stat == "var":
            output[descriptor_name+"_var"] = [np.var(vector, axis=0)]
        """ if stat == "avgdB":
            output["avgdB"] = mean_dB(vector) """
        if stat == "rmc":
            output[descriptor_name+"_rmc"] = [np.sqrt(np.mean(np.power(vector, 3, axis=0)))]
        if stat == "max":
            output[descriptor_name+"_max"] = [np.max(vector, axis=0)]
        if stat == "min":
            output[descriptor_name+"_min"] = [np.min(vector, axis=0)]
        if stat == "p05":
            output[descriptor_name+"_p05"] = [np.percentile(vector, 95, axis=0)]
        if stat == "p10":
            output[descriptor_name+"_p10"] = [np.percentile(vector, 90, axis=0)]
        if stat == "p20":
            output[descriptor_name+"_p20"] = [np.percentile(vector, 80, axis=0)]
        if stat == "p30":
            output[descriptor_name+"_p30"] = [np.percentile(vector, 70, axis=0)]
        if stat == "p40":
            output[descriptor_name+"_p40"] = [np.percentile(vector, 60, axis=0)]
        if stat == "p50":
            output[descriptor_name+"_p50"] = [np.percentile(vector, 50, axis=0)]
        if stat == "p60":
            output[descriptor_name+"_p60"] = [np.percentile(vector, 40, axis=0)]
        if stat == "p70":
            output[descriptor_name+"_p70"] = [np.percentile(vector, 30, axis=0)]
        if stat == "p80":
            output[descriptor_name+"_p80"] = [np.percentile(vector, 20, axis=0)]
        if stat == "p90":
            output[descriptor_name+"_p90"] = [np.percentile(vector, 10, axis=0)]
        if stat == "p95":
            output[descriptor_name+"_p95"] = [np.percentile(vector, 5, axis=0)]
    return output



parameters = {
    'analysisSampleRate': 48000,
    'startTime': 0,
    'endTime': 30,

    'lowlevelFrameSize': 2048,
    'lowlevelHopSize': 1024,
    'lowlevelSilentFrames': 'noise',
    'lowlevelStats': ["mean"],#"max", "dmean", "dmean2", "dvar", "dvar2"
    'lowlevelWindowType': 'blackmanharris62',
    'lowlevelZeroPadding': 0,

    'mfccStats': ["mean"],
    "gfccStats":["mean"],
    #"tristimulusStats":["mean"],

    'rhythmMaxTempo': 208,
    'rhythmMethod': 'degara',
    'rhythmMinTempo':40,
    'rhythmStats': ["mean"], #"mean", "var", "median", "min", "max", "dmean", "dmean2", "dvar", "dvar2"

    'tonalFrameSize': 4096,
    'tonalHopSize': 1024,
    'tonalSilentFrames': 'noise',
    'tonalStats': ["mean"],
    'tonalWindowType': 'blackmanharris62',
    'tonalZeroPadding': 0
}

def run_freesound_extractor(audiofile):
    """ Runs Essentia standard FreesoundExtractor
    :audiofile: absolute path to the audio file to analyze
    """
    try:
        #FreesoundExtractor.analysisSampleRate=48000
        result, resultFrames = FreesoundExtractor(**parameters)(audiofile)
    except RuntimeError as e:
        raise e
    return result, resultFrames

def analyze(input):
        # Run the essentia standard FreesoundExtractor
        print('Running Essentia\'s FreesoundExtractor: {input}')
        result, frames = run_freesound_extractor(input)

        """ # Save all available features in a dictionary
        features = dict()
        frames=dict()
        for descriptor in result.descriptorNames():
            features[descriptor] = result[descriptor]
            print(descriptor, "---", type(result[descriptor]))
            if(type(result[descriptor])==np.ndarray):
                 print(result[descriptor].shape)

        for descriptor in resultFrames.descriptorNames():   
            frames[descriptor] = resultFrames[descriptor] """
        
        # Calculate statistics and save all available features in a dictionary 
        features = dict()
        for descriptor in frames.descriptorNames():
            if(type(frames[descriptor])==np.ndarray):
                stats = [
                    "avg",
                    "median",
                    "var"
                    "min",
                    "max",
                    "p05",
                    "p10",
                    "p20",
                    "p30",
                    "p40",
                    "p50",
                    "p60",
                    "p70",
                    "p80",
                    "p90",
                    "p95",
                ]
                stats_result=calculate_stats(frames[descriptor], stats, descriptor)
                features = {**features, **stats_result}
            else:
                features[descriptor]=frames[descriptor]



        return features,frames



"""audios_path = "../data/soundscapes_augmented/"
file="fold_0_participant_10001_stimulus_02.wav"
audio_path = audios_path + file

# Get digital signal (no wav calibration)
signalR, fs = load(
    audio_path, wav_calib=1, ch=1
)  # R - SINGLE CHANNEL SIGNAL

result,frames=analyze(audio_path)

 column_names = list(result.keys())
#print(column_names)

# Convert dictionary to DataFrame
df = pd.DataFrame(result)
#print(df)

column_names = df.columns.tolist()
print(column_names) """

new_df = pd.DataFrame(columns=feature_list)
# For each audio...
audios_path = "./data/soundscapes_augmented/"
for file in sorted(os.listdir(audios_path)):
    if file.endswith(".mp3") or file.endswith(".wav"):

        print("File ", file)
        audio_path = audios_path + file

        # Extract features for signal
        audio_features = analyze(audio_path)

        # Add acoustic features to output row
        output_row = {}
        output_row.update(audio_features)

        # Save
        new_df = pd.concat(
            [new_df, pd.DataFrame([output_row])], ignore_index=True
        )  # Save row of data

        print(" - - - - - - - - - - - - - - - - - - - - - - - - - - - -")

new_df.to_csv("data/generated_nonacoustic_features_SoundLights.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/amaiasagastimartinez/Desktop/Master/Master-Thesis/Code/code/trying_essentia.ipynb Cell 2 line 1
#     <a href='vscode-notebook-cell:/Users/amaiasagastimartinez/Desktop/Master/Master-Thesis/Code/code/trying_essentia.ipynb#W0sZmlsZQ%3D%3D?line=167'>168</a> # For each audio...
#     <a href='vscode-notebook-cell:/Users/amaiasagastimartinez/Desktop/Master/Master-Thesis/Code/code/trying_essentia.ipynb#W0sZmlsZQ%3D%3D?line=168'>169</a> audios_path = "./data/soundscapes_augmented/"
# --> <a href='vscode-notebook-cell:/Users/amaiasagastimartinez/Desktop/Master/Master-Thesis/Code/code/trying_essentia.ipynb#W0sZmlsZQ%3D%3D?line=169'>170</a> for file in sorted(os.listdir(audios_path)):
# ...

# %%
print(os.listdir())
# Out:
# ['aux.txt', 'aux.py', 'generate_psychoacoustic_features.py', '.DS_Store', 'Mosqito', 'Generate_features.ipynb', 'features_pca.ipynb', 'SoundLights', 'Adequate_responses_csv.ipynb', 'Nspec.npy', 'dummy_labelMean_model.ipynb', 'Checking_PPM-AC_functions.ipynb', 'PsychoacousticParametersMeasurerAndreaCastiella', 'elastic_net_model.ipynb', 'old_code', 'Nspec.csv', 'roughnessMatlab.m', 'trying_essentia.ipynb']

# %%
import numpy as np
i=0
for frame in frames:
    print(i)
    print(frame, type(frames[frame]))
    if(type(frames[frame])==np.ndarray):
        
        print(frame,frames[frame].shape)
    i=i+1
print(frames["lowlevel.melbands"].shape)
print(frames["lowlevel.mfcc"].shape)

""" lowlevel.hfc
lowlevel.pitch_salience
lowlevel.silence_rate_20dB
lowlevel.silence_rate_30dB
lowlevel.silence_rate_60dB
lowlevel.silence_rate_90dB
lowlevel.spectral_centroid
lowlevel.spectral_energy
lowlevel.spectral_energyband_high
lowlevel.spectral_energyband_low
lowlevel.spectral_energyband_middle_high
lowlevel.spectral_energyband_middle_low  """
# Out:
# 0
# lowlevel.average_loudness <class 'float'>
# 1
# lowlevel.dynamic_complexity <class 'float'>
# 2
# lowlevel.loudness_ebu128.integrated <class 'float'>
# 3
# lowlevel.loudness_ebu128.loudness_range <class 'float'>
# 4
# lowlevel.sound_start_frame <class 'float'>
# 5
# lowlevel.sound_stop_frame <class 'float'>
# 6
# metadata.audio_properties.analysis.equal_loudness <class 'float'>
# 7
# metadata.audio_properties.analysis.length <class 'float'>
# 8
# metadata.audio_properties.analysis.sample_rate <class 'float'>
# 9
# metadata.audio_properties.analysis.start_time <class 'float'>
# 10
# metadata.audio_properties.bit_rate <class 'float'>
# 11
# metadata.audio_properties.length <class 'float'>
# 12
# metadata.audio_properties.lossless <class 'float'>
# 13
# metadata.audio_properties.number_channels <class 'float'>
# 14
# metadata.audio_properties.sample_rate <class 'float'>
# 15
# rhythm.bpm <class 'float'>
# 16
# rhythm.bpm_histogram_first_peak_bpm <class 'float'>
# 17
# ...

# %%
import essentia
#print(essentia.standard.FreesoundExtractor)
essentia.standard.FreesoundExtractor.analysisSampleRate=48000
help(essentia.standard.FreesoundExtractor)
# Out:
# Help on class Algo in module essentia.standard:
#
# class Algo(Algorithm)
#  |  Algo(**kwargs)
#  |
#  |  FreesoundExtractor
#  |
#  |
#  |  Inputs:
#  |
#  |    [string] filename - the input audiofile
#  |
#  |
#  |  Outputs:
#  |
#  |    [pool] results - Analysis results pool with across-frames statistics
#  |    [pool] resultsFrames - Analysis results pool with computed frame values
#  |
#  |
#  |  Parameters:
#  |
#  |    analysisSampleRate:
#  |      real ∈ (0,inf) (default = 44100)
#  |      the analysis sampling rate of the audio signal [Hz]
#  |
#  |    endTime:
#  |      real ∈ [0,inf) (default = 1000000)
#  |      the end time of the slice you want to extract [s]
#  |
#  |    gfccStats:
#  |      vector_string (default = ["mean", "var", "stdev", "median", "min", "max", "dmean", "dmean2", "dvar", "dvar2"])
#  |      the statistics to compute for GFCC features
#  |
#  |    lowlevelFrameSize:
#  |      integer ∈ (0,inf) (default = 2048)
# ...
